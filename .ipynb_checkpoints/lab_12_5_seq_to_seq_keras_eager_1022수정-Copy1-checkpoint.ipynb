# %% [markdown]
# # Lab 12-5 sequence to sequence (Keras + eager version)
#
# ### simple neural machine translation training
#
# * sequence to sequence
#
# ### Reference
# * [Sequence to Sequence Learning with Neural Networks](https://arxiv.org/abs/1409.3215)

# %%
pip install tensorflow==1.15
# Out:
# Requirement already satisfied: tensorflow==1.15 in c:\programdata\anaconda3\lib\site-packages (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: gast==0.2.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.24.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.11.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.33.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.16.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.1.7)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.9.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (0.14.1)
# Collecting setuptools>=41.0.0 (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15)
#   Downloading https://files.pythonhosted.org/packages/6a/9a/50fadfd53ec909e4399b67c74cc7f4e883488035cfcdb90b685758fa8b34/setuptools-41.4.0-py2.py3-none-any.whl (580kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.1)
# Installing collected packages: setuptools
#   Found existing installation: setuptools 40.8.0
#     Uninstalling setuptools-40.8.0:
#       Successfully uninstalled setuptools-40.8.0
# Successfully installed setuptools-41.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import absolute_import, division, print_function

# Import TensorFlow >= 1.10 and enable eager execution
import tensorflow as tf
print(tf.__version__)
tf.enable_eager_execution()

from matplotlib import font_manager, rc

rc('font', family='AppleGothic') #for mac

import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

from pprint import pprint
import numpy as np
import os
import pandas as pd
import re
#요약
from gensim.summarization.summarizer import summarize
# Out:
# 1.15.0

# %%
#path = '/content/drive/My Drive/Colab Notebooks/moviedata2.json'
df = pd.read_json('moviedata2.json')[:10000]

# %% [markdown]
# # 전처리

# %%
#df = movie_dataframe

df.movie_name = df.movie_name.apply(lambda x: x.replace('혻',''))

df.movie_summary = df.movie_summary.apply(lambda x: str(x).lower())
df.movie_summary = df.movie_summary.apply(lambda x: re.sub("[^A-Za-z. 0-9]", '', x))
df.movie_summary = df.movie_summary.apply(lambda x: x.replace('\\n',''))

#df.movie_synopsis = df.movie_synopsis.apply(lambda x : str(x).lower())
#df.movie_synopsis = df.movie_synopsis.apply(lambda x : re.sub('[^A-Za-z. ]', '', x))

df.movie_tagline = df.movie_tagline.apply(lambda x: str(x).lower())
df.movie_tagline = df.movie_tagline.apply(lambda x: x.replace('\\n','').replace('\\xa0',''))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub('[^A-Za-z. 0-9]', '', x))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub(' {2,}', '', x))

#태그라인 없는 데이터 row 삭제
index = df[df['movie_tagline']==''].index
df.drop(index, inplace = True)

#summary 없는 데이터 row 삭제
summary_index = df[df['movie_summary']==''].index
df.drop(summary_index, inplace = True)

index = df[df['movie_summary'].str.contains('  ')].index
df.drop(index , inplace = True)

index = df[df['movie_summary']==''].index
df.drop(index, inplace=True)
df = df.reset_index()
df.drop(df.index[-172:], inplace = True)

# %%
df
# Out:
#       index                                        movie_genre  \
# 0         0               [Adventure, Drama, Horror, Thriller]
# 1         2                                   [Horror, Sci-Fi]
# 2         4                        [Adventure, Drama, Fantasy]
# 3         5                           [Crime, Drama, Thriller]
# 4         6                       [Adventure, Family, Fantasy]
# 5         7                          [Comedy, Family, Fantasy]
# 6        18                        [Horror, Mystery, Thriller]
# 7        21                            [Action, Crime, Horror]
# 8        23                                   [Drama, Western]
# 9        24                                     [Drama, Sport]
# 10       25                      [Action, Adventure, Thriller]
# 11       26                       [Action, Adventure, Fantasy]
# 12       27                        [Action, Adventure, Sci-Fi]
# 13       29                                            [Drama]
# 14       31                  [Crime, Drama, Mystery, Thriller]
# 15       32                          [Action, Crime, Thriller]
# 16       33                 [Action, Crime, Fantasy, Thriller]
# 17       34                [Action, Adventure, Drama, Romance]
# 18       39                                   [Drama, History]
# 19       44              [Action, Adventure, Sci-Fi, Thriller]
# 20       45               [Action, Adventure, Drama, Thriller]
# 21       48                  [Biography, Comedy, Drama, Sport]
# 22       49                        [Action, Adventure, Sci-Fi]
# 23       50                 [Action, Horror, Sci-Fi, Thriller]
# 24       51            [Action, Drama, Romance, Thriller, War]
# 25       52                   [Action, Crime, Drama, Thriller]
# 26       54  [Action, Crime, Drama, Mystery, Sci-Fi, Thriller]
# 27       57                      [Adventure, Horror, Thriller]
# 28       58                               [Drama, Horror, War]
# 29       59                        [Action, Adventure, Sci-Fi]
# ...     ...                                                ...
# 3896   9324                                           [Horror]
# 3897   9327                                      [Documentary]
# 3898   9329                             [Comedy, Crime, Drama]
# 3899   9332                                    [Comedy, Crime]
# 3900   9333                                   [Drama, Romance]
# 3901   9342                              [Drama, Romance, War]
# 3902   9343                             [Drama, Sci-Fi, Sport]
# 3903   9344    [Adventure, Animation, Family, Sci-Fi, Fantasy]
# 3904   9345                                    [Action, Drama]
# 3905   9349                                           [Comedy]
# 3906   9350                                       [Drama, War]
# 3907   9356                                            [Drama]
# 3908   9361                                [Adventure, Comedy]
# 3909   9364                                           [Comedy]
# 3910   9365                        [Action, Crime, Drama, War]
# 3911   9370                           [Drama, Family, Romance]
# 3912   9380                                  [Comedy, Romance]
# 3913   9382                                 [Comedy, Thriller]
# 3914   9383     [Animation, Adventure, Drama, Family, Fantasy]
# 3915   9385                                           [Horror]
# 3916   9387                                           [Horror]
# 3917   9390                                           [Action]
# 3918   9397                          [Comedy, Crime, Thriller]
# 3919   9398          [Action, Comedy, Music, Romance, Western]
# 3920   9399                         [Comedy, Musical, Romance]
# 3921   9401  [Action, Biography, Crime, Drama, Family, Fant...
# 3922   9403                                   [Drama, Romance]
# 3923   9408                  [Crime, Drama, History, Thriller]
# 3924   9410                                   [Horror, Sci-Fi]
# 3925   9411                                    [Comedy, Drama]
#
#                                              movie_name  \
# 0                               47 Meters Down: Uncaged
# 1                                                 Alien
# 2     The Lord of the Rings: The Fellowship of the Ring
# 3                                              The Mule
# 4                 Harry Potter and the Sorcerer's Stone
# 5                                           Hocus Pocus
# 6                                       Friday the 13th
# 7                                   From Dusk Till Dawn
# 8                                      Django Unchained
# 9                                             Overcomer
# 10                                              Mile 22
# 11                                                 Thor
# 12                                            Star Trek
# 13                                      American Beauty
# 14                             In the Heat of the Night
# 15                                      The Equalizer 2
# 16                                               Wanted
# 17                                            King Kong
# 18                                                 Troy
# 19                The Hunger Games: Mockingjay - Part 1
# 20                                      The Book of Eli
# 21                              Fighting with My Family
# 22                                        Green Lantern
# 23                                            They Live
# 24                                               Allied
# 25                                  Law Abiding Citizen
# 26                                             Criminal
# 27                                          The Descent
# 28                       Sal챵, or the 120 Days of Sodom
# 29                      Transformers: Age of Extinction
# ...                                                 ...
# 3896                                          The Demon
# 3897                                 Devil's Playground
# 3898                                             M챕nage
# 3899                                         Hard Times
# 3900                              The End of the Affair
# 3901                               The Wind Cannot Read
# 3902                                         Goldengirl
# 3903                 A Journey to the Beginning of Time
# 3904                                      Bare Knuckles
# 3905                                The Swinging Co-eds
# 3906                                             Kippur
# 3907                                               Camp
# 3908                                    Crazy Hong Kong
# 3909                                The White River Kid
# 3910                                        Death Force
# 3911                                              Leila
# 3912                                    Just the Ticket
# 3913                                         Gan-gi-nam
# 3914                                  On Happiness Road
# 3915                               Night of the Pumpkin
# 3916                                            The Jar
# 3917                                          Killpoint
# 3918                  The J철nsson Gang & Dynamite Harry
# 3919                                           Pardners
# 3920                                     The Stork Club
# 3921                                   The Masked Saint
# 3922                               Kissing on the Mouth
# 3923                                  No God, No Master
# 3924                                Frankenstein Island
# 3925                             Agnes and His Brothers
#
#                                            movie_poster  \
# 0     www.imdb.com/title/tt7329656/mediaviewer/rm242...
# 1     www.imdb.com/title/tt0078748/mediaviewer/rm299...
# 2     www.imdb.com/title/tt0120737/mediaviewer/rm359...
# 3     www.imdb.com/title/tt7959026/mediaviewer/rm320...
# 4     www.imdb.com/title/tt0241527/mediaviewer/rm683...
# 5     www.imdb.com/title/tt0107120/mediaviewer/rm354...
# 6     www.imdb.com/title/tt0758746/mediaviewer/rm380...
# 7     www.imdb.com/title/tt0116367/mediaviewer/rm147...
# 8     www.imdb.com/title/tt1853728/mediaviewer/rm958...
# 9     www.imdb.com/title/tt8186318/mediaviewer/rm428...
# 10    www.imdb.com/title/tt4560436/mediaviewer/rm285...
# 11    www.imdb.com/title/tt0800369/mediaviewer/rm327...
# 12    www.imdb.com/title/tt0796366/mediaviewer/rm101...
# 13    www.imdb.com/title/tt0169547/mediaviewer/rm243...
# 14    www.imdb.com/title/tt0061811/mediaviewer/rm258...
# 15    www.imdb.com/title/tt3766354/mediaviewer/rm140...
# 16    www.imdb.com/title/tt0493464/mediaviewer/rm108...
# 17    www.imdb.com/title/tt0360717/mediaviewer/rm252...
# 18    www.imdb.com/title/tt0332452/mediaviewer/rm108...
# 19    www.imdb.com/title/tt1951265/mediaviewer/rm425...
# 20    www.imdb.com/title/tt1037705/mediaviewer/rm231...
# 21    www.imdb.com/title/tt6513120/mediaviewer/rm280...
# 22    www.imdb.com/title/tt1133985/mediaviewer/rm314...
# 23    www.imdb.com/title/tt0096256/mediaviewer/rm141...
# 24    www.imdb.com/title/tt3640424/mediaviewer/rm195...
# 25    www.imdb.com/title/tt1197624/mediaviewer/rm374...
# 26    www.imdb.com/title/tt3014866/mediaviewer/rm144...
# 27    www.imdb.com/title/tt0435625/mediaviewer/rm398...
# 28    www.imdb.com/title/tt0073650/mediaviewer/rm423...
# 29    www.imdb.com/title/tt2109248/mediaviewer/rm100...
# ...                                                 ...
# 3896  www.imdb.com/title/tt0074390/mediaviewer/rm540...
# 3897  www.imdb.com/title/tt0293088/mediaviewer/rm743...
# 3898  www.imdb.com/title/tt0092068/mediaviewer/rm910...
# 3899  www.imdb.com/title/tt1292652/mediaviewer/rm215...
# 3900  www.imdb.com/title/tt0048034/mediaviewer/rm266...
# 3901  www.imdb.com/title/tt0052396/mediaviewer/rm688...
# 3902  www.imdb.com/title/tt0079225/mediaviewer/rm341...
# 3903  www.imdb.com/title/tt0047930/mediaviewer/rm229...
# 3904  www.imdb.com/title/tt1063327/mediaviewer/rm207...
# 3905  www.imdb.com/title/tt0068988/mediaviewer/rm144...
# 3906  www.imdb.com/title/tt0218379/mediaviewer/rm427...
# 3907  www.imdb.com/title/tt2371287/mediaviewer/rm240...
# 3908  www.imdb.com/title/tt0107102/mediaviewer/rm428...
# 3909  www.imdb.com/title/tt0162766/mediaviewer/rm146...
# 3910  www.imdb.com/title/tt0076024/mediaviewer/rm198...
# 3911  www.imdb.com/title/tt0116851/mediaviewer/rm248...
# 3912  www.imdb.com/title/tt0123221/mediaviewer/rm122...
# 3913  www.imdb.com/title/tt2365847/mediaviewer/rm230...
# 3914  www.imdb.com/title/tt7543904/mediaviewer/rm400...
# 3915  www.imdb.com/title/tt1627926/mediaviewer/rm114...
# 3916  www.imdb.com/title/tt0130040/mediaviewer/rm142...
# 3917  www.imdb.com/title/tt0087556/mediaviewer/rm427...
# 3918  www.imdb.com/title/tt0084189/mediaviewer/rm290...
# 3919  www.imdb.com/title/tt0049593/mediaviewer/rm179...
# 3920  www.imdb.com/title/tt0038119/mediaviewer/rm211...
# 3921  www.imdb.com/title/tt3103166/mediaviewer/rm237...
# 3922  www.imdb.com/title/tt0446725/mediaviewer/rm307...
# 3923  www.imdb.com/title/tt1485761/mediaviewer/rm234...
# 3924  www.imdb.com/title/tt0082410/mediaviewer/rm386...
# 3925  www.imdb.com/title/tt0389738/mediaviewer/rm404...
#
#                                           movie_summary  \
# 0     four teen girls diving in a ruined underwater ...
# 1     after a space merchant vessel perceives an unk...
# 2     a meek hobbit from the shire and eight compani...
# 3     a 90yearold horticulturist and korean war vete...
# 4     an orphaned boy enrolls in a school of wizardr...
# 5     a curious youngster moves to salem where he st...
# 6     a group of young adults discover a boarded up ...
# 7     two criminals and their hostages unknowingly s...
# 8     with the help of a german bounty hunter a free...
# 9     a highschool basketball coach volunteers to co...
# 10    a small team of elite american intelligence of...
# 11    the powerful but arrogant god thor is cast out...
# 12    the brash james t. kirk tries to live up to hi...
# 13    a sexually frustrated suburban father has a mi...
# 14    an africanamerican police detective is asked t...
# 15    robert mccall serves an unflinching justice fo...
# 16    a frustrated office worker learns that he is t...
# 17    a greedy film producer assembles a team of mov...
# 18    an adaptation of homers great epic the film fo...
# 19    katniss everdeen is in district 13 after she s...
# 20    a postapocalyptic tale in which a lone man fig...
# 21    a former wrestler and his family make a living...
# 22    reckless test pilot hal jordan is granted an a...
# 23    a drifter discovers a pair of sunglasses that ...
# 24    in 1942 a canadian intelligence officer in nor...
# 25    a frustrated man decides to take justice into ...
# 26    in a lastditch effort to stop a diabolical plo...
# 27    a caving expedition goes horribly wrong as the...
# 28    in world war ii italy four fascist libertines ...
# 29    when humanity allies with a bounty hunter in p...
# ...                                                 ...
# 3896  random people are terrorized by a malevolent m...
# 3897  amish teenagers experience and embrace the mod...
# 3898  a bisexual petty criminal named bob encounters...
# 3899  the town of kilcoulins leap will never be the ...
# 3900  in wartorn london maurice bendrix van johnson ...
# 3901  during world war ii flight lieutenant michael ...
# 3902  a neonazi doctor tries to make a superwoman of...
# 3903  youngest of four boys one day finds a fossil o...
# 3904  can a determined single mom go the distance an...
# 3905  young women come to munich for fun and work du...
# 3906  the film takes place in 1973 during the yom ki...
# 3907  10yearold eli finds himself at summer camp. to...
# 3908  the gods are still crazy after all these years...
# 3909  brother edgar is a generous entrepreneur of lo...
# 3910  an american vietnam soldier on his way home is...
# 3911  leila and reza meet in a kind of celebration a...
# 3912  a ticket scalper wants to make one last big de...
# 3913  a detective seonwoo who moonlights as a privat...
# 3914  chi earned her american dream after perseverin...
# 3915  the pumpkin man embarks on a murderous spree o...
# 3916  a motorist who comes upon an auto accident fin...
# 3917  an l.a. cop investigating the rape and murder ...
# 3918  sickan vanheden and rocky try to rob the berns...
# 3919  a rich mommas boy returns west with the son of...
# 3920  a hatcheck girl at the stork club hutton saves...
# 3921  a pastor and professional wrestler accepts a p...
# 3922  raw. honest. naked. kissing on the mouth is po...
# 3923  when a series of package bombs show up on the ...
# 3924  when a hotair balloon crashes on a remote isla...
# 3925  this drama focuses on three very different sib...
#
#                                          movie_synopsis  \
# 0     [The film starts at a girls school in Yucatan,...
# 1     [The opening credits appear in front of a larg...
# 2     [The prologue, spoken by Galadriel, shows the ...
# 3     [This movie is based on a true story of a Worl...
# 4     [Lord Voldemort, an evil and powerful dark wiz...
# 5     [Hocus Pocus begins in a small town in 1693, w...
# 6                  [\n                , \n            ]
# 7     [Texas sheriff Edgar McGraw pulls up to an iso...
# 8     [In 1858, Django (, ), a slave, is chained to ...
# 9     [The opening scene takes us into the gym of Br...
# 10    [The film starts with agents Alice Kerr (Laure...
# 11    [Three scientists, Jane Foster (, ), Erik Selv...
# 12    [In 2233, the USS Kelvin, a Federation starshi...
# 13    [Lester Burnham (Kevin Spacey) is a 42-year-ol...
# 14    [Philip Colbert, a wealthy man from Chicago wh...
# 15    [The film opens on the Turkish Railway, 400 mi...
# 16    [A young man named Wesley Gibson (James McAvoy...
# 17    [In 1933, during the Great Depression, vaudevi...
# 18    [The story takes place in the fertile, eastern...
# 19    [Katniss Everdeen (, ), victor of the 74th and...
# 20    [The film opens in ash-filled woods. A corpse ...
# 21    [Young Saraya Bevis and her brother Zak are fi...
# 22    [Millions of years before the Earth was formed...
# 23    [George Nada (Roddy Piper) is a homeless labor...
# 24    [French Morocco, 1940, Max Vatan (Brad Pitt) p...
# 25    [Clyde Shelton (Gerard Butler), a Philadelphia...
# 26    [The film opens with Jericho Stewart (Kevin Co...
# 27    [A whitewater rafting trip is underway, with t...
# 28                 [\n                , \n            ]
# 29    [After defeating Sentinel Prime and Megatron's...
# ...                                                 ...
# 3896               [\n                , \n            ]
# 3897  [The Devil's Playground is a fascinating and m...
# 3898               [\n                , \n            ]
# 3899               [\n                , \n            ]
# 3900               [\n                , \n            ]
# 3901               [\n                , \n            ]
# 3902               [\n                , \n            ]
# 3903               [\n                , \n            ]
# 3904  [Women will go to extreme lengths for those th...
# 3905               [\n                , \n            ]
# 3906               [\n                , \n            ]
# 3907  [Eli lives in a small town. His mother is a dr...
# 3908               [\n                , \n            ]
# 3909               [\n                , \n            ]
# 3910               [\n                , \n            ]
# 3911               [\n                , \n            ]
# 3912               [\n                , \n            ]
# 3913               [\n                , \n            ]
# 3914               [\n                , \n            ]
# 3915               [\n                , \n            ]
# 3916               [\n                , \n            ]
# 3917               [\n                , \n            ]
# 3918               [\n                , \n            ]
# 3919               [\n                , \n            ]
# 3920  [Jerry Bates "Pop"(Barry Fitzgerald) is stroll...
# 3921               [\n                , \n            ]
# 3922               [\n                , \n            ]
# 3923               [\n                , \n            ]
# 3924               [\n                , \n            ]
# 3925               [\n                , \n            ]
#
#                                           movie_tagline
# 0                                     the next chapter
# 1                         its alien the 8th passenger.
# 2      all we have to decide is what to do with the ...
# 3                                  nobody runs forever
# 4                      the magic begins november 16th.
# 5                       its just a bunch of hocus pocus
# 6      you know his name. you know the story. on fri...
# 7                             vampires. no interviews.
# 8                    the d is silent. payback wont be.
# 9                      what do you allow to define you
# 10                 90 minutes. 22 miles. zero back up.
# 11                               two worlds. one hero.
# 12                                  the future begins.
# 13                                      ... look closer
# 14     theyre going to pin something on that smart c...
# 15                            dont go to war with him.
# 16                their world. her rules. his destiny.
# 17                      the eighth wonder of the world.
# 18                                            for love
# 19                 fire burns brighter in the darkness
# 20                                   religion is power
# 21                 based on the incredible true story.
# 22     in brightest day in blackest night no evil sh...
# 23     i have come here to chew bubblegum and kick a...
# 24                             nothing is as it seems.
# 25                                 justice at any cost
# 26     the cias last hope is in the mind of a criminal
# 27           afraid of the dark you will be july 2005.
# 28     banned in australia for 17 yearsnow for the f...
# 29                              the rules have changed
# ...                                                 ...
# 3896        the night he came to town the terror began
# 3897                        which path will they choose
# 3898                                    putain de film
# 3899                 a new breed of hardened criminals
# 3900   a tremendous emotional experience print ad ja...
# 3901   2000 years of tradition said no to their love...
# 3902   these five men have developed trained and pro...
# 3903   four boys living the excitement every boy dre...
# 3904                        she fought for everything.
# 3905   working their way through collegeno job is to...
# 3906                       bloody vivid... unvarnished.
# 3907                hope is found in unexpected places.
# 3908   he comes from a hostile and primitive land......
# 3909   sometimes its hard to tell the saints from th...
# 3910   shes in playboy. hes out of penitentiary. jay...
# 3911   the tragedy of a love torn apart by each part...
# 3912   irresponsible unreliable unpredictable and to...
# 3913              a woman in mystery. a man in jeopardy
# 3914     does our dream always come true as we expected
# 3915         that which you carve may one day carve you
# 3916       the jar . . . it blows the lid off of terror
# 3917                 ...street violence out of control.
# 3918                          jnssonligan slr till igen
# 3919   youll ride with em shoot with em laugh with e...
# 3920   don cant give betty anything but love ... bar...
# 3921                             husband. pastor. hero.
# 3922                       postcollege life in closeup.
# 3923                         fearjusticefreedomanarchy
# 3924                the power is 7000000 voltsits alive
# 3925   ... auf dem weg ins glck ... on the way to ha...
#
# [3926 rows x 7 columns]

# %%
df
# Out:
#       level_0  index                                        movie_genre  \
# 0           0      0               [Adventure, Drama, Horror, Thriller]
# 1           1      2                                   [Horror, Sci-Fi]
# 2           2      4                        [Adventure, Drama, Fantasy]
# 3           3      5                           [Crime, Drama, Thriller]
# 4           4      6                       [Adventure, Family, Fantasy]
# 5           5      7                          [Comedy, Family, Fantasy]
# 6           6     18                        [Horror, Mystery, Thriller]
# 7           7     21                            [Action, Crime, Horror]
# 8           8     23                                   [Drama, Western]
# 9           9     24                                     [Drama, Sport]
# 10         10     25                      [Action, Adventure, Thriller]
# 11         11     26                       [Action, Adventure, Fantasy]
# 12         12     27                        [Action, Adventure, Sci-Fi]
# 13         13     29                                            [Drama]
# 14         14     31                  [Crime, Drama, Mystery, Thriller]
# 15         15     32                          [Action, Crime, Thriller]
# 16         16     33                 [Action, Crime, Fantasy, Thriller]
# 17         17     34                [Action, Adventure, Drama, Romance]
# 18         18     39                                   [Drama, History]
# 19         19     44              [Action, Adventure, Sci-Fi, Thriller]
# 20         20     45               [Action, Adventure, Drama, Thriller]
# 21         21     48                  [Biography, Comedy, Drama, Sport]
# 22         22     49                        [Action, Adventure, Sci-Fi]
# 23         23     50                 [Action, Horror, Sci-Fi, Thriller]
# 24         24     51            [Action, Drama, Romance, Thriller, War]
# 25         25     52                   [Action, Crime, Drama, Thriller]
# 26         26     54  [Action, Crime, Drama, Mystery, Sci-Fi, Thriller]
# 27         27     57                      [Adventure, Horror, Thriller]
# 28         28     58                               [Drama, Horror, War]
# 29         29     59                        [Action, Adventure, Sci-Fi]
# ...       ...    ...                                                ...
# 3700     3700   8679      [Action, Adventure, Horror, Sci-Fi, Thriller]
# 3701     3701   8683                                    [Action, Drama]
# 3702     3702   8684                                   [Action, Sci-Fi]
# 3703     3703   8685                            [Crime, Drama, Romance]
# 3704     3704   8688                                   [Drama, Western]
# 3705     3705   8692                                 [Comedy, Thriller]
# 3706     3706   8694  [Action, Adventure, Comedy, Drama, Fantasy, Ho...
# 3707     3707   8704                                          [Western]
# 3708     3708   8708                          [Musical, Drama, Romance]
# 3709     3709   8710       [Crime, Drama, Film-Noir, Mystery, Thriller]
# 3710     3710   8718                                  [Drama, Thriller]
# 3711     3711   8719  [Comedy, Drama, Horror, Mystery, Romance, Thri...
# 3712     3712   8720                  [Action, Fantasy, Horror, Sci-Fi]
# 3713     3713   8732                       [Adventure, Crime, Thriller]
# 3714     3714   8736                                     [Drama, Sport]
# 3715     3715   8738                                  [Drama, Thriller]
# 3716     3716   8745                 [Action, Drama, Thriller, Western]
# 3717     3717   8746                                 [Biography, Drama]
# 3718     3718   8749                           [Comedy, Drama, Fantasy]
# 3719     3719   8750                             [Horror, Romance, War]
# 3720     3720   8754                  [Action, Drama, Romance, Western]
# 3721     3721   8763                        [Horror, Mystery, Thriller]
# 3722     3722   8768                                  [Comedy, Romance]
# 3723     3723   8769                                [Adventure, Family]
# 3724     3724   8770                         [Thriller, Crime, Romance]
# 3725     3725   8772                                    [Comedy, Crime]
# 3726     3726   8773                                   [Drama, Romance]
# 3727     3727   8778                                    [Drama, Horror]
# 3728     3728   8780                  [Crime, Drama, Mystery, Thriller]
# 3729     3729   8784                                     [Drama, Music]
#
#                                              movie_name  \
# 0                               47 Meters Down: Uncaged
# 1                                                 Alien
# 2     The Lord of the Rings: The Fellowship of the Ring
# 3                                              The Mule
# 4                 Harry Potter and the Sorcerer's Stone
# 5                                           Hocus Pocus
# 6                                       Friday the 13th
# 7                                   From Dusk Till Dawn
# 8                                      Django Unchained
# 9                                             Overcomer
# 10                                              Mile 22
# 11                                                 Thor
# 12                                            Star Trek
# 13                                      American Beauty
# 14                             In the Heat of the Night
# 15                                      The Equalizer 2
# 16                                               Wanted
# 17                                            King Kong
# 18                                                 Troy
# 19                The Hunger Games: Mockingjay - Part 1
# 20                                      The Book of Eli
# 21                              Fighting with My Family
# 22                                        Green Lantern
# 23                                            They Live
# 24                                               Allied
# 25                                  Law Abiding Citizen
# 26                                             Criminal
# 27                                          The Descent
# 28                       Sal챵, or the 120 Days of Sodom
# 29                      Transformers: Age of Extinction
# ...                                                 ...
# 3700                        The Brain from Planet Arous
# 3701              Lone Wolf and Cub: Baby Cart to Hades
# 3702                                      Wired to Kill
# 3703                                  My Forbidden Past
# 3704                              Welcome to Hard Times
# 3705                                       Mickey Virus
# 3706                     Yongary, Monster from the Deep
# 3707                                             Cowboy
# 3708                                           Aashiqui
# 3709                                 Affair in Trinidad
# 3710                      Death Blow: A Cry for Justice
# 3711                          Gentlemen Don't Eat Poets
# 3712                                   Ninja Apocalypse
# 3713                                         Madame Sin
# 3714                                          True Blue
# 3715                                    The Liars' Club
# 3716                                 A Man Called Blade
# 3717                               The President's Lady
# 3718                                          Takeshis'
# 3719                                           Nang Nak
# 3720                                  Gunfighter's Moon
# 3721                                              Bodom
# 3722                                 The Callback Queen
# 3723                      The Greening of Whitney Brown
# 3724                                                 Rx
# 3725                     Adventures of a Plumber's Mate
# 3726                                    No Greater Love
# 3727                                           The Past
# 3728                                Compartiment tueurs
# 3729                                  Higher and Higher
#
#                                            movie_poster  \
# 0     www.imdb.com/title/tt7329656/mediaviewer/rm242...
# 1     www.imdb.com/title/tt0078748/mediaviewer/rm299...
# 2     www.imdb.com/title/tt0120737/mediaviewer/rm359...
# 3     www.imdb.com/title/tt7959026/mediaviewer/rm320...
# 4     www.imdb.com/title/tt0241527/mediaviewer/rm683...
# 5     www.imdb.com/title/tt0107120/mediaviewer/rm354...
# 6     www.imdb.com/title/tt0758746/mediaviewer/rm380...
# 7     www.imdb.com/title/tt0116367/mediaviewer/rm147...
# 8     www.imdb.com/title/tt1853728/mediaviewer/rm958...
# 9     www.imdb.com/title/tt8186318/mediaviewer/rm428...
# 10    www.imdb.com/title/tt4560436/mediaviewer/rm285...
# 11    www.imdb.com/title/tt0800369/mediaviewer/rm327...
# 12    www.imdb.com/title/tt0796366/mediaviewer/rm101...
# 13    www.imdb.com/title/tt0169547/mediaviewer/rm243...
# 14    www.imdb.com/title/tt0061811/mediaviewer/rm258...
# 15    www.imdb.com/title/tt3766354/mediaviewer/rm140...
# 16    www.imdb.com/title/tt0493464/mediaviewer/rm108...
# 17    www.imdb.com/title/tt0360717/mediaviewer/rm252...
# 18    www.imdb.com/title/tt0332452/mediaviewer/rm108...
# 19    www.imdb.com/title/tt1951265/mediaviewer/rm425...
# 20    www.imdb.com/title/tt1037705/mediaviewer/rm231...
# 21    www.imdb.com/title/tt6513120/mediaviewer/rm280...
# 22    www.imdb.com/title/tt1133985/mediaviewer/rm314...
# 23    www.imdb.com/title/tt0096256/mediaviewer/rm141...
# 24    www.imdb.com/title/tt3640424/mediaviewer/rm195...
# 25    www.imdb.com/title/tt1197624/mediaviewer/rm374...
# 26    www.imdb.com/title/tt3014866/mediaviewer/rm144...
# 27    www.imdb.com/title/tt0435625/mediaviewer/rm398...
# 28    www.imdb.com/title/tt0073650/mediaviewer/rm423...
# 29    www.imdb.com/title/tt2109248/mediaviewer/rm100...
# ...                                                 ...
# 3700  www.imdb.com/title/tt0050210/mediaviewer/rm335...
# 3701  www.imdb.com/title/tt0068817/mediaviewer/rm342...
# 3702  www.imdb.com/title/tt0092224/mediaviewer/rm648...
# 3703  www.imdb.com/title/tt0043828/mediaviewer/rm702...
# 3704  www.imdb.com/title/tt0062482/mediaviewer/rm861...
# 3705  www.imdb.com/title/tt2796318/mediaviewer/rm875...
# 3706  www.imdb.com/title/tt0061549/mediaviewer/rm162...
# 3707  www.imdb.com/title/tt0051496/mediaviewer/rm279...
# 3708  www.imdb.com/title/tt0149573/mediaviewer/rm584...
# 3709  www.imdb.com/title/tt0044331/mediaviewer/rm335...
# 3710  www.imdb.com/title/tt0094284/mediaviewer/rm172...
# 3711  www.imdb.com/title/tt0113224/mediaviewer/rm169...
# 3712  www.imdb.com/title/tt3085500/mediaviewer/rm134...
# 3713  www.imdb.com/title/tt0067375/mediaviewer/rm391...
# 3714  www.imdb.com/title/tt0117973/mediaviewer/rm321...
# 3715  www.imdb.com/title/tt0107401/mediaviewer/rm110...
# 3716  www.imdb.com/title/tt0076360/mediaviewer/rm231...
# 3717  www.imdb.com/title/tt0046204/mediaviewer/rm122...
# 3718  www.imdb.com/title/tt0478044/mediaviewer/rm188...
# 3719  www.imdb.com/title/tt0217680/mediaviewer/rm485...
# 3720  www.imdb.com/title/tt0113238/mediaviewer/rm163...
# 3721  www.imdb.com/title/tt3669462/mediaviewer/rm158...
# 3722  www.imdb.com/title/tt1890559/mediaviewer/rm348...
# 3723  www.imdb.com/title/tt1507564/mediaviewer/rm417...
# 3724  www.imdb.com/title/tt0357182/mediaviewer/rm346...
# 3725  www.imdb.com/title/tt0077125/mediaviewer/rm139...
# 3726  www.imdb.com/title/tt1225703/mediaviewer/rm982...
# 3727  www.imdb.com/title/tt8011712/mediaviewer/rm115...
# 3728  www.imdb.com/title/tt0059050/mediaviewer/rm708...
# 3729  www.imdb.com/title/tt0065877/mediaviewer/rm288...
#
#                                           movie_summary  \
# 0     four teen girls diving in a ruined underwater ...
# 1     after a space merchant vessel perceives an unk...
# 2     a meek hobbit from the shire and eight compani...
# 3     a 90yearold horticulturist and korean war vete...
# 4     an orphaned boy enrolls in a school of wizardr...
# 5     a curious youngster moves to salem where he st...
# 6     a group of young adults discover a boarded up ...
# 7     two criminals and their hostages unknowingly s...
# 8     with the help of a german bounty hunter a free...
# 9     a highschool basketball coach volunteers to co...
# 10    a small team of elite american intelligence of...
# 11    the powerful but arrogant god thor is cast out...
# 12    the brash james t. kirk tries to live up to hi...
# 13    a sexually frustrated suburban father has a mi...
# 14    an africanamerican police detective is asked t...
# 15    robert mccall serves an unflinching justice fo...
# 16    a frustrated office worker learns that he is t...
# 17    a greedy film producer assembles a team of mov...
# 18    an adaptation of homers great epic the film fo...
# 19    katniss everdeen is in district 13 after she s...
# 20    a postapocalyptic tale in which a lone man fig...
# 21    a former wrestler and his family make a living...
# 22    reckless test pilot hal jordan is granted an a...
# 23    a drifter discovers a pair of sunglasses that ...
# 24    in 1942 a canadian intelligence officer in nor...
# 25    a frustrated man decides to take justice into ...
# 26    in a lastditch effort to stop a diabolical plo...
# 27    a caving expedition goes horribly wrong as the...
# 28    in world war ii italy four fascist libertines ...
# 29    when humanity allies with a bounty hunter in p...
# ...                                                 ...
# 3700  gor a powerful criminal brain from the planet ...
# 3701  ogami itto volunteers to be tortured by the ya...
# 3702  in the near future law and order breaks down d...
# 3703  barbara beaurevel lives with her aunt and cous...
# 3704  a sociopathic stranger all but destroys a smal...
# 3705  when delhi police comes across an unusual case...
# 3706  earthquakes in central korea turn out to be th...
# 3707  an idealistic tenderfoot chicago hotel clerk i...
# 3708  rahul and anu fall in love with each other but...
# 3709  nightclub singer and her brotherinlaw try to f...
# 3710  when a man dodges conviction after raping mult...
# 3711  sir hugo sir alan bates is more interested in ...
# 3712  framed for assassinating the grandmaster the l...
# 3713  a c.i.a. agent is used as a pawn in an insane ...
# 3714  the story of the year the oxford and cambridge...
# 3715  the loyalty of a tight group of friends is put...
# 3716  a bounty hunter arrives in a mining town and i...
# 3717  the story of president andrew jackson from his...
# 3718  beat takeshi a prominent actor meets a lookali...
# 3719  mak goes home from war and lives together with...
# 3720  a notorious gunfighter returns to his exwife w...
# 3721  for the 50th anniversary of the lake bodom mur...
# 3722  in the cutthroat london film industry a vivaci...
# 3723  whitney a spoiled preteen from philadelphia is...
# 3724  what is meant to be a weekend party across the...
# 3725  randy plumber sid south enjoys a profession wh...
# 3726  jeff and heather baker were life long sweethea...
# 3727  the movie chronicles the life of simran a youn...
# 3728  six people travel in a railroad sleeping car f...
# 3729  a beautiful blonde hooks up with a rock star a...
#
#                                          movie_synopsis  \
# 0     [The film starts at a girls school in Yucatan,...
# 1     [The opening credits appear in front of a larg...
# 2     [The prologue, spoken by Galadriel, shows the ...
# 3     [This movie is based on a true story of a Worl...
# 4     [Lord Voldemort, an evil and powerful dark wiz...
# 5     [Hocus Pocus begins in a small town in 1693, w...
# 6                  [\n                , \n            ]
# 7     [Texas sheriff Edgar McGraw pulls up to an iso...
# 8     [In 1858, Django (, ), a slave, is chained to ...
# 9     [The opening scene takes us into the gym of Br...
# 10    [The film starts with agents Alice Kerr (Laure...
# 11    [Three scientists, Jane Foster (, ), Erik Selv...
# 12    [In 2233, the USS Kelvin, a Federation starshi...
# 13    [Lester Burnham (Kevin Spacey) is a 42-year-ol...
# 14    [Philip Colbert, a wealthy man from Chicago wh...
# 15    [The film opens on the Turkish Railway, 400 mi...
# 16    [A young man named Wesley Gibson (James McAvoy...
# 17    [In 1933, during the Great Depression, vaudevi...
# 18    [The story takes place in the fertile, eastern...
# 19    [Katniss Everdeen (, ), victor of the 74th and...
# 20    [The film opens in ash-filled woods. A corpse ...
# 21    [Young Saraya Bevis and her brother Zak are fi...
# 22    [Millions of years before the Earth was formed...
# 23    [George Nada (Roddy Piper) is a homeless labor...
# 24    [French Morocco, 1940, Max Vatan (Brad Pitt) p...
# 25    [Clyde Shelton (Gerard Butler), a Philadelphia...
# 26    [The film opens with Jericho Stewart (Kevin Co...
# 27    [A whitewater rafting trip is underway, with t...
# 28                 [\n                , \n            ]
# 29    [After defeating Sentinel Prime and Megatron's...
# ...                                                 ...
# 3700  [Titles and credits run over a vista of the de...
# 3701  [In this third 'Lone Wolf and Cub' movie, Ogam...
# 3702               [\n                , \n            ]
# 3703               [\n                , \n            ]
# 3704               [\n                , \n            ]
# 3705               [\n                , \n            ]
# 3706               [\n                , \n            ]
# 3707               [\n                , \n            ]
# 3708               [\n                , \n            ]
# 3709               [\n                , \n            ]
# 3710               [\n                , \n            ]
# 3711               [\n                , \n            ]
# 3712               [\n                , \n            ]
# 3713               [\n                , \n            ]
# 3714               [\n                , \n            ]
# 3715               [\n                , \n            ]
# 3716  [Bounty hunter Blade and his prisoner Burt Cra...
# 3717               [\n                , \n            ]
# 3718               [\n                , \n            ]
# 3719               [\n                , \n            ]
# 3720               [\n                , \n            ]
# 3721               [\n                , \n            ]
# 3722               [\n                , \n            ]
# 3723               [\n                , \n            ]
# 3724  [Andrew and Melissa are a young couple coping ...
# 3725               [\n                , \n            ]
# 3726               [\n                , \n            ]
# 3727  [The story starts with a character name Simran...
# 3728               [\n                , \n            ]
# 3729               [\n                , \n            ]
#
#                                           movie_tagline
# 0                                      the next chapter
# 1                          its alien the 8th passenger.
# 2     all we have to decide is what to do with the t...
# 3                                   nobody runs forever
# 4                       the magic begins november 16th.
# 5                       its just a bunch of hocus pocus
# 6     you know his name. you know the story. on frid...
# 7                              vampires. no interviews.
# 8                     the d is silent. payback wont be.
# 9                       what do you allow to define you
# 10                  90 minutes. 22 miles. zero back up.
# 11                                two worlds. one hero.
# 12                                   the future begins.
# 13                                      ... look closer
# 14    theyre going to pin something on that smart co...
# 15                             dont go to war with him.
# 16                 their world. her rules. his destiny.
# 17                      the eighth wonder of the world.
# 18                                             for love
# 19                  fire burns brighter in the darkness
# 20                                    religion is power
# 21                  based on the incredible true story.
# 22    in brightest day in blackest night no evil sha...
# 23    i have come here to chew bubblegum and kick as...
# 24                              nothing is as it seems.
# 25                                  justice at any cost
# 26      the cias last hope is in the mind of a criminal
# 27            afraid of the dark you will be july 2005.
# 28    banned in australia for 17 yearsnow for the fi...
# 29                               the rules have changed
# ...                                                 ...
# 3700         it will steal your body and damn your soul
# 3701  the samurai ... in his hands flashing steel be...
# 3702        if you want history you gotta make your own
# 3703              what a spot for bob original print ad
# 3704          one bullet can kill a townjust like a man
# 3705               meet the weirdest hacker of dilli...
# 3706  a monster from another age ... with terrifying...
# 3707  a real western its really the best...because i...
# 3708                               love makes life live
# 3709  you werent the first ... and you wont be the last
# 3710                   they fought for final justice...
# 3711  beneath the surface of respectability lies the...
# 3712                devastation. mutation. termination.
# 3713         even doctor no would say yes to madame sin
# 3714                        to be second is to be last.
# 3715          whats a dirty little secret among friends
# 3716       sharp shoots gun and axe with great accuracy
# 3717                         they branded her adultress
# 3718                           500 kitanonothing to add
# 3719                           death do never us a part
# 3720  calling frank morgan a gunfighter is like call...
# 3721  hungarys first feature length found footage ho...
# 3722   shes hollywoods next big thing... hes hollywood.
# 3723                     life unfolds wherever you are.
# 3724  crossing the border was easy. getting home was...
# 3725            hes always on call for this sort of job
# 3726                         first love. second chance.
# 3727  the pastthe past movie 2018the past hindi horr...
# 3728  suddenly a scream pierces the air...and youre ...
# 3729  she was curious. she was eager. she couldnt fi...
#
# [3730 rows x 8 columns]

# %%
#summary 문장 수가 너무 많을 경우 summarize를 통해 압축
# for idx, summary in enumerate(df['movie_summary']):
#     x = summary.split('. ')
#     #print(x)
#     if len(x) <= 2:
#         df['movie_summary'][idx] = summary
#     else:
#         df['movie_summary'][idx] = summarize(summary, word_count=50,ratio = 0.3)


index = df[df['movie_summary']==''].index
df.drop(index, inplace=True)
df = df.reset_index()
df.drop(df.index[-712:], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-9a674236c098> in <module>
#      11 index = df[df['movie_summary']==''].index
#      12 df.drop(index, inplace=True)
# ---> 13 df = df.reset_index()
#      14 df.drop(df.index[-712:], inplace = True)
#      15
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
tl = list(df["movie_tagline"])
tl = ["".join([ j for j in i if j != "\n"]).strip() for i in tl]

summ = list(df['movie_summary'])

df.movie_tagline = tl
df.movie_summary = summ

sources = [i.split() for i in df['movie_summary']]
targets = [i.split() for i in df['movie_tagline']]

# %% [markdown]
# # 단어 나누기

# %%
sources, targets = processed_df(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-a1e6d83640c3> in <module>
#       1
# ----> 2 sources, targets = processed_df(df1)
#
# NameError: name 'processed_df' is not defined

# %%
# vocabulary for sources
s_vocab = list(set(sum(sources, [])))
s_vocab.sort()
s_vocab = ['<pad>'] + s_vocab
source2idx = {word : idx for idx, word in enumerate(s_vocab)}
idx2source = {idx : word for idx, word in enumerate(s_vocab)}

# %%
# vocabulary for targets
t_vocab = list(set(sum(targets, [])))
t_vocab.sort()
t_vocab = ['<pad>', '<bos>', '<eos>'] + t_vocab
target2idx = {word : idx for idx, word in enumerate(t_vocab)}
idx2target = {idx : word for idx, word in enumerate(t_vocab)}

# %%
def preprocess(sequences, max_len, dic, mode = 'source'):
    assert mode in ['source', 'target'], 'source와 target 중에 선택해주세요.'
    
    if mode == 'source':
        # preprocessing for source (encoder)
        s_input = list(map(lambda sentence : [dic.get(token) for token in sentence], sequences))
        
        #s_input = [[x for x in each_input if x] for each_input in s_input]
        #pprint(s_input)
        s_len = list(map(lambda sentence : len(sentence), s_input))
        s_input = pad_sequences(sequences = s_input, maxlen = max_len, padding = 'post', truncating = 'post')
        return s_len, s_input
    

    elif mode == 'target':
        # preprocessing for target (decoder)
        # input
        t_input = list(map(lambda sentence : ['<bos>'] + sentence + ['<eos>'], sequences))
        
        #t_input = [[x for x in each_input if x] for each_input in t_input]
        #pprint(t_input)
        t_input = list(map(lambda sentence : [dic.get(token) for token in sentence], t_input))
        t_len = list(map(lambda sentence : len(sentence), t_input))
        t_input = pad_sequences(sequences = t_input, maxlen = max_len, padding = 'post', truncating = 'post')
     
        # output
        t_output = list(map(lambda sentence : sentence + ['<eos>'], sequences))
        t_output = list(map(lambda sentence : [dic.get(token) for token in sentence], t_output))
        t_output = pad_sequences(sequences = t_output, maxlen = max_len, padding = 'post', truncating = 'post')
        
        return t_len, t_input, t_output

# %%
# preprocessing for source
s_max_len = 10
s_len, s_input = preprocess(sequences = sources,
                            max_len = s_max_len, dic = source2idx, mode = 'source')
#print(s_len, s_input)

# %%
# preprocessing for target
t_max_len = 12
t_len, t_input, t_output = preprocess(sequences = targets,
                                      max_len = t_max_len, dic = target2idx, mode = 'target')
print(t_len, t_input, t_output)
# Out:
# [5, 7, 18, 5, 7, 9, 17, 5, 9, 9, 9, 6, 5, 5, 25, 8, 8, 8, 4, 8, 5, 8, 26, 17, 7, 6, 13, 11, 47, 6, 12, 13, 6, 10, 15, 8, 6, 17, 9, 9, 75, 35, 12, 8, 4, 10, 12, 8, 13, 8, 4, 12, 22, 4, 7, 6, 4, 10, 5, 23, 8, 8, 5, 7, 10, 10, 7, 12, 7, 5, 7, 6, 23, 7, 6, 5, 12, 6, 10, 14, 19, 4, 12, 7, 6, 15, 8, 8, 6, 9, 37, 15, 6, 5, 13, 8, 11, 7, 13, 10, 7, 5, 9, 6, 7, 9, 6, 16, 10, 14, 9, 10, 16, 11, 8, 6, 10, 6, 8, 8, 21, 11, 10, 23, 6, 6, 5, 13, 10, 6, 10, 12, 5, 7, 8, 5, 7, 5, 12, 8, 9, 10, 8, 8, 6, 4, 9, 4, 6, 11, 5, 14, 11, 5, 11, 12, 13, 6, 7, 29, 10, 8, 13, 10, 10, 7, 7, 5, 11, 10, 6, 7, 26, 7, 9, 7, 8, 8, 9, 11, 6, 7, 11, 6, 8, 6, 14, 5, 9, 16, 11, 18, 6, 45, 9, 5, 8, 7, 9, 23, 9, 9, 13, 16, 8, 9, 9, 17, 4, 7, 10, 14, 5, 6, 7, 12, 8, 9, 5, 17, 5, 14, 26, 10, 11, 5, 8, 8, 6, 11, 7, 7, 13, 6, 13, 15, 6, 7, 26, 9, 12, 10, 12, 16, 9, 8, 11, 11, 6, 15, 7, 8, 12, 8, 5, 10, 8, 11, 10, 9, 9, 6, 9, 16, 10, 8, 6, 16, 12, 10, 6, 12, 8, 9, 6, 8, 20, 15, 14, 9, 7, 19, 12, 9, 6, 6, 14, 8, 13, 10, 11, 9, 15, 11, 18, 11, 15, 6, 10, 13, 18, 13, 8, 6, 10, 9, 8, 9, 6, 14, 11, 20, 9, 10, 3, 6, 9, 8, 10, 14, 5, 28, 10, 18, 7, 25, 10, 13, 9, 10, 9, 13, 11, 16, 7, 19, 8, 7, 10, 10, 17, 7, 10, 6, 8, 32, 7, 20, 11, 8, 14, 17, 5, 5, 8, 5, 5, 16, 5, 6, 7, 16, 10, 9, 5, 15, 9, 15, 6, 6, 20, 5, 10, 6, 5, 9, 5, 4, 6, 9, 9, 10, 4, 13, 7, 11, 26, 7, 6, 13, 9, 10, 6, 8, 6, 12, 8, 8, 8, 9, 7, 7, 27, 7, 7, 11, 11, 10, 16, 16, 9, 6, 9, 9, 9, 7, 7, 11, 7, 21, 23, 9, 16, 8, 8, 10, 8, 7, 13, 3, 11, 10, 11, 13, 4, 8, 12, 18, 10, 12, 8, 28, 10, 11, 7, 11, 6, 9, 7, 19, 10, 7, 6, 10, 18, 7, 13, 6, 7, 16, 14, 13, 20, 4, 5, 11, 6, 7, 12, 9, 9, 7, 7, 4, 8, 9, 7, 12, 12, 10, 8, 5, 15, 11, 4, 10, 13, 13, 14, 6, 16, 8, 7, 6, 5, 6, 10, 9, 5, 6, 19, 9, 13, 7, 10, 5, 13, 26, 12, 10, 4, 6, 7, 7, 13, 6, 8, 5, 21, 8, 7, 6, 8, 16, 6, 8, 16, 9, 21, 25, 20, 6, 9, 5, 14, 21, 20, 19, 16, 14, 10, 9, 14, 7, 10, 6, 13, 4, 32, 7, 5, 10, 9, 7, 13, 46, 8, 6, 6, 8, 8, 9, 9, 6, 7, 12, 11, 10, 16, 21, 6, 18, 11, 13, 6, 13, 10, 13, 6, 9, 13, 14, 11, 7, 12, 8, 4, 15, 12, 7, 10, 9, 13, 9, 10, 9, 7, 11, 19, 18, 6, 12, 12, 6, 10, 10, 10, 5, 9, 7, 6, 13, 12, 7, 9, 12, 7, 7, 7, 9, 6, 6, 11, 6, 9, 9, 14, 6, 13, 7, 9, 7, 10, 12, 16, 22, 9, 16, 9, 6, 13, 15, 10, 7, 7, 8, 9, 7, 6, 12, 5, 7, 8, 9, 9, 8, 9, 7, 13, 13, 23, 10, 5, 5, 16, 10, 13, 12, 12, 9, 22, 6, 8, 5, 9, 4, 17, 4, 13, 9, 10, 9, 12, 6, 9, 10, 13, 8, 9, 6, 10, 6, 9, 11, 13, 18, 8, 12, 6, 7, 24, 8, 7, 7, 12, 6, 13, 6, 14, 11, 10, 4, 13, 6, 7, 10, 7, 7, 10, 16, 5, 15, 10, 5, 7, 11, 7, 8, 19, 11, 5, 8, 5, 5, 6, 21, 16, 11, 10, 6, 13, 9, 15, 6, 11, 13, 10, 11, 16, 13, 14, 9, 20, 12, 21, 7, 10, 13, 11, 5, 7, 5, 13, 6, 18, 10, 13, 13, 5, 7, 13, 9, 12, 13, 8, 10, 5, 5, 15, 28, 8, 10, 7, 10, 9, 9, 9, 6, 10, 9, 15, 7, 6, 13, 17, 7, 18, 4, 9, 28, 9, 19, 10, 10, 7, 12, 12, 9, 9, 8, 5, 15, 19, 6, 8, 9, 25, 7, 16, 8, 12, 116, 11, 5, 8, 22, 12, 7, 8, 30, 12, 5, 5, 6, 9, 5, 8, 21, 9, 9, 7, 9, 11, 18, 12, 37, 6, 5, 8, 8, 12, 8, 19, 10, 22, 19, 6, 22, 9, 23, 8, 8, 7, 17, 11, 10, 17, 12, 6, 14, 19, 14, 14, 5, 9, 14, 10, 16, 6, 9, 10, 6, 13, 7, 13, 11, 13, 6, 6, 9, 99, 12, 10, 13, 13, 16, 8, 17, 11, 10, 5, 11, 12, 7, 9, 8, 10, 19, 10, 18, 7, 13, 35, 10, 14, 10, 5, 6, 14, 7, 10, 6, 8, 5, 8, 13, 6, 12, 12, 10, 6, 11, 10, 12, 4, 6, 16, 10, 12, 7, 9, 16, 12, 11, 14, 6, 5, 8, 8, 12, 11, 17, 8, 10, 6, 7, 6, 8, 16, 5, 6, 8, 25, 7, 6, 9, 14, 11, 20, 15, 10, 18, 16, 7, 10, 8, 8, 9, 11, 6, 19, 16, 6, 13, 6, 7, 9, 10, 9, 7, 7, 13, 13, 17, 9, 16, 17, 9, 11, 13, 16, 22, 9, 10, 12, 7, 7, 8, 6, 8, 28, 5, 10, 5, 8, 4, 9, 21, 16, 19, 6, 8, 7, 8, 14, 10, 12, 6, 9, 11, 15, 10, 19, 12, 7, 6, 5, 26, 9, 14, 4, 5, 8, 5, 13, 12, 10, 7, 14, 12, 8, 7, 7, 21, 7, 9, 14, 6, 16, 8, 19, 10, 8, 12, 6, 10, 7, 16, 14, 11, 7, 8, 16, 13, 7, 7, 8, 13, 13, 8, 8, 8, 19, 36, 13, 10, 10, 6, 8, 6, 9, 8, 11, 12, 10, 9, 12, 6, 8, 9, 7, 5, 5, 9, 12, 8, 28, 14, 12, 10, 14, 5, 13, 9, 5, 5, 20, 13, 10, 10, 9, 4, 8, 15, 10, 15, 63, 11, 8, 17, 10, 9, 12, 6, 5, 18, 5, 5, 9, 26, 11, 11, 7, 14, 13, 9, 7, 7, 7, 7, 3, 5, 6, ...
#  [   1 3711  369 ...    0    0    0]
#  [   1  378 7576 ... 2033 7722 6875]
#  ...
#  [   1    5  587 ... 6875 7568 7010]
#  [   1 6875 4880 ...    0    0    0]
#  [   1 4959 2617 ...    0    0    0]] [[6875 4799 1275 ...    0    0    0]
#  [3711  369 6875 ...    0    0    0]
#  [ 378 7576 3209 ... 7722 6875 6987]
#  ...
#  [   5  587 1885 ... 7568 7010 3165]
#  [6875 4880 4440 ...    0    0    0]
#  [4959 2617 6871 ...    0    0    0]]

# %% [markdown]
# # hyper-param

# %%
# hyper-parameters
epochs = 100
batch_size = 4
learning_rate = .005
total_step = epochs / batch_size
buffer_size = 100
n_batch = buffer_size//batch_size
embedding_dim = 32
units = 32

# input
data = tf.data.Dataset.from_tensor_slices((s_len, s_input, t_len, t_input, t_output))
data = data.shuffle(buffer_size = buffer_size)
data = data.batch(batch_size = batch_size)
# s_mb_len, s_mb_input, t_mb_len, t_mb_input, t_mb_output = iterator.get_next()

# %%
def gru(units):
  # If you have a GPU, we recommend using CuDNNGRU(provides a 3x speedup than GRU)
  # the code automatically does that.
    if tf.test.is_gpu_available():
        return tf.keras.layers.CuDNNGRU(units, 
                                        return_sequences=True, 
                                        return_state=True, 
                                        recurrent_initializer='glorot_uniform')
    else:
        return tf.keras.layers.GRU(units, 
                                   return_sequences=True, 
                                   return_state=True, 
                                   recurrent_activation='sigmoid', 
                                   recurrent_initializer='glorot_uniform')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.enc_units)
        
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        return output, state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.dec_units)
        self.fc = tf.keras.layers.Dense(vocab_size)
                
    def call(self, x, hidden, enc_output):
        
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size * 1, vocab)
        x = self.fc(output)
        
        return x, state
        
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.dec_units))

# %%
encoder = Encoder(len(source2idx), embedding_dim, units, batch_size)
decoder = Decoder(len(target2idx), embedding_dim, units, batch_size)

def loss_function(real, pred):
    mask = 1 - np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
    
#     print("real: {}".format(real))
#     print("pred: {}".format(pred))
#     print("mask: {}".format(mask))
#     print("loss: {}".format(tf.reduce_mean(loss_)))
    
    return tf.reduce_mean(loss_)

# creating optimizer
optimizer = tf.train.AdamOptimizer()

# creating check point (Object-based saving)
checkpoint_dir = './data_out/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                encoder=encoder,
                                decoder=decoder)
print(checkpoint_prefix)
# create writer for tensorboard
summary_writer = tf.contrib.summary.create_file_writer(logdir=checkpoint_dir)
print(summary_writer)
# Out:
# ./data_out/training_checkpoints\ckpt
# <tensorflow.python.ops.summary_ops_v2.ResourceSummaryWriter object at 0x0000000013F53048>

# %%
EPOCHS = 1

for epoch in range(EPOCHS):
    
    hidden = encoder.initialize_hidden_state()
    #print(hidden.shape)
    total_loss = 0
    for i, (s_len, s_input, t_len, t_input, t_output) in enumerate(data):
        loss = 0
        #print(s_input, s_input.shape)
        with tf.GradientTape() as tape:
            enc_output, enc_hidden = encoder(s_input, hidden)

            dec_hidden = enc_hidden
            
            dec_input = tf.expand_dims([target2idx['<bos>']] * batch_size, 1)
            
            #Teacher Forcing: feeding the target as the next input
            for t in range(1, t_input.shape[1]):
                
                predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
                
                loss += loss_function(t_input[:, t], predictions)
            
                dec_input = tf.expand_dims(t_input[:, t], 1) #using teacher forcing
                
        batch_loss = (loss / int(t_input.shape[1]))
        
        total_loss += batch_loss
        
        variables = encoder.variables + decoder.variables
        
        gradient = tape.gradient(loss, variables)
        
        optimizer.apply_gradients(zip(gradient, variables))


#     if epoch % 10 == 0:
#         #save model every 10 epoch
#         print('Epoch {} Loss {:.4f} Batch Loss {:.4f}'.format(epoch,
#                                             total_loss / n_batch,
#                                             batch_loss.numpy()))
#         optimizer.minimize(variables)
#         checkpoint.save(file_prefix = checkpoint_prefix)


#save model every 10 epoch
print('Epoch {} Loss {:.4f} Batch Loss {:.4f}'.format(epoch,
                                    total_loss / n_batch,
                                    batch_loss.numpy()))
optimizer.minimize(variables)
checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# Epoch 0 Loss 182.4760 Batch Loss 4.0433
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-85-9bf358abdb02> in <module>
#      49                                     total_loss / n_batch,
#      50                                     batch_loss.numpy()))
# ---> 51 optimizer.minimize(variables)
#      52 checkpoint.save(file_prefix = checkpoint_prefix)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\optimizer.py in minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     401         aggregation_method=aggregation_method,
#     402         colocate_gradients_with_ops=colocate_gradients_with_ops,
# --> 403         grad_loss=grad_loss)
#     404
#     405     vars_with_grad = [v for g, v in grads_and_vars if g is not None]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     479     if context.executing_eagerly():
#     480       raise RuntimeError(
# --> 481           "`loss` passed to Optimizer.compute_gradients should "
#     482           "be a function when eager execution is enabled.")
#     483
#
# RuntimeError: `loss` passed to Optimizer.compute_gradients should be a function when eager execution is enabled.

# %%
# #최근 학습된 모델을 불러오고 이어서 EPOCHS로 돌아감
# saver = tf.train.Saver()
# with tf.Session() as sess:
    
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
#sentence = 'I feel hungry'
sentence = 'donghoon is teens minsu eat bingsoo'
print(sentence)
print(df.movie_name[7])
print(df.movie_tagline[7])
#sentence = 'desperado'
#checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# donghoon is teens minsu eat bingsoo
# From Dusk Till Dawn
# vampires. no interviews.

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(i)
            
    print(inputs)
    #inputs = [inp_lang[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
        
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
        
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
   
    for t in range(max_length_targ):
        

        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += idx2target[predicted_id] + ' '
        
        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)    
            
    return result, sentence
    
result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)

print(sentence)
print(result)
# Out:
# ['is', 'teens', 'eat']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-582-72e0aa8406b4> in <module>
#      38     return result, sentence
#      39
# ---> 40 result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
#      41
#      42 print(sentence)
#
# <ipython-input-582-72e0aa8406b4> in prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ)
#      10     print(inputs)
#      11     #inputs = [inp_lang[i] for i in sentence.split(' ')]
# ---> 12     inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
#      13     inputs = tf.convert_to_tensor(inputs)
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras_preprocessing\sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      94
#      95         # check `trunc` has expected shape
# ---> 96         trunc = np.asarray(trunc, dtype=dtype)
#      97         if trunc.shape[1:] != sample_shape:
#      98             raise ValueError('Shape of sample %s of sequence at position %s '
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: invalid literal for int() with base 10: 'is'

# %%
#len(df.movie_summary[39].split('. '))

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    
    inputs = [inp_lang[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
    print(inputs)
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
    idx = 0
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    #print(dec_input)
    xList = []
    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        #print("*"*100)
        #print(predictions)
        #print("*"*100)
        #print(tf.argmax(predictions[0]))
        print(predictions)
        x = tf.nn.top_k(predictions[0], k=3, sorted=True, name=None)
        for i in range(3):
            predicted_id = x[1][i].numpy()
            #print(predicted_id)

            result += idx2target[predicted_id] + ' '
            #print("result:", result)
            #print(idx2target[predicted_id])
            #if idx2target.get(predicted_id) == '<eos>':
            #             return result, sentence

          #result=""

        # the predicted ID is fed back into the model
            dec_input = tf.expand_dims([predicted_id], 0)  
        xList.append([result])
        result = ''
        
    return xList

# result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
tList=prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
# print(sentence)
from pprint import pprint
pprint(tList)
# Out:
# tf.Tensor([[ 9287 41231  2931 37745  3580   680 14226 39757 37864 17115]], shape=(1, 10), dtype=int32)
# tf.Tensor(
# [[ 9.4020230e-05  1.6653375e-03  5.9435581e-05 ...  7.5239193e-05
#   -5.9340463e-04  4.3913058e-04]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[ 2.3767170e-06  3.6741138e-04  1.1428281e-03 ...  6.2416471e-04
#   -1.3262214e-03  1.6500485e-03]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[ 0.00011707  0.00041446 -0.00140442 ... -0.00071536 -0.00150845
#    0.00089381]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-8.0903753e-04  1.2703988e-03 -3.2420724e-04 ... -9.9565950e-04
#    5.0295421e-05 -6.8175787e-04]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-1.8458246e-04  1.8385120e-03 -1.8158337e-04 ... -8.3507708e-04
#   -6.6731489e-05  4.4791863e-04]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-0.00167988  0.00135579  0.00150765 ...  0.00170083  0.00119689
#    0.00111826]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-0.00103964 -0.00076731  0.00131002 ...  0.0004116  -0.00093449
#    0.00146894]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-0.00092425  0.00019543 -0.00054506 ...  0.00025707 -0.000208
#    0.00161421]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-0.0018978   0.00176671  0.00088002 ... -0.00027791 -0.00014475
#   -0.000185  ]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-1.7797775e-03 -2.3530038e-04  5.7919323e-04 ...  3.0137046e-04
#   -5.1015092e-04 -6.8093148e-05]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-0.00060455 -0.00068901  0.00021484 ...  0.00081777  0.00132637
#   -0.00073004]], shape=(1, 7871), dtype=float32)
# tf.Tensor(
# [[-1.3772422e-03 -8.8524423e-05  1.7755594e-03 ...  5.3336995e-04
#   -9.5369574e-04 -8.2297891e-04]], shape=(1, 7871), dtype=float32)
# [['inherit hitchcock pity '],
#  ['desired hitchcock extinct. '],
#  ['got... allting extracting '],
#  ['perhaps cons....eddies bitter '],
#  ['oharas pounds submit '],
#  ['friend returned use '],
#  ['chandler fleeting... suddenly '],
#  ['idiots excon. picture '],
#  ['dax itll for. '],
#  ['hippie in. terrifying '],
#  ['as... before beckons '],
#  ['brains. brown eyes ']]
