# %% [markdown]
# # Lab 12-5 sequence to sequence (Keras + eager version)
#
# ### simple neural machine translation training
#
# * sequence to sequence
#
# ### Reference
# * [Sequence to Sequence Learning with Neural Networks](https://arxiv.org/abs/1409.3215)

# %%
pip install tensorflow==1.15
# Out:
# Requirement already satisfied: tensorflow==1.15 in c:\programdata\anaconda3\lib\site-packages (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: gast==0.2.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.24.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.11.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.33.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.16.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.1.7)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.9.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (0.14.1)
# Collecting setuptools>=41.0.0 (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15)
#   Downloading https://files.pythonhosted.org/packages/6a/9a/50fadfd53ec909e4399b67c74cc7f4e883488035cfcdb90b685758fa8b34/setuptools-41.4.0-py2.py3-none-any.whl (580kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.1)
# Installing collected packages: setuptools
#   Found existing installation: setuptools 40.8.0
#     Uninstalling setuptools-40.8.0:
#       Successfully uninstalled setuptools-40.8.0
# Successfully installed setuptools-41.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import absolute_import, division, print_function

# Import TensorFlow >= 1.10 and enable eager execution
import tensorflow as tf
print(tf.__version__)
tf.enable_eager_execution()

from matplotlib import font_manager, rc

rc('font', family='AppleGothic') #for mac

import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

from pprint import pprint
import numpy as np
import os
import pandas as pd
import re
#요약
from gensim.summarization.summarizer import summarize
# Out:
# 1.15.0

# %%
#path = '/content/drive/My Drive/Colab Notebooks/moviedata2.json'
df = pd.read_json('moviedata_preprocessed.json')

# %% [markdown]
# # 전처리

# %%
#df = movie_dataframe

df.movie_name = df.movie_name.apply(lambda x: x.replace('혻',''))

df.movie_summary = df.movie_summary.apply(lambda x: str(x).lower())
df.movie_summary = df.movie_summary.apply(lambda x: re.sub("[^A-Za-z. 0-9]", '', x))
df.movie_summary = df.movie_summary.apply(lambda x: x.replace('\\n',''))

#df.movie_synopsis = df.movie_synopsis.apply(lambda x : str(x).lower())
#df.movie_synopsis = df.movie_synopsis.apply(lambda x : re.sub('[^A-Za-z. ]', '', x))

df.movie_tagline = df.movie_tagline.apply(lambda x: str(x).lower())
df.movie_tagline = df.movie_tagline.apply(lambda x: x.replace('\\n','').replace('\\xa0',''))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub('[^A-Za-z. 0-9]', '', x))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub(' {2,}', '', x))

#태그라인 없는 데이터 row 삭제
index = df[df['movie_tagline']==''].index
df.drop(index, inplace = True)

#summary 없는 데이터 row 삭제
summary_index = df[df['movie_summary']==''].index
df.drop(summary_index, inplace = True)

index = df[df['movie_summary'].str.contains('  ')].index
df.drop(index , inplace = True)

# %%
df= df.reset_index()

# %%
df
# Out:
#       level_0  index                                  movie_genre  \
# 0           0      0         [Adventure, Drama, Horror, Thriller]
# 1           1      2                             [Horror, Sci-Fi]
# 2          10   3690                       [Drama, Thriller, War]
# 3         100   3848                              [Comedy, Crime]
# 4        1000   5628                            [Drama, Thriller]
# 5        1001   1871          [Biography, Crime, Drama, Thriller]
# 6        1002   2168                            [Comedy, Romance]
# 7        1003   5631                                     [Comedy]
# 8        1004   5638                               [War, Western]
# 9        1005    507        [Action, Adventure, Sci-Fi, Thriller]
# 10       1006   5640                            [Family, Fantasy]
# 11       1007   5641                      [Comedy, Drama, Sci-Fi]
# 12       1008   5642  [Adventure, Biography, Drama, History, War]
# 13       1009   5646                      [Action, Horror, Drama]
# 14        101   3849            [Action, Drama, Horror, Thriller]
# 15       1010   5647                            [Comedy, Mystery]
# 16       1011   5648                    [Comedy, Crime, Thriller]
# 17       1012   5650                            [Drama, Thriller]
# 18       1013    244                            [Comedy, Romance]
# 19       1014   5651                            [Comedy, Romance]
# 20       1015   5654    [Action, Drama, Horror, Sci-Fi, Thriller]
# 21       1016   5658                             [Drama, Romance]
# 22       1017    508                     [Comedy, Drama, Romance]
# 23       1018   5660                           [Adventure, Drama]
# 24       1019   5661                     [Drama, Romance, Sci-Fi]
# 25        102   2028                             [Action, Comedy]
# 26       1020   5662                           [Comedy, Thriller]
# 27       1021   5663  [Animation, Action, Crime, Drama, Thriller]
# 28       1022   5665                     [Thriller, Crime, Drama]
# 29       1023   5675                            [Comedy, Fantasy]
# ...       ...    ...                                          ...
# 8606      972   5558                             [Drama, Romance]
# 8607      973   5564                           [Horror, Thriller]
# 8608      974   5565                    [Action, Crime, Thriller]
# 8609      975   5570                             [Drama, Romance]
# 8610      976   5573                             [Sci-Fi, Horror]
# 8611      977   5579                                     [Comedy]
# 8612      978    505    [Action, Crime, Drama, Romance, Thriller]
# 8613      979   2165                         [Action, Drama, War]
# 8614       98   3844            [Action, Drama, Musical, Romance]
# 8615      980   5584             [Action, Crime, Drama, Thriller]
# 8616      981   5586                                     [Sci-Fi]
# 8617      982   5589                      [Drama, History, Music]
# 8618      983   5591                                      [Drama]
# 8619      984   5592   [Crime, Drama, Fantasy, Mystery, Thriller]
# 8620      985   5593                                      [Drama]
# 8621      986   5598                   [Comedy, Musical, Romance]
# 8622      987   5599                                     [Comedy]
# 8623      988   5600                   [Crime, Thriller, Western]
# 8624      989   5601         [Biography, Drama, Musical, Romance]
# 8625       99   3845                                     [Horror]
# 8626      990   2166                             [Action, Comedy]
# 8627      991     57                [Adventure, Horror, Thriller]
# 8628      992    506                            [Comedy, Fantasy]
# 8629      993   5602                     [Action, Horror, Sci-Fi]
# 8630      994   5606                          [Animation, Family]
# 8631      995   5607                                     [Comedy]
# 8632      996   5608          [Crime, Drama, Film-Noir, Thriller]
# 8633      997   5614                            [Drama, Thriller]
# 8634      998   5617  [Adventure, Comedy, Family, Music, Romance]
# 8635      999   5627                             [Drama, Romance]
#
#                               movie_name  \
# 0                47 Meters Down: Uncaged
# 1                                  Alien
# 2                        Innocent Voices
# 3     Torrente, el brazo tonto de la ley
# 4                        Geu nom moksori
# 5             The Falcon and the Snowman
# 11    everything returns to normal after chernobyl. ...
# 12    an entire nations destiny lies in the hands of...
# 13    the satans are a very cruel biker gang led by ...
# 14    in a small tennessee town an historian relates...
# 15    a beautiful novelist gets involved with the vi...
# 16    a crossdressing mental patient escapes from an...
# 17    a security guard falls for a famous tv actress...
# 18    a high school senior drives crosscountry with ...
# 19    two obnoxious and dimwitted misfits attempt to...
# 20    a freak accident turns a bulk of the worlds po...
# 21    in 1945 during a 48hour leave a soldier accide...
# 22    during a hometown memorial for his kentuckybor...
# 23    a husband wife and their son are stranded on a...
# 24    a miner trapped in a cavein resurfaces and upo...
# 25    the bandit goes on another crosscountry run tr...
# 26    after spending seven years behind bars johnny ...
# 27    after killing the son of a powerful oil tycoon...
# 28    a police detective tracks a serial killer who ...
# 29    george burns returns as god and as satan. they...
# ...                                                 ...
# 8606  on a fishing boat at sea a 60year old man has ...
# 8607  three friends head to the seafront for a drunk...
# 8608  a special agents plans to reconcile with his e...
# 8609  two lonely retired septuagenarians an unkempt ...
# 8610  lonely deranged puppetmaster designs a machine...
# 8611  young pretty and innocent fanny hill has lost ...
# 8612  a retired us navy pilot comes to mexico where ...
# 8613  in world war iiera korea rival runners one kor...
# 8614  shah rukh khan and sharad kapoor are the leade...
# 8615  a miami social worker scott helps a fatherless...
# 8616  a trio of scientists plan to create a selfrepl...
# 8617  the story of alan freed the pioneering disc jo...
# 8618  the disappearance of a 3yearold boy divides a ...
# 8619  a man with the ability to visit the past by lo...
# 8620  a former drug addict gets a new lease of life ...
# 8621  an offbeat comedy about a former 80s pop star ...
# 8622  the boys buy a uranium mine out west but when ...
# 8623  a disgraced paleontologist struggling to raise...
# 8624  george gershwin is a driven composer whose nee...
# 8625  a woman who may be a witch defends her husband...
# 8626  hollywood aging stuntman sonny hooper wants to...
# 8627  a caving expedition goes horribly wrong as the...
# 8628  after two of the devils three sons escape hell...
# 8629  a team of scientists go to a nuclear mining fa...
# 8630  about a young girl who finds a pear of pink ba...
# 8631  bumbling high school geek virgil heitmeyer has...
# 8632  highclass crook gets in trouble with the law. ...
# 8633  kay stanton her husband neil and son tommy liv...
# 8634  two carefree castaways on a desert shore find ...
# 8635  spanish actor jose antonio ceinos stars as a d...
#
#                                          movie_synopsis  \
# 0     [The film starts at a girls school in Yucatan,...
# 1     [The opening credits appear in front of a larg...
# 2                  [\n                , \n            ]
# 3                  [\n                , \n            ]
# 4     [Han Kyung Bae (Sol Kyung Gu) is a successful ...
# 5     [Christopher Boyce (Timothy Hutton), a young s...
# 6                  [\n                , \n            ]
# 7                  [\n                , \n            ]
# 8                  [\n                , \n            ]
# 9     [Note: this entire, experimental film takes pl...
# 10                 [\n                , \n            ]
# 11    [Centering around the word No Thing . Jean Luc...
# 12                 [\n                , \n            ]
# 13                 [\n                , \n            ]
# 14                 [\n                , \n            ]
# 15                 [\n                , \n            ]
# 16                 [\n                , \n            ]
# 17                 [\n                , \n            ]
# 18    [Ian Lafferty (Josh Zuckerman) is an 18-year-o...
# 19    [Two dim-witted New York street peddlers, Jake...
# 20                 [\n                , \n            ]
# 21                 [\n                , \n            ]
# 22    [The film begins with a recall of Mercury Worl...
# 23                 [\n                , \n            ]
# 24                 [\n                , \n            ]
# 25    [Big Enos Burdett (Pat McCormick) is attemptin...
# 26                 [\n                , \n            ]
# 27                 [\n                , \n            ]
# 28                 [\n                , \n            ]
# 29    [In 1960 New York City, Arthur Shelton (John D...
# ...                                                 ...
# 8606               [\n                , \n            ]
# 8607               [\n                , \n            ]
# 8608               [\n                , \n            ]
# 8609               [\n                , \n            ]
# 8610  [Title and credits run over an image of people...
# 8611               [\n                , \n            ]
# 8612               [\n                , \n            ]
# 8613  [The year is 1928 in Gyeong-seong (modern-day ...
# 8614  [The film is set in a town called Vasco in Goa...
# 8615               [\n                , \n            ]
# 8616               [\n                , \n            ]
# 8617               [\n                , \n            ]
# 8618               [\n                , \n            ]
# 8619  [The movie starts with Jai Puri (Akshay Kumar)...
# 8620               [\n                , \n            ]
# 8621               [\n                , \n            ]
# 8622               [\n                , \n            ]
# 8623               [\n                , \n            ]
# 8624               [\n                , \n            ]
# 8625               [\n                , \n            ]
# 8626               [\n                , \n            ]
# 8627  [A whitewater rafting trip is underway, with t...
# 8628  [In this very unusual comedy, the devil meets ...
# 8629               [\n                , \n            ]
# 8630  [Dance your way to a magical adventure with Ba...
# 8631               [\n                , \n            ]
# 8632               [\n                , \n            ]
# 8633               [\n                , \n            ]
# 8634  [The film opens with a freighter at sea explod...
# 8635               [\n                , \n            ]
#
#                                           movie_tagline
# 0                                      the next chapter
# 1                          its alien the 8th passenger.
# 2     how much will a mother sacrifice for the love ...
# 3     when you thought that spanish cinema was impro...
# 4                 44 days of nerveracking phone threats
# 5                  the falconthe snowman. a true story.
# 6             this outrageous road trip really heats up
# 7                 comic relief for incurable romantics.
# 8     the gun... the girl... they made one man the e...
# 9     first they made him dangerous. then they made ...
# 10    its always an adventure when your best friend ...
# 11                          a picture shot in the back.
# 12      han svor hvn og fik et helt folk med sigdenmark
# 13                 hippie psychos on a mad murder spree
# 14    welcome to oldfield. stop in for a night of pu...
# 15    2 outrageous women are turning new york city u...
# 16         forget glen or glendais this billy or billie
# 17            the more he watched...the more he wanted.
# 18                         hes leaving virgin territory
# 19    the whoopee boys have a thing or two to show t...
# 20                        this town will eat you alive.
# 21    a story as gay as spring...exciting as love it...
# 22                     the best place to find yourself.
# 23                    no woman is an island... forever.
# 24    it will grip your imagination as no film has e...
# 25    its another race against time for burt sally a...
# 26               sometimes revenge is the best therapy.
# 27    spreading through the world like wildfire... t...
# 28    when it comes to murder it aint over till its ...
# 29        thats funny they both look like george burns.
# ...                                                 ...
# 8606  a girl who thought the sea was the whole world...
# 8607              the only way out is to let it inside.
# 8608              flying has never been so dangerous...
# 8609  ...and other lies your friends let you get awa...
# 8610        doll dwarfs versus the crushing giant beats
# 8611                   they said it could not be filmed
# 8612  theres only one passion more uncontrollable th...
# 8613        in a world at war my enemy is my salvation.
# 8614                                       full of life
# 8615  in the war on drugs... he was their secret weapon
# 8616                            the future is cancelled
# 8617  1959. new york city. the battleground was rock...
# 8618                one town. one life. one wrong turn.
# 8619                  this summer.... excitement begins
# 8620                                      a true story.
# 8621  olivia just met the perfect man for her mom......
# 8622  theyre huntin for the hot rocks in the uranium...
# 8623                some things are better left buried.
# 8624             the jubilant story of george gershwin.
# 8625  do the undead demons of hell still arise to te...
# 8626                        the greatest stuntman alive
# 8627          afraid of the dark you will be july 2005.
# 8628                      be unafraid.be very unafraid.
# 8629                              back for another bite
# 8630  listen to the beat of your heart and keep on d...
# 8631     its a dirty mind but somebodys got to have it.
# 8632  johnny was smart...too smart to tangle with wo...
# 8633  her loneliness... his hunger... so vulnerable....
# 8634  youll shriek at these shieks . . . trying the ...
# 8635  model of sensuality object of desire target of...
#
# [8636 rows x 8 columns]

# %%
tl = list(df["movie_tagline"])
tl = ["".join([ j for j in i if j != "\n"]).strip() for i in tl]

summ = list(df['movie_summary'])

df.movie_tagline = tl
df.movie_summary = summ

sources = [i.split() for i in df['movie_summary']]
targets = [i.split() for i in df['movie_tagline']]

# %%
df.tail()
# Out:
#       level_0  index                                  movie_genre  \
# 8631      995   5607                                     [Comedy]
# 8632      996   5608          [Crime, Drama, Film-Noir, Thriller]
# 8633      997   5614                            [Drama, Thriller]
# 8634      998   5617  [Adventure, Comedy, Family, Music, Romance]
# 8635      999   5627                             [Drama, Romance]
#
#                     movie_name  \
# 8631  Sex and the Teenage Mind
# 8632            Johnny O'Clock
# 8633          Moment to Moment
# 8634           Road to Morocco
# 8635               Black Venus
#
#                                            movie_poster  \
# 8631  www.imdb.com/title/tt0299203/mediaviewer/rm394...
# 8632  www.imdb.com/title/tt0039515/mediaviewer/rm211...
# 8633  www.imdb.com/title/tt0060711/mediaviewer/rm237...
# 8634  www.imdb.com/title/tt0035262/mediaviewer/rm188...
# 8635  www.imdb.com/title/tt0085249/mediaviewer/rm346...
#
#                                           movie_summary  \
# 8631  bumbling high school geek virgil heitmeyer has...
# 8632  highclass crook gets in trouble with the law. ...
# 8633  kay stanton her husband neil and son tommy liv...
# 8634  two carefree castaways on a desert shore find ...
# 8635  spanish actor jose antonio ceinos stars as a d...
#
#                                          movie_synopsis  \
# 8631               [\n                , \n            ]
# 8632               [\n                , \n            ]
# 8633               [\n                , \n            ]
# 8634  [The film opens with a freighter at sea explod...
# 8635               [\n                , \n            ]
#
#                                           movie_tagline
# 8631     its a dirty mind but somebodys got to have it.
# 8632  johnny was smart...too smart to tangle with wo...
# 8633  her loneliness... his hunger... so vulnerable....
# 8634  youll shriek at these shieks . . . trying the ...
# 8635  model of sensuality object of desire target of...

# %% [markdown]
# # 단어 나누기

# %%
# vocabulary for sources
s_vocab = list(set(sum(sources, [])))
s_vocab.sort()
s_vocab = ['<pad>'] + s_vocab
source2idx = {word : idx for idx, word in enumerate(s_vocab)}
idx2source = {idx : word for idx, word in enumerate(s_vocab)}

# %%
# vocabulary for targets
t_vocab = list(set(sum(targets, [])))
t_vocab.sort()
t_vocab = ['<pad>', '<bos>', '<eos>'] + t_vocab
target2idx = {word : idx for idx, word in enumerate(t_vocab)}
idx2target = {idx : word for idx, word in enumerate(t_vocab)}

# %%
def preprocess(sequences, max_len, dic, mode = 'source'):
    assert mode in ['source', 'target'], 'source와 target 중에 선택해주세요.'
    
    if mode == 'source':
        # preprocessing for source (encoder)
        s_input = list(map(lambda sentence : [dic.get(token) for token in sentence], sequences))
        
        #s_input = [[x for x in each_input if x] for each_input in s_input]
        #pprint(s_input)
        s_len = list(map(lambda sentence : len(sentence), s_input))
        s_input = pad_sequences(sequences = s_input, maxlen = max_len, padding = 'post', truncating = 'post')
        return s_len, s_input
    

    elif mode == 'target':
        # preprocessing for target (decoder)
        # input
        t_input = list(map(lambda sentence : ['<bos>'] + sentence + ['<eos>'], sequences))
        
        #t_input = [[x for x in each_input if x] for each_input in t_input]
        #pprint(t_input)
        t_input = list(map(lambda sentence : [dic.get(token) for token in sentence], t_input))
        t_len = list(map(lambda sentence : len(sentence), t_input))
        t_input = pad_sequences(sequences = t_input, maxlen = max_len, padding = 'post', truncating = 'post')
     
        # output
        t_output = list(map(lambda sentence : sentence + ['<eos>'], sequences))
        t_output = list(map(lambda sentence : [dic.get(token) for token in sentence], t_output))
        t_output = pad_sequences(sequences = t_output, maxlen = max_len, padding = 'post', truncating = 'post')
        
        return t_len, t_input, t_output

# %%
sum_ = 0
for i in df.movie_summary:
    length = len(i.split())
    sum_ += length
average_no = sum_ / len(df) #summary당 평균 122.84 단어
# preprocessing for source
#단어 수는 120개로 제한
s_max_len = int(average_no) + 30
s_len, s_input = preprocess(sequences = sources,
                            max_len = s_max_len, dic = source2idx, mode = 'source')
print(s_len, s_input)
# Out:
# [109, 346, 39, 138, 65, 406, 94, 54, 107, 327, 176, 119, 109, 74, 94, 28, 32, 90, 269, 120, 151, 85, 597, 24, 187, 79, 52, 104, 24, 89, 137, 96, 67, 70, 19, 153, 168, 27, 287, 26, 36, 74, 668, 134, 59, 109, 26, 78, 16, 292, 76, 143, 58, 142, 103, 124, 83, 182, 87, 70, 108, 72, 397, 14, 86, 13, 153, 124, 16, 88, 87, 265, 109, 24, 27, 379, 64, 36, 89, 108, 55, 196, 25, 85, 305, 28, 186, 95, 272, 23, 32, 82, 27, 118, 366, 44, 97, 264, 58, 279, 37, 414, 120, 411, 154, 62, 27, 200, 81, 83, 44, 142, 87, 37, 56, 91, 185, 274, 85, 11, 97, 10, 86, 221, 106, 196, 230, 105, 386, 250, 206, 202, 69, 369, 144, 49, 7, 36, 32, 65, 19, 38, 111, 153, 108, 17, 251, 104, 120, 255, 213, 141, 101, 231, 130, 171, 121, 184, 182, 389, 190, 54, 255, 185, 68, 81, 131, 333, 107, 95, 25, 81, 337, 268, 24, 109, 121, 106, 63, 44
#  [ 6746   651 12642 ...     0     0     0]
#  [ 6293  8471 14101 ...  4897 12642  7660]
#  ...
#  [ 5977  7601  6109 ... 11668 13686  6727]
#  [14379 11395  1001 ...     3     3 13236]
#  [ 8310  8950 11158 ... 12480  8950  7741]]

# %% [markdown]
# # hyper-param

# %%
# hyper-parameters
epochs = 100
batch_size = 32
learning_rate = .005
total_step = epochs / batch_size
buffer_size = 100
n_batch = buffer_size//batch_size
embedding_dim = 32
units =64

# input
data = tf.data.Dataset.from_tensor_slices((s_len, s_input, t_len, t_input, t_output))
data = data.shuffle(buffer_size = buffer_size)
data = data.batch(batch_size = batch_size)
# s_mb_len, s_mb_input, t_mb_len, t_mb_input, t_mb_output = iterator.get_next()

# %%
def gru(units):
  # If you have a GPU, we recommend using CuDNNGRU(provides a 3x speedup than GRU)
  # the code automatically does that.
    if tf.test.is_gpu_available():
        return tf.keras.layers.CuDNNGRU(units, 
                                        return_sequences=True, 
                                        return_state=True, 
                                        recurrent_initializer='glorot_uniform')
    else:
        return tf.keras.layers.GRU(units, 
                                   return_sequences=True, 
                                   return_state=True, 
                                   recurrent_activation='sigmoid', 
                                   recurrent_initializer='glorot_uniform')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.enc_units)
        
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        return output, state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.dec_units)
        self.fc = tf.keras.layers.Dense(vocab_size)
                
    def call(self, x, hidden, enc_output):
        
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size * 1, vocab)
        x = self.fc(output)
        
        return x, state
        
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.dec_units))

# %%
encoder = Encoder(len(source2idx), embedding_dim, units, batch_size)
decoder = Decoder(len(target2idx), embedding_dim, units, batch_size)

def loss_function(real, pred):
    mask = 1 - np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
    
#     print("real: {}".format(real))
#     print("pred: {}".format(pred))
#     print("mask: {}".format(mask))
#     print("loss: {}".format(tf.reduce_mean(loss_)))
    
    return tf.reduce_mean(loss_)

# creating optimizer
optimizer = tf.train.AdamOptimizer()

# creating check point (Object-based saving)
checkpoint_dir = './data_out/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                encoder=encoder,
                                decoder=decoder)
print(checkpoint_prefix)
# create writer for tensorboard
summary_writer = tf.contrib.summary.create_file_writer(logdir=checkpoint_dir)
print(summary_writer)
# Out:
# ./data_out/training_checkpoints\ckpt
# <tensorflow.python.ops.summary_ops_v2.ResourceSummaryWriter object at 0x00000000128C21D0>

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    
    hidden = encoder.initialize_hidden_state()
    #print(hidden.shape)
    total_loss = 0
    for i, (s_len, s_input, t_len, t_input, t_output) in enumerate(data):
        loss = 0
        #print(s_input, s_input.shape)
        with tf.GradientTape() as tape:
            enc_output, enc_hidden = encoder(s_input, hidden)

            dec_hidden = enc_hidden
            
            dec_input = tf.expand_dims([target2idx['<bos>']] * batch_size, 1)
            
            #Teacher Forcing: feeding the target as the next input
            for t in range(1, t_input.shape[1]):
                
                predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
                
                loss += loss_function(t_input[:, t], predictions)
            
                dec_input = tf.expand_dims(t_input[:, t], 1) #using teacher forcing
                
        batch_loss = (loss / int(t_input.shape[1]))
        
        total_loss += batch_loss
        
        variables = encoder.variables + decoder.variables
        
        gradient = tape.gradient(loss, variables)
        
        optimizer.apply_gradients(zip(gradient, variables))


    if epoch % 10 == 0:
        #save model every 10 epoch
        print('Epoch {} Loss {:.4f} Batch Loss {:.4f}'.format(epoch,
                                            total_loss / n_batch,
                                            batch_loss.numpy()))
        optimizer.minimize(variables)
        checkpoint.save(file_prefix = checkpoint_prefix)

# %%
# #최근 학습된 모델을 불러오고 이어서 EPOCHS로 돌아감
# saver = tf.train.Saver()
# with tf.Session() as sess:
    
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-651aaa7bd903> in <module>
#       3 # with tf.Session() as sess:
#       4
# ----> 5 checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\util.py in restore(self, save_path)
#    1668           called when `save_path` is not `None`.
#    1669     """
# -> 1670     status = self._saver.restore(save_path=save_path)
#    1671     # Create the save counter now so it gets initialized with other variables
#    1672     # when graph building. Creating it earlier would lead to double
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\util.py in restore(self, save_path)
#    1268         graph_view=self._graph_view)
#    1269     base.CheckpointPosition(
# -> 1270         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1271     load_status = CheckpointLoadStatus(
#    1272         checkpoint,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     866           ._single_restoration_from_checkpoint_position(
#     867               checkpoint_position=current_position,
# --> 868               visit_queue=visit_queue))
#     869       restore_ops.extend(new_restore_ops)
#     870       tensor_saveables.update(new_tensor_saveables)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _single_restoration_from_checkpoint_position(self, checkpoint_position, visit_queue)
#     901                                                []).append(child_position)
#     902       else:
# --> 903         if child_position.bind_object(trackable=local_object):
#     904           # This object's correspondence is new, so dependencies need to be
#     905           # visited. Delay doing it so that we get a breadth-first dependency
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in bind_object(self, trackable)
#     256                   proto_id=slot_restoration.slot_variable_id),
#     257               variable=trackable,
# --> 258               slot_name=slot_restoration.slot_name)
#     259       return True  # New assignment
#     260     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\optimizer.py in _create_or_restore_slot_variable(self, slot_variable_position, slot_name, variable)
#    1229       # If we've either made this slot variable, or if we've pulled out an
#    1230       # existing slot variable, we should restore it.
# -> 1231       slot_variable_position.restore(slot_variable)
#    1232     else:
#    1233       # We didn't make the slot variable. Defer restoring until it gets created
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     872     restore_ops.extend(
#     873         current_position.checkpoint.restore_saveables(
# --> 874             tensor_saveables, python_saveables))
#     875     return restore_ops
#     876
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     287              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     288       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 289           validated_saveables).restore(self.save_path_tensor)
#     290       if not context.executing_eagerly():
#     291         for name, restore_op in sorted(new_restore_ops.items()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in restore(self, file_prefix)
#     253     for device, saver in sorted(self._single_device_savers.items()):
#     254       with ops.device(device):
# --> 255         restore_ops.update(saver.restore(file_prefix))
#     256     return restore_ops
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in restore(self, file_prefix)
#     100                                           structured_restored_tensors):
#     101       restore_ops[saveable.name] = saveable.restore(
# --> 102           restored_tensors, restored_shapes=None)
#     103     return restore_ops
#     104
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     113       restored_tensor = array_ops.identity(restored_tensor)
#     114       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 115           self.handle_op, self._var_shape, restored_tensor)
#     116
#     117
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     289   with _handle_graph(handle):
#     290     value_tensor = ops.convert_to_tensor(value)
# --> 291   shape.assert_is_compatible_with(value_tensor.shape)
#     292   return gen_resource_variable_ops.assign_variable_op(handle,
#     293                                                       value_tensor,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in assert_is_compatible_with(self, other)
#    1113     """
#    1114     if not self.is_compatible_with(other):
# -> 1115       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1116
#    1117   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (14280, 32) and (7883, 32) are incompatible

# %%
#sentence = 'I feel hungry'
sentence = 'donghoon teens are eat minsoo'
print(sentence)
print(df.movie_name[7])
print(df.movie_tagline[7])
#sentence = 'desperado'
#checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# donghoon teens are eat minsoo
# From Dusk Till Dawn
# vampires. no interviews.

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(inp_lang[i])
            
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
        
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
        
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
   
    for t in range(max_length_targ):
        

        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += idx2target[predicted_id] + ' '
        
        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)    
            
    return result, sentence
    
result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)

print(sentence)
print(result)
# Out:
# [37494, 2510, 12072]
# donghoon teens are eat minsoo
# until prodigal energy haunted tell. pilot...grand redemption. timing spoke balaguer. jericho heart

# %%
#len(df.movie_summary[39].split('. '))

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(inp_lang[i])
            
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
    print(inputs)
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
    idx = 0
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    #print(dec_input)
    xList = []
    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        #print("*"*100)
        #print(predictions)
        #print("*"*100)
        #print(tf.argmax(predictions[0]))
        print(predictions)
        x = tf.nn.top_k(predictions[0], k=3, sorted=True, name=None)
        for i in range(3):
            predicted_id = x[1][i].numpy()
            #print(predicted_id)

            result += idx2target[predicted_id] + ' '
            #print("result:", result)
            #print(idx2target[predicted_id])
            #if idx2target.get(predicted_id) == '<eos>':
            #             return result, sentence

          #result=""

        # the predicted ID is fed back into the model
            dec_input = tf.expand_dims([predicted_id], 0)  
        xList.append([result])
        result = ''
        
    return xList

# result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
tList=prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
# print(sentence)
from pprint import pprint
pprint(tList)
# Out:
# tf.Tensor([[37494  2510 12072     0     0     0     0     0     0     0]], shape=(1, 10), dtype=int32)
# tf.Tensor(
# [[ 0.00192981  0.00387653 -0.0001338  ...  0.00084078  0.00136333
#   -0.00058426]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[3.0533713e-04 3.6703222e-03 7.5694861e-06 ... 2.1257490e-04
#   9.7969046e-04 6.0740899e-04]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-0.00073569  0.00345075  0.00034872 ... -0.00028084  0.00050289
#    0.00119432]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-0.00100886  0.00106799  0.00237389 ...  0.00022285 -0.00064127
#    0.00126915]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-1.8556989e-03  1.7531029e-03  7.8196794e-04 ... -2.2061402e-03
#    6.1286998e-04 -2.2338849e-05]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-1.1637511e-03 -8.2672969e-04  5.2065455e-04 ... -5.8668706e-04
#   -4.1378371e-04  3.7095942e-05]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-0.00093286 -0.00019236  0.00069534 ... -0.00250729 -0.00149696
#   -0.00030172]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[ 0.00206074 -0.00010398 -0.00054133 ... -0.00042972 -0.00079173
#   -0.00107709]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[ 2.2824362e-03 -1.2694584e-03 -5.4641056e-04 ... -1.9097101e-04
#   -2.6764639e-05 -1.7013230e-03]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[ 0.00024993 -0.00102069  0.00081941 ... -0.00110381 -0.00073508
#   -0.00064227]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[-4.9861375e-04 -9.8794268e-04  9.8451285e-04 ...  1.2363353e-05
#    5.6191441e-04  5.1111751e-04]], shape=(1, 7883), dtype=float32)
# tf.Tensor(
# [[ 0.00043118  0.00068359 -0.00011226 ... -0.00044427 -0.00031892
#    0.00011867]], shape=(1, 7883), dtype=float32)
# [['until fantastic. adventures '],
#  ['rebel censorship. adventures '],
#  ['censorship. suddenly capture. '],
#  ['censorship. boldly eclectic '],
#  ['souls picked remote '],
#  ['behave angle once '],
#  ['bardot trigger chew '],
#  ['hunter dobler. hippie '],
#  ['bites day...but intricately '],
#  ['ii squad aos '],
#  ['power...until farmers invitation '],
#  ['bond. grip resemblance ']]
