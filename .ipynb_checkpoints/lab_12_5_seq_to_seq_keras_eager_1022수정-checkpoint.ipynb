# %% [markdown]
# # Lab 12-5 sequence to sequence (Keras + eager version)
#
# ### simple neural machine translation training
#
# * sequence to sequence
#
# ### Reference
# * [Sequence to Sequence Learning with Neural Networks](https://arxiv.org/abs/1409.3215)

# %%
pip install tensorflow==1.15
# Out:
# Requirement already satisfied: tensorflow==1.15 in c:\programdata\anaconda3\lib\site-packages (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: gast==0.2.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.24.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.11.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.33.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.16.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.8.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==1.15) (0.1.7)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.9.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (0.14.1)
# Collecting setuptools>=41.0.0 (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15)
#   Downloading https://files.pythonhosted.org/packages/6a/9a/50fadfd53ec909e4399b67c74cc7f4e883488035cfcdb90b685758fa8b34/setuptools-41.4.0-py2.py3-none-any.whl (580kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.1)
# Installing collected packages: setuptools
#   Found existing installation: setuptools 40.8.0
#     Uninstalling setuptools-40.8.0:
#       Successfully uninstalled setuptools-40.8.0
# Successfully installed setuptools-41.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import absolute_import, division, print_function

# Import TensorFlow >= 1.10 and enable eager execution
import tensorflow as tf
print(tf.__version__)
tf.enable_eager_execution()

from matplotlib import font_manager, rc

rc('font', family='AppleGothic') #for mac

import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

from pprint import pprint
import numpy as np
import os
import pandas as pd
import re
#요약
from gensim.summarization.summarizer import summarize
# Out:
# 1.15.0

# %%
#path = '/content/drive/My Drive/Colab Notebooks/moviedata2.json'
df = pd.read_json('moviedata2.json')[:10000]

# %% [markdown]
# # 전처리

# %%
#df = movie_dataframe
def preprocessing(df):
    df.movie_name = df.movie_name.apply(lambda x: x.replace('혻',''))
    
    df.movie_summary = df.movie_summary.apply(lambda x: str(x).lower())
    df.movie_summary = df.movie_summary.apply(lambda x: re.sub("[^A-Za-z. 0-9]", '', x))
    
    df.movie_synopsis = df.movie_synopsis.apply(lambda x : str(x).lower())
    df.movie_synopsis = df.movie_synopsis.apply(lambda x : re.sub('[^A-Za-z. ]', '', x))
    
    df.movie_tagline = df.movie_tagline.apply(lambda x: str(x).lower())
    df.movie_tagline = df.movie_tagline.apply(lambda x: x.replace('\\n','').replace('\\xa0',''))
    df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub('[^A-Za-z. 0-9]', '', x))
    df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub(' {2,}', '', x))
    
    #태그라인 없는 데이터 row 삭제
    index = df[df['movie_tagline']==''].index
    df.drop(index, inplace = True)

    #summary 없는 데이터 row 삭제
    summary_index = df[df['movie_summary']==''].index
    df.drop(summary_index, inplace = True)
    
    index = df[df['movie_summary'].str.contains('  ')].index
    df.drop(index , inplace = True)

    df.reset_index()
    
    #summary 문장 수가 너무 많을 경우 summarize를 통해 압축
    for idx, summary in enumerate(df['movie_summary']):
        x = summary.split('. ')
        #print(x)
        if len(x) <= 2:
            df['movie_summary'][idx] = summary
        else:
            df['movie_summary'][idx] = summarize(summary, word_count=150,ratio = 0.3)
        
        
    index = df[df['movie_summary']==''].index
    df.drop(index, inplace=True)
    df.reset_index()
    
    return df

def processed_df(df):
    tl = list(df["movie_tagline"])
    tl = ["".join([ j for j in i if j != "\n"]).strip() for i in tl]

    summ = list(df['movie_summary'])

    df.movie_tagline = tl
    df.movie_summary = summ

    sources = [i.split() for i in df['movie_summary']]
    targets = [i.split() for i in df['movie_tagline']]
    return sources, targets

# %%
df.movie_summary[54]
# Out:
# 'in a lastditch effort to stop a diabolical plot a dead cia operatives memories secrets and skills are implanted into a deathrow inmate in hopes that he will complete the operatives mission. bill pope ryan reynolds is a cia agent on a mission in london tracking down a shadowy hacker nicknamed the dutchman. when he gets mysteriously ambushed and killed an experimental procedure is used to transfer his memories into dangerous convict jericho stewart kevin costner. when he wakes up with the cia agents memories his mission is to find the dutchman and make the deal with him before the hacker launches icbms and starts world war iii. but complications soon arise and the mission turns personal. captured by a spanish anarchist before he seals a deal with the profitmotivated hacker known only as the dutchman the londonbased cia operative bill pope is killed in the line of duty. suddenly retrieving the memories and the invaluable information inside the brain of the dead agent become the bureaus top priorityand with the help of dr franks radical procedurehis knowledge is transplanted into the troubled brain of the perfect candidate the emotionless psychopath jerico stewart. now as jericos fragmented memories become inextricably intertwined with popes classified information about the intercontinental ballistic missile system he becomes the target of both the cia and the anarchists. is a volatile criminal our last hope'

# %%
summarize(df.movie_summary[54], word_count=150, ratio = 0.5)
# Out:
# 'in a lastditch effort to stop a diabolical plot a dead cia operatives memories secrets and skills are implanted into a deathrow inmate in hopes that he will complete the operatives mission.\nbill pope ryan reynolds is a cia agent on a mission in london tracking down a shadowy hacker nicknamed the dutchman.\nwhen he wakes up with the cia agents memories his mission is to find the dutchman and make the deal with him before the hacker launches icbms and starts world war iii.\ncaptured by a spanish anarchist before he seals a deal with the profitmotivated hacker known only as the dutchman the londonbased cia operative bill pope is killed in the line of duty.\nnow as jericos fragmented memories become inextricably intertwined with popes classified information about the intercontinental ballistic missile system he becomes the target of both the cia and the anarchists.'

# %% [markdown]
# # 단어 나누기

# %%
sources, targets = processed_df(preprocessing(df))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
targets
# Out:
# [['the', 'next', 'chapter'],
#  ['its', 'alien', 'the', '8th', 'passenger.'],
#  ['all',
#   'we',
#   'have',
#   'to',
#   'decide',
#   'is',
#   'what',
#   'to',
#   'do',
#   'with',
#   'the',
#   'time',
#   'that',
#   'we',
#   'are',
#   'given'],
#  ['nobody', 'runs', 'forever'],
#  ['the', 'magic', 'begins', 'november', '16th.'],
#  ['its', 'just', 'a', 'bunch', 'of', 'hocus', 'pocus'],
#  ['you',
#   'know',
#   'his',
#   'name.',
#   'you',
#   'know',
#   'the',
#   'story.',
#   'on',
#   'friday',
#   'the',
#   '13th',
#   'witness',
#   'his',
#   'resurrection...'],
#  ['vampires.', 'no', 'interviews.'],
#  ['the', 'd', 'is', 'silent.', 'payback', 'wont', 'be.'],
#  ['what', 'do', 'you', 'allow', 'to', 'define', 'you'],
#  ['90', 'minutes.', '22', 'miles.', 'zero', 'back', 'up.'],
#  ['two', 'worlds.', 'one', 'hero.'],
#  ['the', 'future', 'begins.'],
#  ['...', 'look', 'closer'],
#  ['theyre',
#   'going',
#   'to',
#   'pin',
#   'something',
#   'on',
#   'that',
#   'smart',
#   'cop',
#   'from',
#   'philidelphia',
#   '.',
#   '.',
#   '.',
#   'maybe',
#   'a',
#   'medal',
#   '.',
#   '.',
#   '.',
#   'maybe',
#   'a',
#   'murder'],
#  ['dont', 'go', 'to', 'war', 'with', 'him.'],
#  ['their', 'world.', 'her', 'rules.', 'his', 'destiny.'],
#  ['the', 'eighth', 'wonder', 'of', 'the', 'world.'],
#  ['for', 'love'],
#  ['fire', 'burns', 'brighter', 'in', 'the', 'darkness'],
#  ['religion', 'is', 'power'],
#  ['based', 'on', 'the', 'incredible', 'true', 'story.'],
#  ['in',
#   'brightest',
#   'day',
#   'in',
#   'blackest',
#   'night',
#   'no',
#   'evil',
#   'shall',
#   'escape',
#   'my',
#   'sight',
#   'let',
#   'those',
#   'who',
#   'worship',
#   'evils',
#   'might',
#   'beware',
#   'my',
#   'power',
#   'green',
#   'lanterns',
#   'light.'],
#  ['i',
#   'have',
#   'come',
#   'here',
#   'to',
#   'chew',
#   'bubblegum',
#   'and',
#   'kick',
#   'ass...and',
#   'im',
#   'all',
#   'out',
#   'of',
#   'bubblegum.'],
#  ['nothing', 'is', 'as', 'it', 'seems.'],
#  ['justice', 'at', 'any', 'cost'],
#  ['the',
#   'cias',
#   'last',
#   'hope',
#   'is',
#   'in',
#   'the',
#   'mind',
#   'of',
#   'a',
#   'criminal'],
#  ['afraid', 'of', 'the', 'dark', 'you', 'will', 'be', 'july', '2005.'],
#  ['banned',
#   'in',
#   'australia',
#   'for',
#   '17',
#   'yearsnow',
#   'for',
#   'the',
#   'first',
#   'time',
#   'australian',
#   'audiences',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'judge',
#   'one',
#   'of',
#   'the',
#   'most',
#   'controversial',
#   'films',
#   'in',
#   'the',
#   'history',
#   'of',
#   'cinema.',
#   'a',
#   'work',
#   'of',
#   'rigorous',
#   'moral',
#   'intelligence',
#   'or',
#   'a',
#   'descent',
#   'into',
#   'a',
#   'nightmare',
#   'of',
#   'cruelty',
#   'and',
#   'lust',
#   '1993'],
#  ['the', 'rules', 'have', 'changed'],
#  ['no',
#   'mortal',
#   'could',
#   'possess',
#   'it',
#   'no',
#   'kingdom',
#   'could',
#   'command',
#   'it'],
#  ['lock',
#   'your',
#   'car',
#   'or',
#   'it',
#   'may',
#   'be...',
#   'gone',
#   'in',
#   '60',
#   'seconds'],
#  ['everyone', 'is', 'a', 'suspect.'],
#  ['if', 'only', 'they', 'knew', 'she', 'had', 'the', 'power.'],
#  ['his',
#   'life',
#   'is',
#   'fantastic...',
#   'his',
#   'wife',
#   'is',
#   'fantastic...',
#   'his',
#   'neighbors',
#   'not',
#   'so',
#   'fantastic.'],
#  ['discover', 'the', 'truth', 'behind', 'the', 'legend'],
#  ['its', 'hotter', 'than', 'hell'],
#  ['the',
#   'only',
#   'thing',
#   'more',
#   'powerful',
#   'than',
#   'the',
#   'system',
#   'is',
#   'the',
#   'man',
#   'that',
#   'will',
#   'overthrow',
#   'it.'],
#  ['prepare', 'for', 'the', 'rideshare', 'of', 'your', 'life'],
#  ['best', 'friends', 'social', 'trends', 'and', 'occasional', 'murder.'],
#  ['doug',
#   'is',
#   '18.',
#   'raised',
#   'on',
#   'an',
#   'air',
#   'base',
#   'and',
#   'born',
#   'to',
#   'fly.',
#   'his',
#   'father',
#   'has',
#   'been',
#   'shot',
#   'down',
#   '6000',
#   'miles',
#   'away',
#   'and',
#   'has',
#   'been',
#   'sentenced',
#   'to',
#   'death...',
#   'for',
#   'the',
#   'crime',
#   'of',
#   'being',
#   'an',
#   'american.',
#   'everyones',
#   'telling',
#   'doug',
#   'to',
#   'sit',
#   'tight',
#   'and',
#   'wait.',
#   'everyone',
#   'but',
#   'retired',
#   'air',
#   'force',
#   'colonel',
#   'chappy',
#   'sinclair.',
#   'they',
#   'know',
#   'what',
#   'they',
#   'have',
#   'to',
#   'do.',
#   'and',
#   'theyve',
#   'borrowed',
#   'a',
#   'pair',
#   'of',
#   'f16s',
#   'to',
#   'do',
#   'it.',
#   'for',
#   'them',
#   'waiting',
#   'time',
#   'is',
#   'over.'],
#  ['when',
#   'a',
#   'tough',
#   'cop',
#   'has',
#   'a',
#   'cool',
#   'convict',
#   'as',
#   'a',
#   'partner',
#   'and',
#   '48',
#   'hrs',
#   'to',
#   'catch',
#   'a',
#   'killer',
#   'a',
#   'lot',
#   'of',
#   'funny',
#   'things',
#   'can',
#   'happen',
#   'in',
#   '.',
#   '.',
#   '.',
#   '48',
#   'hrs.',
#   'australia',
#   'theatrical'],
#  ['you',
#   'only',
#   'live',
#   'once...',
#   'so',
#   'see',
#   'the',
#   'pink',
#   'panther',
#   'twice'],
#  ['200', 'years', 'later', 'hes', 'still', 'alive.'],
#  ['appearing', 'soon'],
#  ['ever', 'felt', 'like', 'you', 'were', 'surrounded', 'by', 'zombies'],
#  ['for',
#   'every',
#   'good',
#   'in',
#   'the',
#   'universe',
#   'there',
#   'is',
#   'an',
#   'evil.'],
#  ['joe', 'was', 'once', 'a', 'good', 'man'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'important',
#   'and',
#   'powerful',
#   'films',
#   'of',
#   'all',
#   'time'],
#  ['the', 'past', 'never', 'stays', 'in', 'focus.'],
#  ['evil.', 'unmasked.'],
#  ['one',
#   'man',
#   'brought',
#   'a',
#   'family',
#   'together...and',
#   'changed',
#   'their',
#   'lives',
#   'forever.'],
#  ['there',
#   'were',
#   'three',
#   'men',
#   'in',
#   'her',
#   'life.',
#   'one',
#   'to',
#   'take',
#   'her...',
#   'one',
#   'to',
#   'love',
#   'her...',
#   'and',
#   'one',
#   'to',
#   'kill',
#   'her.'],
#  ['trust', 'me'],
#  ['they', 'havent', 'finished', 'being', 'alive.'],
#  ['good', 'girls', 'gone', 'bad'],
#  ['kids', 'rule'],
#  ['the', 'classic', 'love', 'story', 'set', 'in', 'our', 'time.'],
#  ['life', 'beyond', 'motherhood'],
#  ['you',
#   'are',
#   'cordially',
#   'invited',
#   'to',
#   'meet',
#   'the',
#   'stangle',
#   'brothers.',
#   'theyre',
#   'turning',
#   'things',
#   'around',
#   'but',
#   'their',
#   'dates',
#   'are',
#   'turning',
#   'it',
#   'upside',
#   'down.'],
#  ['see', 'how', 'the', 'other', 'half', 'steals.'],
#  ['at', 'last', 'a', 'comedy', 'that', 'bites'],
#  ['pioneer.', 'genius.', 'rebel.'],
#  ['the', 'truth', 'cannot', 'be', 'converted'],
#  ['you', 'know', 'what', 'they', 'say...', 'love', 'is', 'blind'],
#  ['after', 'the', 'fall', 'from', 'innocence', 'the', 'legend', 'begins.'],
#  ['in',
#   'every',
#   'woman',
#   'there',
#   'is',
#   'the',
#   'girl',
#   'she',
#   'left',
#   'behind.'],
#  ['lifes', 'a', 'party.', 'crash', 'it.'],
#  ['check', 'your', 'baggage.'],
#  ['from', 'the', 'director', 'of', 'prisoners'],
#  ['new', 'decade.', 'new', 'rules.'],
#  ['based', 'on', 'the', 'bestselling', 'novel.'],
#  ['young', 'cunning', 'and', 'deadly'],
#  ['its', 'a', 'smash'],
#  ['a',
#   'magical',
#   'love',
#   'story',
#   'that',
#   'stretches',
#   'across',
#   'time',
#   'and',
#   'space.'],
#  ['all', 'art', 'is', 'dangerous.'],
#  ['they', 'dont', 'have', 'forever', 'they', 'have', 'each', 'other.'],
#  ['the',
#   'master',
#   'of',
#   'erotica',
#   'brings',
#   'a',
#   'young',
#   'girls',
#   'desire',
#   'to',
#   'its',
#   'heights.'],
#  ['er',
#   'kam',
#   'als',
#   'feind...',
#   'und',
#   'wurde',
#   'ihr',
#   'held.',
#   'he',
#   'came',
#   'as',
#   'an',
#   'enemy...',
#   'and',
#   'became',
#   'their',
#   'hero.'],
#  ['evil', 'breeds.'],
#  ['the',
#   'australian',
#   'true',
#   'story',
#   'of',
#   'a',
#   'life',
#   'lost',
#   'and',
#   'found'],
#  ['fear', 'is', 'the', 'ultimate', 'currency'],
#  ['great', 'friends.', 'terrible', 'choices.'],
#  ['so', 'dark', 'the', 'con', 'of', 'man'],
#  ['such', 'minor', 'changes', 'such', 'huge', 'consequences.'],
#  ['heavy', 'mental...', 'take', 'notes.'],
#  ['all', 'you', 'have', 'to', 'do', 'is', 'dream...'],
#  ['col.',
#   'frank',
#   'slade',
#   'has',
#   'a',
#   'very',
#   'special',
#   'plan',
#   'for',
#   'the',
#   'weekend.',
#   'it',
#   'involves',
#   'travel',
#   'women',
#   'good',
#   'food',
#   'fine',
#   'wine',
#   'the',
#   'tango',
#   'chauffeured',
#   'limousines',
#   'and',
#   'a',
#   'loaded',
#   'fortyfive.',
#   'and',
#   'hes',
#   'bringing',
#   'charlie',
#   'along',
#   'for',
#   'the',
#   'ride.'],
#  ['somewhere',
#   'under',
#   'the',
#   'sea',
#   'and',
#   'beyond',
#   'your',
#   'imagination',
#   'is',
#   'an',
#   'adventure',
#   'in',
#   'fantasy.'],
#  ['everyones', 'talking', 'about', 'mary...'],
#  ['terror', 'has', 'multiplied.'],
#  ['alfred',
#   'hitchcock',
#   'engulfs',
#   'you',
#   'in',
#   'a',
#   'whirlpool',
#   'of',
#   'terror',
#   'and',
#   'tension'],
#  ['do', 'you', 'believe', 'in', 'ghostsshe', 'didnt...'],
#  ['real', 'power', 'cant', 'be', 'given.', 'it', 'must', 'be', 'taken.'],
#  ['monsters', 'come', 'in', 'many', 'forms'],
#  ['a',
#   'comedy',
#   'about',
#   'one',
#   'nice',
#   'guy',
#   'who',
#   'gets',
#   'pushed',
#   'too',
#   'far.'],
#  ['theyre', 'back', 'to', 'save', 'america', 'from', 'the', '90s'],
#  ['we', 'all', 'have', 'our', 'sins'],
#  ['sense', 'something', 'beautiful'],
#  ['if', 'you', 'cant', 'get', 'out', 'get', 'even'],
#  ['the', 'puck', 'stops', 'here'],
#  ['abandoned.', 'adrift.', 'not', 'alone.'],
#  ['based',
#   'on',
#   'a',
#   'true',
#   'story',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'horrific',
#   'murders',
#   'in',
#   'history'],
#  ['in', 'space', 'no', 'one', 'can', 'eat', 'ice', 'cream'],
#  ['a',
#   'simple',
#   'trip',
#   'to',
#   'mars',
#   'will',
#   'become',
#   'the',
#   'journey',
#   'of',
#   'a',
#   'lifetime'],
#  ['the', 'most', 'terrifying', 'ride', 'youll', 'ever', 'take'],
#  ['secrets', 'gossip', 'and', 'scandal', 'are', 'back', 'in', 'fashion.'],
#  ['someone',
#   'you',
#   'pass',
#   'on',
#   'the',
#   'street',
#   'may',
#   'already',
#   'be',
#   'the',
#   'love',
#   'of',
#   'your',
#   'life.'],
#  ['lines', 'may', 'divide', 'us', 'but', 'hope', 'will', 'unite', 'us...'],
#  ['discover', 'the', 'key', 'to', 'the', 'mystery.'],
#  ['the', 'secret', 'lies', 'within.'],
#  ['90', 'of', 'them', 'are', 'found', 'in', 'a', 'month.'],
#  ['hes', 'leaving', 'virgin', 'territory'],
#  ['two', 'countries', 'two', 'loves', 'one', 'heart.'],
#  ['see', 'how', 'the', 'mother', 'half', 'lives.'],
#  ['now.',
#   'whatever',
#   'you',
#   'saw',
#   'or',
#   'did.',
#   'is',
#   'no',
#   'longer',
#   'my',
#   'concern.',
#   'but',
#   'lets',
#   'be',
#   'clear.',
#   'it',
#   'wont',
#   'end',
#   'well.'],
#  ['the', 'cat', 'is', 'the', 'most', 'feared', 'animal', 'there', 'is'],
#  ['youre', 'only', 'young', 'once...', 'is', 'it', 'over', 'yet'],
#  ['its',
#   'about',
#   'flights',
#   'of',
#   'fantasy.',
#   'and',
#   'the',
#   'nightmare',
#   'of',
#   'reality.',
#   'terrorist',
#   'bombings.',
#   'and',
#   'late',
#   'night',
#   'shopping.',
#   'true',
#   'love.',
#   'and',
#   'creative',
#   'plumbing.'],
#  ['darkness', 'will', 'consume', 'you.'],
#  ['youll', 'laugh', 'or', 'else.'],
#  ['angel', 'or', 'demon'],
#  ['a',
#   'comedy',
#   'in',
#   'the',
#   'last',
#   'place',
#   'you',
#   'expect',
#   'to',
#   'find',
#   'one.'],
#  ['...it', 'dont', 'stand', 'for', 'nice', 'white', 'and', 'accessible.'],
#  ['friendship', 'is', 'a', 'trip'],
#  ['once', 'upon', 'a', 'time...', 'can', 'happen', 'any', 'time.'],
#  ['what', 'would', 'you', 'do', 'if', 'this', 'was', 'happening', 'to', 'you'],
#  ['a', 'nervous', 'romance.'],
#  ['revenge', 'never', 'looked', 'so', 'good.'],
#  ['a', 'comedy', 'with', 'everything', 'on', 'it.'],
#  ['love.', 'pain.', 'glory.'],
#  ['forget', 'about', 'love'],
#  ['dont', 'look', 'for', 'a', 'reason...', 'look', 'for', 'a', 'way', 'out'],
#  ['they', 'were', 'started', 'to', 'protect', 'us...'],
#  ['get', 'ready', 'for', 'something', 'big', 'july', '20th'],
#  ['when', 'nature', 'turns', 'evil', 'true', 'terror', 'awaits.', 'uk'],
#  ['...', 'and', 'hell', 'followed', 'with', 'him.'],
#  ['in', 'some', 'instances', 'death', 'may', 'occur.'],
#  ['good', 'breeding', 'gone', 'bad'],
#  ['opposites', 'attract.'],
#  ['the', 'next', 'chapter', 'is', 'always', 'the', 'best.'],
#  ['sea', 'evil'],
#  ['not', 'so', 'silent', 'anymore'],
#  ['theyre', 'here', 'and', 'they', 'want', 'to', 'meet', 'the', 'neighbors'],
#  ['mummys', 'little', 'monster...'],
#  ['hes',
#   'the',
#   'best',
#   'there',
#   'is',
#   'actually',
#   'hes',
#   'the',
#   'only',
#   'one',
#   'there',
#   'is.'],
#  ['quien',
#   'est',
#   'detrs',
#   'who',
#   'did',
#   'it',
#   'argentine',
#   'release',
#   'poster'],
#  ['a', 'stateoftheart', 'adventure'],
#  ['she', 'can', 'hear', 'mens', 'thoughts.', 'let', 'the', 'games', 'begin.'],
#  ['the', 'view', 'may', 'be', 'beautiful', 'but', 'you', 'cant', 'eat', 'it.'],
#  ['entangled',
#   'in',
#   'his',
#   'past.',
#   'running',
#   'from',
#   'the',
#   'law.',
#   'all',
#   'for',
#   'love.'],
#  ['he', 'doesnt', 'need', 'words.'],
#  ['you',
#   'will',
#   'never',
#   'see',
#   'the',
#   'most',
#   'highly',
#   'acclaimed',
#   'film',
#   'of',
#   'our',
#   'time',
#   'on',
#   'television.',
#   'this',
#   'may',
#   'be',
#   'your',
#   'last',
#   'chance',
#   'to',
#   'see',
#   'it',
#   'in',
#   'a',
#   'theater.',
#   '1975'],
#  ['some', 'call', 'him', 'bad', 'they', 'call', 'him', 'dad.'],
#  ['the', 'internet', 'is', 'about', 'to', 'crash'],
#  ['a',
#   'battle',
#   'between',
#   'two',
#   'nations',
#   'became',
#   'a',
#   'conflict',
#   'between',
#   'two',
#   'men.'],
#  ['fear', 'reaches', 'out...', 'for', 'the', 'girl', 'next', 'door.'],
#  ['growing', 'up', 'has', 'nothing', 'to', 'do', 'with', 'age.'],
#  ['based', 'on', 'the', 'bestselling', 'novel'],
#  ['your', 'world', 'has', 'been', 'adjusted'],
#  ['theres', 'something', 'about'],
#  ['big', 'they', 'fought', 'big', 'they', 'loved', 'big', 'their', 'story'],
#  ['the', 'raunchiest', 'movie', 'about', 'growing', 'up', 'ever', 'made'],
#  ['no', 'one', 'is', 'safe'],
#  ['for', 'money.for', 'murder.for', 'each', 'other.'],
#  ['life', 'is', 'not', 'a', 'malfunction.'],
#  ['the', 'legend', 'continues...the', 'italian', 'stallion', 'is', 'back'],
#  ['her', 'story', 'will', 'be', 'told.'],
#  ['every', 'child', 'needs', 'to', 'feel', 'loved.'],
#  ['can', 'you', 'keep', 'a', 'national', 'secret'],
#  ['three', 'generations.', 'two', 'families.', 'one', 'forbidden', 'love.'],
#  ['they',
#   'survived',
#   'the',
#   'terror...but',
#   'they',
#   'cant',
#   'escape',
#   'their',
#   'destiny.'],
#  ['innocence', 'dies.', 'abby', 'doesnt.'],
#  ['based', 'on', 'a', 'true', 'story.'],
#  ['life', 'can', 'change', 'at', 'the', 'turn', 'of', 'a', 'page.'],
#  ['dont', 'close', 'your', 'eyes.'],
#  ['the', 'end', 'is', 'coming', 'august', '29'],
#  ['its', 'happening', 'so', 'fast.'],
#  ['sometimes',
#   'when',
#   'you',
#   'want',
#   'to',
#   'come',
#   'clean',
#   'you',
#   'have',
#   'to',
#   'play',
#   'dirty.'],
#  ['increase', 'the', 'peace.'],
#  ['shes', 'about', 'to', 'find', 'the', 'perfect', 'fit.'],
#  ['six',
#   'students',
#   'are',
#   'about',
#   'to',
#   'find',
#   'out',
#   'their',
#   'teachers',
#   'really',
#   'are',
#   'from',
#   'another',
#   'planet.'],
#  ['alguien',
#   'respondi',
#   'a',
#   'tu',
#   'llamada.',
#   'someone',
#   'answered',
#   'your',
#   'call.'],
#  ['to',
#   'know',
#   'lloyd',
#   'dobler',
#   'is',
#   'to',
#   'love',
#   'him.',
#   'diane',
#   'court',
#   'is',
#   'about',
#   'to',
#   'know',
#   'lloyd',
#   'dobler.'],
#  ['we', 'are', 'all', 'connected'],
#  ['everybody',
#   'has',
#   'a',
#   'secret...',
#   'duke',
#   'wants',
#   'olivia',
#   'who',
#   'likes',
#   'sebastian',
#   'who',
#   'is',
#   'really',
#   'viola',
#   'whose',
#   'brother',
#   'is',
#   'dating',
#   'monique',
#   'so',
#   'she',
#   'hates',
#   'olivia',
#   'whos',
#   'with',
#   'duke',
#   'to',
#   'make',
#   'sebastian',
#   'jealous',
#   'who',
#   'is',
#   'really',
#   'viola',
#   'whos',
#   'crushing',
#   'on',
#   'duke',
#   'who',
#   'thinks',
#   'shes',
#   'a',
#   'guy...'],
#  ['how', 'could', 'he', 'escape', 'from', 'his', 'nightmares'],
#  ['just', 'be', 'you.'],
#  ['were', 'all', 'different', 'on', 'the', 'inside'],
#  ['from', 'acclaimed', 'director', 'na', 'hongjin'],
#  ['no', 'one', 'gets', 'off.', 'until', 'he', 'does.'],
#  ['a',
#   'district',
#   'attorney',
#   'out',
#   'for',
#   'a',
#   'conviction.',
#   'a',
#   'new',
#   'lawyer',
#   'out',
#   'of',
#   'her',
#   'league.',
#   'a',
#   'young',
#   'boy',
#   'who',
#   'knew',
#   'too',
#   'much.'],
#  ['some', 'people', 'would', 'kill', 'to', 'fit', 'in.'],
#  ['based', 'on', 'an', 'absurd', 'but', 'true', 'story'],
#  ['to',
#   'find',
#   'her',
#   'son',
#   'she',
#   'did',
#   'what',
#   'no',
#   'one',
#   'else',
#   'dared.'],
#  ['he',
#   'was',
#   'a',
#   'cool',
#   'customer.',
#   '.',
#   '.until',
#   'the',
#   'law',
#   'made',
#   'it',
#   'hot',
#   'for',
#   'him'],
#  ['separated', 'by', 'fate.', 'bound', 'by', 'destiny.'],
#  ['our', 'greatest', 'threat', 'is', 'our', 'only', 'hope.'],
#  ['ha',
#   'kann',
#   'nur',
#   'gedeihen',
#   'wo',
#   'liebe',
#   'ist...',
#   'hatred',
#   'can',
#   'only',
#   'develop',
#   'when',
#   'there',
#   'is',
#   'love...'],
#  ['unpleasant', 'dreams...'],
#  ['everyone', 'has', 'something', 'to', 'hide.'],
#  ['stand', 'for', 'whats', 'right', 'fight', 'for', 'whats', 'true.'],
#  ['yesterday',
#   'they',
#   'were',
#   'businessmen.',
#   'today',
#   'theyre',
#   'cowboys.',
#   'tomorrow',
#   'theyll',
#   'be',
#   'walking',
#   'funny.'],
#  ['unleash', 'the', 'terror.'],
#  ['untamed', 'souls.', 'kindred', 'spirits.'],
#  ['nothing', 'is', 'what', 'it', 'seems'],
#  ['the',
#   'greatest',
#   'cast',
#   'of',
#   'suspicious',
#   'characters',
#   'ever',
#   'involved',
#   'in',
#   'murder.'],
#  ['tell', 'yourself', 'its', 'just', 'a', 'game.'],
#  ['small', 'town', 'kid', 'big', 'time', 'right', 'hook'],
#  ['whos', 'your', 'daddy'],
#  ['a',
#   'place',
#   'for',
#   'dreams.',
#   'a',
#   'place',
#   'for',
#   'heartbreak.',
#   'a',
#   'place',
#   'to',
#   'pick',
#   'up',
#   'the',
#   'pieces.'],
#  ['the', 'truth', 'hurts.'],
#  ['joel',
#   'had',
#   'all',
#   'the',
#   'normal',
#   'teenage',
#   'fantasies...cars',
#   'girls',
#   'money.',
#   'then',
#   'his',
#   'parents',
#   'left',
#   'for',
#   'a',
#   'week',
#   'and',
#   'all',
#   'his',
#   'fantasies',
#   'came',
#   'true.',
#   'uk',
#   'theatrical'],
#  ['he', 'makes', 'the', 'trouble', 'she', 'takes', 'the', 'blame.'],
#  ['the', 'secret', 'of', 'life', 'the', 'secrets', 'in', 'the', 'sauce.'],
#  ['hearts', 'will', 'bleed.'],
#  ['evil', 'is', 'closer', 'than', 'you', 'think.'],
#  ['this', 'holiday', 'discover', 'your', 'inner', 'elf.'],
#  ['sorry', 'jack...', 'chuckys', 'back'],
#  ['between', 'good', 'and', 'evil', 'and', 'heaven', 'and', 'hell', 'is...'],
#  ['its', 'about', 'to', 'get', 'twisted'],
#  ['some', 'sacrifices', 'must', 'be', 'made'],
#  ['the',
#   'epic',
#   'conclusion',
#   'to',
#   'the',
#   'trilogy',
#   'of',
#   'mayhem',
#   'and',
#   'bad',
#   'decisions'],
#  ['the', 'legend', 'lives', 'on...'],
#  ['alien',
#   'abduction.november',
#   '5',
#   '1975.white',
#   'mountains',
#   'northeastern',
#   'arizona.based',
#   'on',
#   'the',
#   'true',
#   'story.'],
#  ['never',
#   'does',
#   'it',
#   'die',
#   'it',
#   'starts',
#   'again',
#   'and',
#   'again.',
#   'its',
#   'in',
#   'your',
#   'hands.'],
#  ['ice', 'age', 'is', 'coming'],
#  ['a', 'story', 'of', 'unholy', 'murder.'],
#  ['the',
#   'same',
#   'star...the',
#   'same',
#   'director',
#   'who',
#   'gave',
#   'you',
#   'stagecoach',
#   'and',
#   'fort',
#   'apache',
#   'now',
#   'give',
#   'you',
#   'another',
#   'roaring',
#   'story',
#   'of',
#   'the',
#   'fighting',
#   'cavalry',
#   'ad',
#   'cuts.'],
#  ['a', 'new', 'twist', 'on', 'the', 'classic', 'tail.'],
#  ['fragments',
#   'of',
#   'a',
#   'melancholy',
#   'soul',
#   'loathing',
#   'the',
#   'l.a.',
#   'vacant',
#   'life.'],
#  ['many', 'saw', 'evil.', 'they', 'dared', 'to', 'stop', 'it.'],
#  ['the', 'end', 'of', 'earth', 'doesnt', 'mean', 'the', 'end', 'of', 'us.'],
#  ['bernie',
#   'lomax',
#   'would',
#   'be',
#   'the',
#   'perfect',
#   'host',
#   'except',
#   'for',
#   'one',
#   'small',
#   'problem',
#   'hes',
#   'dead.'],
#  ['donnie', 'brasco.', 'based', 'on', 'a', 'true', 'story.'],
#  ['no', 'one', 'is', 'above', 'the', 'law.'],
#  ['il', 'y', 'a', 'une', 'vie', 'aprs', 'le', 'lyce...', 'france'],
#  ['he', 'is', 'her', 'only', 'hope.', 'and', 'her', 'greatest', 'threat.'],
#  ['fear', 'what', 'is', 'within'],
#  ['a',
#   'thousand',
#   'feet',
#   'beneath',
#   'the',
#   'sea',
#   'the',
#   'blackest',
#   'holes',
#   'are',
#   'in',
#   'the',
#   'mind...'],
#  ['the', 'story', 'of', 'hank', 'williams.'],
#  ['there', 'are', 'no', 'partners', 'in', 'crime'],
#  ['a',
#   'true',
#   'story',
#   'about',
#   'finding',
#   'the',
#   'courage',
#   'to',
#   'be',
#   'yourself.'],
#  ['a', 'comedy', 'about', 'an', 'overwhelming', 'underachiever.'],
#  ['pass', 'the', 'warning.'],
#  ['youre', 'only', 'as', 'strong', 'as', 'your', 'next', 'move.'],
#  ['based', 'on', 'an', 'extraordinary', 'true', 'story.'],
#  ['a',
#   'recreation',
#   'of',
#   'the',
#   'nightmare',
#   'that',
#   'started',
#   'it',
#   'all...'],
#  ['experience',
#   '2019s',
#   'first',
#   'great',
#   'romantic',
#   'comedy',
#   'for',
#   'grownups'],
#  ['from', 'the', 'creators', 'of', 'toy', 'story', '3'],
#  ['from', 'the', 'creator', 'of', 'rashomon', 'and', 'ikiru'],
#  ['matt', 'helms', 'final', 'assignment', 'is', 'a', 'blast'],
#  ['jungle',
#   'book',
#   'was',
#   'a',
#   'joy...',
#   'aristocats',
#   'was',
#   'a',
#   'ball...',
#   'robin',
#   'hood',
#   'is',
#   'a',
#   'riot'],
#  ['the', 'inside', 'story', 'of', 'the', 'harvey', 'weinsten', 'scandal'],
#  ['a', 'thousand', 'voices.', 'a', 'single', 'dream.'],
#  ['long', 'time', 'no', 'z.'],
#  ['based',
#   'on',
#   'the',
#   'true',
#   'story',
#   'of',
#   'danny',
#   'greene',
#   'the',
#   'man',
#   'the',
#   'mob',
#   'couldnt',
#   'kill'],
#  ['weve',
#   'sensed',
#   'it.',
#   'weve',
#   'seen',
#   'the',
#   'signs.',
#   'now...',
#   'its',
#   'happening.'],
#  ['theres',
#   'only',
#   'one',
#   'passion',
#   'more',
#   'uncontrollable',
#   'than',
#   'love.'],
#  ['be', 'unafraid.be', 'very', 'unafraid.'],
#  ['first',
#   'they',
#   'made',
#   'him',
#   'dangerous.',
#   'then',
#   'they',
#   'made',
#   'him',
#   'mad.'],
#  ['the', 'best', 'place', 'to', 'find', 'yourself.'],
#  ['all', 'she', 'wants', 'is', 'hell', 'on', 'earth'],
#  ['meet', 'the', 'original', 'force', 'of', 'nature.'],
#  ['cursed',
#   'for',
#   'eternity...no',
#   'force',
#   'in',
#   'heaven',
#   'will',
#   'release',
#   'them.',
#   'no',
#   'power',
#   'on',
#   'earth',
#   'can',
#   'save',
#   'them.',
#   'uk',
#   'theatrical'],
#  ['they',
#   'havent',
#   'quite',
#   'figured',
#   'it',
#   'all',
#   'out',
#   'but',
#   'theyre',
#   'getting',
#   'a',
#   'little',
#   'warmer.'],
#  ['choose',
#   'to',
#   'believe.',
#   'choose',
#   'to',
#   'fight.',
#   'choose',
#   'to',
#   'love.',
#   'choose',
#   'to',
#   'listen.'],
#  ['youre', 'never', 'too', 'old', 'to', 'get', 'even.'],
#  ['play', 'at', 'your', 'own', 'risk.'],
#  ['the',
#   'future',
#   'of',
#   'the',
#   'galaxy',
#   'and',
#   'the',
#   'survival',
#   'of',
#   'a',
#   'race',
#   'depend',
#   'on',
#   'an',
#   'act',
#   'of',
#   'rebellion'],
#  ['when', 'the', 'howling', 'starts...', 'the', 'horror', 'begins'],
#  ['deadly.', 'forbidden.', 'and', 'alive.'],
#  ['gordon', 'never', 'gives', 'up'],
#  ['no',
#   'one',
#   'has',
#   'ever',
#   'escaped',
#   'from',
#   'alcatraz...',
#   'and',
#   'no',
#   'one',
#   'ever',
#   'will'],
#  ['there', 'are', 'no', 'answers.', 'only', 'choices.'],
#  ['in',
#   'times',
#   'like',
#   'these',
#   'see',
#   'a',
#   'movie',
#   'about',
#   'love',
#   'and',
#   'humanity'],
#  ['earthmen', 'on', 'a', 'fabulous', 'periljourney', 'into', 'outer', 'space'],
#  ['theres',
#   'no',
#   'rule',
#   'book',
#   'for',
#   'finding',
#   'happiness',
#   'in',
#   'life.'],
#  ['everyone', 'gets', 'old.', 'not', 'everyone', 'grows', 'up.'],
#  ['it',
#   'took',
#   'them',
#   '17',
#   'years',
#   'to',
#   'learn',
#   'the',
#   'rules.',
#   'and',
#   'one',
#   'week',
#   'to',
#   'break',
#   'them',
#   'all.'],
#  ['a',
#   'story',
#   'as',
#   'warm',
#   'and',
#   'moving',
#   'as',
#   'going',
#   'my',
#   'way...but',
#   'with',
#   'brass',
#   'knuckles'],
#  ['everythings', 'better', 'with', 'maturity'],
#  ['holli', 'would', 'if', 'she', 'could', '...and', 'she', 'will'],
#  ['a',
#   'crosscountry',
#   'trip.',
#   'an',
#   'unexpected',
#   'breakdown.',
#   'the',
#   'trap',
#   'has',
#   'been',
#   'set.'],
#  ['brian',
#   'de',
#   'palma',
#   'the',
#   'modern',
#   'master',
#   'of',
#   'suspense',
#   'invites',
#   'you',
#   'witnessa',
#   'seduction.',
#   'a',
#   'mystery.',
#   'a',
#   'murder.'],
#  ['they',
#   'came',
#   'from',
#   'above...',
#   '...and',
#   'attacked',
#   'from',
#   'below.',
#   'uk',
#   'video',
#   'box'],
#  ['the', 'antiwar', 'satire', 'of', 'epic', 'proportions.'],
#  ['the', 'legendary', 'cult', 'classic'],
#  ['welcome', 'to', 'a', 'world', 'where', 'anything', 'is', 'possible.'],
#  ['its', 'not', 'an', 'incident', 'its', 'the', 'works'],
#  ['you', 'like', 'to', 'watch...', 'dont', 'you'],
#  ['it', 'was', 'only', 'a', 'matter', 'of', 'time.'],
#  ['the', 'chase', 'is', 'on'],
#  ['the', 'most', 'beautiful', 'place', 'to', 'be', 'is', 'in', 'love.'],
#  ['kono',
#   'kuni',
#   'wa',
#   'mada',
#   'hont',
#   'no',
#   'hero',
#   'wo',
#   'shiranai',
#   'japan',
#   'this',
#   'land',
#   'doesnt',
#   'know',
#   'a',
#   'real',
#   'hero.',
#   'yet.'],
#  ['its', 'going', 'to', 'be', 'a', 'long', 'night.'],
#  ['ska2oosh'],
#  ['the', 'trap', 'is', 'set.'],
#  ['a', 'movie', 'with', 'a', 'lot', 'of', 'balls.'],
#  ['some', 'dates', 'start', 'with', 'a', 'kiss.'],
#  ['youve', 'got', 'to', 'play', 'the', 'hand', 'youre', 'dealt.'],
#  ['my',
#   'city',
#   'screams.',
#   'she',
#   'is',
#   'my',
#   'lover.',
#   'and',
#   'i',
#   'am',
#   'her',
#   'spirit.'],
#  ['let', 'love', 'lie.'],
#  ['one',
#   'man',
#   'is',
#   'copying',
#   'the',
#   'most',
#   'notorious',
#   'killers',
#   'in',
#   'history',
#   'one',
#   'at',
#   'a',
#   'time.',
#   'together',
#   'two',
#   'women',
#   'must',
#   'stop',
#   'him',
#   'from',
#   'killing',
#   'again.',
#   'or',
#   'theyre',
#   'next.'],
#  ['can', 'you', 'trust', 'a', 'witness', 'who', 'wasnt', 'there'],
#  ['la',
#   'verdadera',
#   'historia',
#   'del',
#   'origen',
#   'del',
#   'narcotrfico.',
#   'the',
#   'true',
#   'story',
#   'of',
#   'the',
#   'origins',
#   'of',
#   'drug',
#   'trafficking.'],
#  ['no', 'more', 'mr.', 'nice', 'guy'],
#  ['through',
#   'the',
#   'eye',
#   'of',
#   'the',
#   'cat',
#   'a',
#   'twisted',
#   'tail',
#   'of',
#   'macabre',
#   'suspense',
#   'from',
#   'the',
#   'author',
#   'of',
#   'carrie',
#   'the',
#   'shining',
#   'and',
#   'the',
#   'dead',
#   'zone.'],
#  ['the', 'dead', 'have', 'waited.', 'the', 'day', 'has', 'come.'],
#  ['two',
#   'people',
#   'with',
#   'their',
#   'backs',
#   'to',
#   'the',
#   'ancient',
#   'wall',
#   'of',
#   'china'],
#  ['what', 'if', '...being', 'friends', 'has', 'its', 'benefits'],
#  ['trying', 'to', 'fit', 'in.', 'born', 'to', 'stand', 'out.'],
#  ['some', 'things', 'arent', 'meant', 'to', 'be', 'found.'],
#  ['the',
#   'year',
#   'is',
#   '1766...',
#   'the',
#   'hunt',
#   'for',
#   'a',
#   'killer',
#   'has',
#   'begun'],
#  ['dont', 'focus', 'on', 'what', 'if.', 'focus', 'on', 'what', 'is.'],
#  ['just',
#   'when',
#   'you',
#   'thought',
#   'it',
#   'was',
#   'safe',
#   'to',
#   'go',
#   'back',
#   'in',
#   'the',
#   'torture',
#   'dungeon...'],
#  ['mankind', 'has', 'an', 'expiration', 'date'],
#  ['how',
#   'far',
#   'would',
#   'you',
#   'go',
#   'how',
#   'much',
#   'would',
#   'you',
#   'sacrifice',
#   'to',
#   'get',
#   'back',
#   'what',
#   'you',
#   'have',
#   'lost'],
#  ['the', 'future', 'is', 'in', 'their', 'hands'],
#  ['a', 'comedy', 'of', 'sexual', 'disorientation'],
#  ['i', 'was', 'feeling', 'blue', 'but', 'im', 'better', 'now.'],
#  ['there', 'are', 'no', 'bad', 'words...', 'only', 'bad', 'deeds.'],
#  ['according',
#   'to',
#   'science',
#   'bigfoot',
#   'doesnt',
#   'exist.',
#   'when',
#   'you',
#   'cant',
#   'believe',
#   'your',
#   'eyes',
#   'trust',
#   'your',
#   'heart.'],
#  ['some', 'mistakes', 'wont', 'let', 'go.'],
#  ['a', 'city', 'will', 'fall.', 'a', 'hero', 'will', 'rise.'],
#  ['fantasy', 'beyond', 'your', 'imagination'],
#  ['three', 'young', 'friends...', 'one', 'last', 'chance.'],
#  ['in',
#   'the',
#   'very',
#   'near',
#   'future',
#   'a',
#   'small',
#   'group',
#   'of',
#   'americans',
#   'and',
#   'russians',
#   'set',
#   'out',
#   'on',
#   'the',
#   'greatest',
#   'adventure',
#   'of',
#   'them',
#   'all...',
#   'to',
#   'see',
#   'if',
#   'there',
#   'is',
#   'life',
#   'beyond',
#   'the',
#   'stars'],
#  ['do', 'not', 'leave', 'the', 'path.'],
#  ['are',
#   'you',
#   'a',
#   'stepford',
#   'wife',
#   'are',
#   'you',
#   'a',
#   'stepford',
#   'husband',
#   'couple',
#   'ask',
#   'yourselves',
#   'would',
#   'you',
#   'move',
#   'to',
#   'stepford'],
#  ['you', 'will', 'believe', 'a', 'man', 'can', 'ride', 'a', 'bike.'],
#  ['after', 'school.', 'parking', 'lot.', 'its', 'on.'],
#  ['you',
#   'are',
#   'cordially',
#   'invited',
#   'to',
#   'the',
#   'most',
#   'surprising',
#   'merger',
#   'of',
#   'the',
#   'year.'],
#  ['a',
#   'story',
#   'about',
#   'how',
#   'far',
#   'we',
#   'must',
#   'travel',
#   'to',
#   'find',
#   'the',
#   'place',
#   'where',
#   'we',
#   'belong.'],
#  ['terror', 'has', 'evolved.'],
#  ['everything', 'is', 'connected'],
#  ['hope', 'runs', 'deep'],
#  ['you', 'will', 'believe.'],
#  ['you', 'can', 'dangle.'],
#  ['filthy.', 'rich.', 'spoilt.', 'rotten.'],
#  ['a', 'night', 'youll', 'never', 'remember'],
#  ['it',
#   'was',
#   'just',
#   'an',
#   'innocent',
#   'game...',
#   'until',
#   'a',
#   'young',
#   'girl',
#   'vanished',
#   'for',
#   'thirty',
#   'years'],
#  ['shy.',
#   'sensitive.',
#   'lawabiding.',
#   'polite.',
#   'repsectful.i',
#   'dont',
#   'think',
#   'so.'],
#  ['loyalty.', 'honor.', 'betrayal.'],
#  ['alice',
#   'is',
#   '35.',
#   'her',
#   'son',
#   'is',
#   '12.',
#   'together',
#   'theyre',
#   'running',
#   'away',
#   'from',
#   'home.'],
#  ['at', 'last', 'the', 'night', 'has', 'a', 'hero.'],
#  ['nothing',
#   'is',
#   'more',
#   'desirable',
#   'or',
#   'more',
#   'deadly',
#   'than',
#   'a',
#   'woman',
#   'with',
#   'a',
#   'secret'],
#  ['prepare', 'for', 'the', 'apocalypse.'],
#  ['revenge', 'never', 'gets', 'old.'],
#  ['1500',
#   'slaves.',
#   '353260000',
#   'royal',
#   'subjects.',
#   'warlords.',
#   'concubines.',
#   'and',
#   '2',
#   'wives.',
#   'he',
#   'was',
#   'the',
#   'loneliest',
#   'boy',
#   'in',
#   'the',
#   'world.'],
#  ['a', 'love', 'story'],
#  ['when', 'everyone', 'is', 'connected', 'no', 'one', 'is', 'safe'],
#  ['set', 'your', 'power', 'free.'],
#  ['a', 'castle', 'can', 'only', 'have', 'one', 'king'],
#  ['warrior.', 'legend.', 'king.'],
#  ['love', 'stings'],
#  ['nothing', 'human', 'loves', 'forever'],
#  ['back', 'together', 'for', 'the', 'first', 'time', 'again.'],
#  ['can', 'you', 'explain', 'your', 'place', 'in', 'the', 'universe'],
#  ['open', 'house'],
#  ['steve',
#   'martin',
#   'had',
#   'no',
#   'reason',
#   'to',
#   'panic...until',
#   'john',
#   'candy',
#   'came',
#   'along.'],
#  ['let', 'desire', 'be', 'your', 'destiny.'],
#  ['when', 'the', 'road', 'ends', 'the', 'battle', 'for', 'survival', 'begins'],
#  ['finally',
#   'the',
#   'movie',
#   'that',
#   'proves',
#   'that',
#   'justice',
#   'isnt',
#   'always',
#   'poetic',
#   'jungle',
#   'fever',
#   'isnt',
#   'always',
#   'pretty',
#   'and',
#   'higher',
#   'learning',
#   'can',
#   'be',
#   'a',
#   'waste',
#   'of',
#   'time.'],
#  ['this', 'time...', 'theyve', 'really', 'gone'],
#  ['sometimes',
#   'it',
#   'is',
#   'preferable',
#   'not',
#   'to',
#   'travel',
#   'with',
#   'a',
#   'dead',
#   'man.'],
#  ['all', 'the', 'adventure', 'your', 'imagination', 'can', 'hold.'],
#  ['youre', 'never', 'quite', 'ready', 'for', 'what', 'life', 'delivers.'],
#  ['this', 'june', 'evolution', 'begins'],
#  ['coming', 'soon', 'to', 'theaters', 'everywhere...', 'okay'],
#  ['they', 'knew', 'too', 'much'],
#  ['on',
#   'december',
#   '21',
#   'put',
#   'a',
#   'little',
#   'tingle',
#   'in',
#   'your',
#   'jingle.'],
#  ['this', 'christmas', 'you', 'better', 'watch', 'out'],
#  ['a', 'motion', 'picture', 'experience', 'for', 'everyone'],
#  ['from', 'the', 'director', 'of', 'the', 'bourne', 'identity.'],
#  ['three', 'officers', 'one', 'bloody', 'night.'],
#  ['his', 'courage', 'made', 'them', 'champions.'],
#  ['the', 'greatest', 'hero', 'ever', 'assembled'],
#  ['roll', 'over', 'beethovenits', 'freddys', 'fifth'],
#  ['he', 'tamed', 'the', 'west...', 'but', 'could', 'he', 'tame', 'her'],
#  ['where', 'does', 'a', 'mother', 'end', 'and', 'a', 'daughter', 'begin'],
#  ['8', 'wheels.', '1', 'family.', 'no', 'brakes.', 'australia', 'theatrical'],
#  ['when',
#   'someone',
#   'does',
#   'you',
#   'a',
#   'big',
#   'favor',
#   'dont',
#   'pay',
#   'it',
#   'back...',
#   'pay',
#   'it',
#   'forward'],
#  ['trapped',
#   'outside',
#   'the',
#   'boundaries',
#   'of',
#   'time',
#   'and',
#   'space...',
#   '102',
#   'aircraft...',
#   '6000',
#   'men...',
#   'all',
#   'missing.'],
#  ['the', 'crime', 'is', 'clear.the', 'truth', 'is', 'not.'],
#  ['whats', 'in', 'his', 'head'],
#  ['it', 'only', 'looks', 'like', 'the', 'good', 'life.'],
#  ['vi', 'trodde', 'aldrig', 'det', 'skulle', 'hnda', 'oss'],
#  ['theyre', 'up', 'to', 'something', 'big.'],
#  ['prayer', 'is', 'a', 'powerful', 'weapon'],
#  ['the', 'only', 'person', 'you', 'need', 'to', 'be', 'is', 'yourself.'],
#  ['its', 'on', 'in', 'the', 'amazon'],
#  ['carolines',
#   'a',
#   'rising',
#   'executive.',
#   'jack',
#   'just',
#   'lost',
#   'his',
#   'job.',
#   'jacks',
#   'going',
#   'to',
#   'have',
#   'to',
#   'start',
#   'from',
#   'the',
#   'bottom',
#   'up.'],
#  ['left',
#   'for',
#   'dead',
#   'on',
#   'a',
#   'remote',
#   'planet',
#   'for',
#   'obsolete',
#   'machines',
#   'and',
#   'people',
#   'a',
#   'fallen',
#   'hero',
#   'has',
#   'one',
#   'last',
#   'battle',
#   'to',
#   'fight'],
#  ['the', 'battle', 'of', 'the', 'kung', 'fu', 'kings'],
#  ['she',
#   'was',
#   'having',
#   'a',
#   'perfectly',
#   'bad',
#   'day...',
#   'then',
#   'he',
#   'came',
#   'along',
#   'and',
#   'spoiled',
#   'it.'],
#  ['coming', 'home', 'was', 'only', 'the', 'beginning'],
#  ['no', 'one', 'knows', 'youre', 'up', 'there.'],
#  ['tonight', 'his', 'take', 'home', 'pay', 'is', '410000...tax', 'free.'],
#  ['the', 'girl', 'who', 'fell', 'to', 'earth.'],
#  ['their', 'song', 'will', 'haunt', 'you.'],
#  ['if',
#   'you',
#   'lived',
#   'in',
#   'this',
#   'town',
#   'youd',
#   'be',
#   'dead',
#   'by',
#   'now.'],
#  ['run.'],
#  ['you',
#   'think',
#   'you',
#   'know',
#   'about',
#   'dreams...',
#   'you',
#   'know',
#   'nothing'],
#  ['the',
#   'enterprise',
#   'is',
#   'back.',
#   'this',
#   'time',
#   'have',
#   'they',
#   'gone',
#   'too',
#   'far'],
#  ['love...', 'unexpected.'],
#  ['how', 'do', 'we', 'explain', 'the', 'impossible'],
#  ['theres',
#   'a',
#   'reason',
#   'weve',
#   'never',
#   'gone',
#   'back',
#   'to',
#   'the',
#   'moon.'],
#  ['there',
#   'are',
#   'two',
#   'things',
#   'a',
#   'woman',
#   'knows',
#   'what',
#   'shes',
#   'looking',
#   'for',
#   'and',
#   'what',
#   'shell',
#   'settle',
#   'for.'],
#  ['dont', 'mess', 'with', 'people', 'who', 'have', 'other', 'people'],
#  ['you',
#   'cant',
#   'trust',
#   'your',
#   'mother...your',
#   'best',
#   'friend...your',
#   'neighbor',
#   'next',
#   'door...'],
#  ['one', 'more', 'chance', 'one', 'more', 'time.'],
#  ['where', 'the', 'dead', 'are', 'no', 'longer', 'that', 'way...'],
#  ['some', 'girls', 'just', 'want', 'to', 'watch', 'the', 'world', 'burn.'],
#  ['hows', 'your', 'faith', 'these', 'days'],
#  ['the',
#   'greatest',
#   'adventure',
#   'a',
#   'man',
#   'ever',
#   'lived...with',
#   'a',
#   'woman'],
#  ['marriage', 'cant', 'stop', 'love...'],
#  ['your', 'senses', 'will', 'never', 'be', 'the', 'same'],
#  ['one', 'wrong', 'turn', 'deserves', 'another'],
#  ['they',
#   'were',
#   'told',
#   'no',
#   'because',
#   'they',
#   'were',
#   'women.',
#   'this',
#   'is',
#   'the',
#   'true',
#   'story',
#   'that',
#   'proved',
#   'everyone',
#   'wrong'],
#  ['im', 'not', 'santa', 'clause', 'all', 'right', 'japanese', 'dvd'],
#  ['terror', 'enters', 'a', 'new', 'face'],
#  ['theres', 'a', 'demon', 'inside'],
#  ['if', 'youve', 'never', 'seen', 'a', 'ghost...', 'look', 'closer.'],
#  ['...',
#   'gnulegeips',
#   'redej',
#   'retnih',
#   'treual',
#   'neuarg',
#   'sad',
#   'german',
#   'backwards',
#   'the',
#   'evil',
#   'lurks',
#   'behind',
#   'every',
#   'reflection',
#   '...'],
#  ['its', 'all', 'about', 'getting', 'off.'],
#  ['jack',
#   'powell',
#   'is',
#   'about',
#   'to',
#   'tackle',
#   'his',
#   'biggest',
#   'adventure',
#   'ever...fifth',
#   'grade'],
#  ['the', 'fear', 'is', 'spreading'],
#  ['watch', 'and', 'learn', 'this', 'april'],
#  ['if',
#   'they',
#   'get',
#   'caught',
#   'its',
#   'all',
#   'over.',
#   'if',
#   'they',
#   'dont',
#   'its',
#   'just',
#   'the',
#   'beginning'],
#  ['hes',
#   'the',
#   'first',
#   'hero',
#   'of',
#   'the',
#   '21st',
#   'century...and',
#   'hes',
#   'our',
#   'only',
#   'hope.'],
#  ['greatest',
#   'odyssey',
#   'of',
#   'the',
#   'agesfor',
#   'the',
#   'first',
#   'time',
#   'on',
#   'the',
#   'screen'],
#  ['in',
#   'the',
#   'battle',
#   'for',
#   'justice',
#   'and',
#   'equality',
#   'the',
#   'satanic',
#   'temple',
#   'is',
#   'putting',
#   'up',
#   'a',
#   'hell',
#   'of',
#   'a',
#   'fight.'],
#  ['look', 'up'],
#  ['halloween', 'blood', 'drive'],
#  ['he', 'wrote', 'to', 'her', 'about', 'her', 'and', 'for', 'her.'],
#  ['a', 'voyage', 'into', 'fear.'],
#  ['insanity', 'is', 'infectious', 'uk', 'poster'],
#  ['it',
#   'destroyed',
#   'his',
#   'world.',
#   'he',
#   'wont',
#   'let',
#   'it',
#   'destroy',
#   'ours.'],
#  ['dont', 'judge', 'a', 'cop', 'by', 'his', 'cover.'],
#  ['the', 'futures', 'most', 'wanted', 'fugitive.'],
#  ['an', 'empire', 'lies', 'in', 'the', 'balance.'],
#  ['the', 'most', 'controversial', 'picture', 'of', 'our', 'time'],
#  ['because', 'everybody', 'needs', 'a', 'friend.'],
#  ['walt',
#   'disneys',
#   'mighty',
#   'magnificent',
#   'memorable',
#   '20000',
#   'leagues',
#   'under',
#   'the',
#   'sea'],
#  ['one',
#   'passion',
#   'wont',
#   'be',
#   'ignored.',
#   'one',
#   'love',
#   'wont',
#   'be',
#   'forgotten.'],
#  ['time', 'heals', 'the', 'heart.', 'faith', 'heals', 'the', 'rest.'],
#  ['she', 'would', 'kill', 'to', 'be', 'famous.'],
#  ['a', 'great', 'adventure'],
#  ['from',
#   'the',
#   'team',
#   'that',
#   'assembled',
#   'the',
#   'lego',
#   'movie',
#   'and',
#   'the',
#   'lego',
#   'batman',
#   'movie'],
#  ['the', 'story', 'of', 'the', 'man', 'who', 'taught', 'bruce', 'lee.'],
#  ['its', 'on'],
#  ['save', 'the', 'world', 'one', 'child', 'at', 'a', 'time.'],
#  ['two',
#   'friends',
#   'that',
#   'didnt',
#   'know',
#   'they',
#   'were',
#   'supposed',
#   'to',
#   'be',
#   'enemies.'],
#  ['from',
#   'the',
#   'novel',
#   'that',
#   'enthralled',
#   'the',
#   'world',
#   'comes',
#   'an',
#   'animation',
#   'classic.'],
#  ['based',
#   'on',
#   'the',
#   'true',
#   'story',
#   'of',
#   'one',
#   'woman',
#   'who',
#   'defied',
#   'an',
#   'empire.'],
#  ['fear', 'blinds', 'the', 'truth'],
#  ['the',
#   'shooting',
#   'saga',
#   'of',
#   'beattie',
#   'who',
#   'bought',
#   'the',
#   'law',
#   'to',
#   'sundown...murder',
#   'town',
#   'original',
#   'poster'],
#  ['every', 'one', 'has', 'a', 'dark', 'side.'],
#  ['hes', 'armed', 'but', 'shes', 'dangerous.'],
#  ['shes', 'to', 'die', 'for.'],
#  ['what', 'comes', 'next'],
#  ['in', 'exciting', '4track', 'stereo'],
#  ['nothing',
#   'left',
#   'to',
#   'live',
#   'for......everything',
#   'to',
#   'fight',
#   'for'],
#  ['one', 'hour.', 'one', 'exit.', 'who', 'will', 'survive'],
#  ['enjoy', 'the', 'show.'],
#  ['it', 'could', 'be', 'tomorrow'],
#  ['a',
#   'rebellious',
#   'young',
#   'man.',
#   'with',
#   'his',
#   'own',
#   'vision',
#   'of',
#   'the',
#   'future.',
#   'and',
#   'his',
#   'own',
#   'fantasy',
#   'of',
#   'love.'],
#  ['together', 'they', 'take', 'on', 'hitlers', 'war', 'machine'],
#  ['there',
#   'are',
#   'moments',
#   'that',
#   'test',
#   'us',
#   'and',
#   'choices',
#   'that',
#   'define',
#   'us.'],
#  ['the', 'oddest', 'couple', 'ever', 'unleashed'],
#  ['saving', 'the', 'neighborhood', 'one', 'sole', 'at', 'a', 'time.'],
#  ['fear', 'the', 'dark'],
#  ['killing',
#   'a',
#   'priest',
#   'on',
#   'a',
#   'sunday.',
#   'thatll',
#   'be',
#   'a',
#   'good',
#   'one.'],
#  ['three',
#   'unforgettable',
#   'love',
#   'stories',
#   'told',
#   'against',
#   'the',
#   'background',
#   'of',
#   'a',
#   'world',
#   'war.',
#   'three',
#   'hours',
#   'and',
#   'twentyeight',
#   'minutes',
#   'of',
#   'incomparable',
#   'entertainment...youll',
#   'wish',
#   'there',
#   'were',
#   'more'],
#  ['a',
#   'journey',
#   'of',
#   '2755.8',
#   'miles',
#   'begins',
#   'with',
#   'a',
#   'single',
#   'bounce.'],
#  ['on', 'this', 'river', 'god', 'never', 'finished', 'his', 'creation.'],
#  ['theyre', 'back'],
#  ['honor', 'was', 'their', 'code.'],
#  ['to', 'her', 'trouble', 'comes', 'supernaturally.'],
#  ['you', 'wont', 'believe', 'your', 'ice'],
#  ['love', 'is', 'a', 'monster.'],
#  ['the', 'legend', 'continues', 'the', 'grandmaster', 'returns.'],
#  ['a', 'nightmare', 'alive'],
#  ['a',
#   'martial',
#   'arts',
#   'master',
#   'so',
#   'powerful',
#   'he',
#   'hesitated',
#   'to',
#   'unleash',
#   'that',
#   'power...until',
#   'the',
#   'day',
#   'he',
#   'couldnt',
#   'hesitate',
#   'any',
#   'longer.'],
#  ['some', 'soldiers', 'take', 'things', 'too', 'far'],
#  ['champions', 'can', 'come', 'from', 'anywhere'],
#  ['escape', 'from', 'new', 'america.'],
#  ['whatever', 'you', 'dodont', 'answer', 'the', 'phone.'],
#  ['just',
#   'when',
#   'you',
#   'think',
#   'youve',
#   'found',
#   'the',
#   'right',
#   'guy',
#   'someone',
#   'even',
#   'worse',
#   'comes',
#   'along.'],
#  ['fear', 'is', 'a', 'place.'],
#  ['the', 'biggest', 'kick', 'of', 'the', 'year'],
#  ['this',
#   'is',
#   'the',
#   'great',
#   'film',
#   'he',
#   'has',
#   'been',
#   'working',
#   'on',
#   'for',
#   'a',
#   'whole',
#   'year'],
#  ['between', 'innocence', 'and', 'evil', 'lies', 'the', 'seduction.'],
#  ['the',
#   'audiences',
#   'dont',
#   'just',
#   'see',
#   'itthey',
#   'talk',
#   'to',
#   'it',
#   'they',
#   'cheer',
#   'it',
#   'they',
#   'roar',
#   'with',
#   'it',
#   'they',
#   'explode',
#   'with',
#   'it',
#   'they',
#   'love',
#   'it'],
#  ['twin',
#   'girls',
#   'haunt',
#   'a',
#   'new',
#   'girl',
#   'in',
#   'town',
#   'to',
#   'steer',
#   'her',
#   'down',
#   'the',
#   'path',
#   'to',
#   'the',
#   'right',
#   'killer.'],
#  ['the', 'legend', 'is', 'reborn...'],
#  ['all', 'the', 'children', 'are', 'gone...', 'except', 'one.'],
#  ['consider', 'the', 'possibilities'],
#  ['the',
#   'dark',
#   'knight',
#   'fights',
#   'to',
#   'save',
#   'gotham',
#   'city',
#   'from',
#   'its',
#   'deadliest',
#   'enemy.'],
#  ['they',
#   'were',
#   'two',
#   'live',
#   'wires',
#   'in',
#   'a',
#   'deadend',
#   'town',
#   'both',
#   'searching',
#   'for',
#   'the',
#   'only',
#   'family',
#   'theyd',
#   'ever',
#   'known...each',
#   'other.'],
#  ['between',
#   'the',
#   'worlds',
#   'of',
#   'the',
#   'living',
#   'and',
#   'the',
#   'dead',
#   'there',
#   'is',
#   'a',
#   'place',
#   'youre',
#   'not',
#   'supposed',
#   'to',
#   'stay.'],
#  ['a',
#   'rusty',
#   'sub.',
#   'a',
#   'rebel',
#   'commander.',
#   'a',
#   'renegade',
#   'crew.',
#   'when',
#   'destiny',
#   'called',
#   'they',
#   'should',
#   'have',
#   'hung',
#   'up.'],
#  ['she',
#   'has',
#   'the',
#   'best',
#   'of',
#   'both',
#   'worlds...',
#   'now',
#   'she',
#   'has',
#   'to',
#   'pick',
#   'just',
#   'one.'],
#  ['he',
#   'didnt',
#   'come',
#   'looking',
#   'for',
#   'trouble',
#   'but',
#   'trouble',
#   'came',
#   'looking',
#   'for',
#   'him.'],
#  ['with',
#   'love',
#   'comes',
#   'risk.',
#   'with',
#   'obsession',
#   'comes...',
#   'damage.'],
#  ['you', 'will', 'believe', 'a', 'squirrel', 'can', 'fly.'],
#  ['jag',
#   'ska',
#   'aldrig',
#   'mer',
#   'bli',
#   'ihop',
#   'med',
#   'nn.',
#   'jag',
#   'ska',
#   'bli',
#   'celibat.'],
#  ['every', 'moment', 'another', 'story', 'begins'],
#  ['i', 'wish', 'i', 'could', 'say', 'i', 'was', 'sorry.'],
#  ['was', 'shakespeare', 'a', 'fraud'],
#  ['its',
#   'her',
#   'last',
#   'best',
#   'chance...',
#   'is',
#   'she',
#   'going',
#   'to',
#   'take',
#   'it'],
#  ['it', 'melts'],
#  ['see...',
#   'a',
#   'universe',
#   'on',
#   'the',
#   'rocks',
#   'see...',
#   'great',
#   'special',
#   'affects',
#   'see...',
#   'space',
#   'herpie',
#   'the',
#   'love',
#   'bug',
#   'see...',
#   'the',
#   'evil',
#   'emperor',
#   'and',
#   'his',
#   'bird',
#   'see...',
#   'actionpacked',
#   'action',
#   'see',
#   'ferocious',
#   'space',
#   'possums'],
#  ['theyre', 'real', 'gone...into', 'another', 'whirl'],
#  ['anxiety', 'loves', 'company.'],
#  ['everything', 'you', 'know', 'about', 'desire', 'is', 'dead', 'wrong.'],
#  ['love', 'me', 'or', 'leave', 'me.'],
#  ['what',
#   'are',
#   'the',
#   'consequences',
#   'of',
#   'giving',
#   'birth',
#   'to',
#   'your',
#   'dead',
#   'boyfriend'],
#  ['see',
#   'all',
#   'of',
#   'the',
#   'famed',
#   'characters',
#   'in',
#   'erich',
#   'maria',
#   'remarques',
#   'worldstirring',
#   'novellouis',
#   'wolheim',
#   'as',
#   'katzcinsky',
#   'lewis',
#   'ayres',
#   'as',
#   'paul',
#   'baumer',
#   'john',
#   'wray',
#   'as',
#   'sergeant',
#   'himmelstoss.',
#   'see',
#   'tjaden',
#   'the',
#   'french',
#   'girls',
#   'across',
#   'the',
#   'canal',
#   'pauls',
#   'motherevery',
#   'one',
#   'of',
#   'the',
#   'folks',
#   'in',
#   'the',
#   'book',
#   'is',
#   'here'],
#  ['the', 'apocalypse', 'was', 'just', 'the', 'beginning'],
#  ['young.', 'not', 'so', 'innocent.'],
#  ['there', 'are', 'no', 'rules.', 'uk', 'dvd'],
#  ['every', 'mom', 'deserves', 'a', 'time', 'out'],
#  ['with', 'spies', 'like', 'these', 'who', 'needs', 'enemies'],
#  ['its', 'unrelenting', 'moments', 'its', 'tragedies', 'and', 'splendors'],
#  ['let', 'your', 'imagination', 'soar.'],
#  ['every', 'year', 'young', 'people', 'disappear'],
#  ['warm',
#   'wet',
#   'bodies',
#   'fresh',
#   'in',
#   'the',
#   'sweet',
#   'heat',
#   'of',
#   'loving.'],
#  ['some',
#   'days',
#   'business',
#   'is',
#   'goodand',
#   'some',
#   'days',
#   'its',
#   'murder'],
#  ['how', 'far', 'would', 'you', 'go...to', 'protect', 'your', 'children'],
#  ['after',
#   'being',
#   'dead',
#   'for',
#   '70',
#   'years.',
#   'she',
#   'wakes',
#   'to',
#   'a',
#   'world',
#   'controlled',
#   'by',
#   'evil.'],
#  ['bud',
#   'and',
#   'doyle',
#   'are',
#   'here',
#   'to',
#   'save',
#   'the',
#   'world.',
#   'but',
#   'whos',
#   'gonna',
#   'save',
#   'the',
#   'world',
#   'from',
#   'bud',
#   'and',
#   'doyle'],
#  ['no', 'work.', 'all', 'play.'],
#  ['the',
#   'united',
#   'states',
#   'supreme',
#   'court',
#   'has',
#   'ruled',
#   'that',
#   'carnal',
#   'knowledge',
#   'is',
#   'not',
#   'obscene.',
#   'see',
#   'it',
#   'now'],
#  ['greed', 'is', 'good.', 'sex', 'is', 'easy.', 'youth', 'is', 'forever.'],
#  ['in',
#   'the',
#   'face',
#   'of',
#   'fear',
#   'they',
#   'found',
#   'strength',
#   'in',
#   'each',
#   'other.'],
#  ['youve',
#   'never',
#   'seen',
#   'or',
#   'heard',
#   'anything',
#   'like',
#   'it',
#   'in',
#   'your',
#   'life'],
#  ['i', 'warned', 'you', 'not', 'to', 'go', 'out', 'tonight'],
#  ['its',
#   'a',
#   'brand',
#   'new',
#   'beginning',
#   'in',
#   'the',
#   'adventure',
#   'that',
#   'never',
#   'ends'],
#  ['life', 'is', 'an', 'occasion.', 'rise', 'to', 'it.'],
#  ['hes',
#   'a',
#   'cop',
#   'who',
#   'believes',
#   'no',
#   'one',
#   'is',
#   'above',
#   'the',
#   'law.'],
#  ['a', 'comedy', 'about', 'sex', 'love', 'and', 'a', 'nose', 'job...'],
#  ['the', 'adventure', 'of', 'two', 'lifetimes.'],
#  ['this',
#   'town',
#   'isnt',
#   'small',
#   'enough',
#   'for',
#   'the',
#   'both',
#   'of',
#   'them.'],
#  ['this', 'is', 'the', 'way', 'it', 'was.'],
#  ['theyre', 'hot'],
#  ['based',
#   'on',
#   'the',
#   'mostly',
#   'true',
#   'story',
#   'of',
#   'the',
#   '30yearold',
#   'who',
#   'just',
#   'hit',
#   'puberty.'],
#  ['when', 'life', 'is', 'on', 'the', 'line', 'there', 'can', 'be', '...'],
#  ['thats', 'all', 'they', 'really', 'want'],
#  ['the', 'evil', 'lives', 'on...', 'can', 'it', 'be', 'stopped'],
#  ['winning', 'is', 'a', 'feeling', 'you', 'never', 'lose.'],
#  ['meet',
#   'morgan',
#   'hiller.',
#   'hes',
#   'a',
#   'rebel',
#   'about',
#   'to',
#   'become',
#   'a',
#   'hero.'],
#  ['theres', 'beauty', 'in', 'the', 'patterns', 'of', 'life.'],
#  ['would', 'you', 'pay', 'her...', 'to', 'have', 'your', 'baby'],
#  ['beneath', 'heaven', 'lies', 'hell', 'beneath', 'hell', 'lies...'],
#  ['love', 'will', 'bring', 'you', 'home.'],
#  ['a',
#   'timeless',
#   'feud.',
#   'a',
#   'forbidden',
#   'love.',
#   'an',
#   'epic',
#   'battle.'],
#  ['a',
#   'giant',
#   'of',
#   'a',
#   'man',
#   'against',
#   'a',
#   'general',
#   'seeking',
#   'glory...a',
#   'spectacular',
#   'adventure',
#   'of',
#   'arch',
#   'enemies',
#   'in',
#   'battle.'],
#  ['if',
#   'they',
#   'knew',
#   'the',
#   'city',
#   'was',
#   'this',
#   'crazy',
#   'they',
#   'would',
#   'have',
#   'stayed',
#   'in',
#   'the',
#   'asylum.',
#   'dvd'],
#  ['psycho', 'wife', 'unhappy', 'life'],
#  ['most',
#   'people',
#   'have',
#   'a',
#   'dark',
#   'side.',
#   'she',
#   'had',
#   'nothing',
#   'else.'],
#  ['every',
#   'house',
#   'has',
#   'a',
#   'history.',
#   'this',
#   'one',
#   'has',
#   'a',
#   'legend.'],
#  ['be', 'careful...', 'she', 'just', 'might', 'take', 'your', 'heart.'],
#  ['paths', 'of', 'grieve', 'intersect', 'on', 'the', 'ganges', 'river.'],
#  ['the', 'pokemon', 'match', 'of', 'all', 'time', 'is', 'here.'],
#  ['apparitions', 'evils', 'corruptions'],
#  ['outrageous', 'adventures', 'in', 'the', 'kingdom', 'of', 'women'],
#  ['jason',
#   'freddy',
#   'myers.',
#   'we',
#   'all',
#   'need',
#   'someone',
#   'to',
#   'look',
#   'up',
#   'to.'],
#  ['its', 'a', 'tough', 'job', 'but', 'somebodys', 'got', 'to', 'do', 'it'],
#  ['revenge', 'was', 'never', 'this', 'sweet'],
#  ['you', 'dont', 'have', 'a', 'chance.', 'seize', 'it'],
#  ['a',
#   'blast',
#   'of',
#   'dramatic',
#   'dynamite',
#   'exploded',
#   'right',
#   'before',
#   'your',
#   'eyes'],
#  ['thrills', 'chills', 'and', 'guitar', 'drills'],
#  ['from', 'the', 'makers', 'of', 'halloween'],
#  ['luchino', 'viscontis', 'enduring', 'romantic', 'adventure'],
#  ['when', 'you', 'dont', 'know', 'who', 'to', 'trust...'],
#  ['an', 'impulsive', 'love', 'story.'],
#  ['subway.', 'a', 'seductive', 'fable.'],
#  ['the', 'purest', 'form', 'of', 'war', 'is', 'one', 'on', 'one.'],
#  ['faith', 'has', 'failed', 'us.'],
#  ['from', 'the', 'director', 'of', 'the', 'brothers', 'mcmullen'],
#  ['a', 'comedy', 'about', 'the', 'game', 'of', 'love.'],
#  ['dont',
# ...
#   'have',
#   'time',
#   'to',
#   'scream...',
#   'before',
#   'it',
#   'tears',
#   'you',
#   'apart'],
#  ['it', 'will', 'move', 'you', 'to', 'love', 'laughter', 'and', 'tears'],
#  ['in',
#   'a',
#   'world',
#   'of',
#   'seduction',
#   'and',
#   'power',
#   'temptation',
#   'has',
#   'its',
#   'price.'],
#  ['the', 'hitchhiker', 'from', 'hell'],
#  ['a', 'stripped', 'down', 'comedy.'],
#  ['the',
#   'father.',
#   'he',
#   'knew',
#   'there',
#   'was',
#   'something',
#   'sinister',
#   'about',
#   'the',
#   'house',
#   'but',
#   'he',
#   'didnt',
#   'know',
#   'what',
#   'it',
#   'was.',
#   'the',
#   'mother.',
#   'she',
#   'was',
#   'living',
#   'in',
#   'the',
#   'house',
#   'but',
#   'she',
#   'didnt',
#   'know',
#   'the',
#   'house',
#   'was',
#   'beginning',
#   'to',
#   'live',
#   'in',
#   'her.',
#   'the',
#   'landlord.',
#   'he',
#   'told',
#   'them',
#   'the',
#   'house',
#   'would',
#   'take',
#   'care',
#   'of',
#   'itself.',
#   'but',
#   'he',
#   'didnt',
#   'tell',
#   'them',
#   'it',
#   'would',
#   'take',
#   'care',
#   'of',
#   'them',
#   'too.',
#   'the',
#   'aunt.',
#   'she',
#   'wanted',
#   'a',
#   'nice',
#   'quiet',
#   'vacationbut',
#   'it',
#   'may',
#   'be',
#   'the',
#   'last',
#   'one',
#   'she',
#   'ever',
#   'takes.',
#   'the',
#   'landlords',
#   'sister.',
#   'she',
#   'asked',
#   'them',
#   'to',
#   'take',
#   'care',
#   'of',
#   'her',
#   'mother',
#   'but',
#   'she',
#   'wouldnt',
#   'tell',
#   'them',
#   'why'],
#  ['a',
#   'daughter',
#   'out',
#   'of',
#   'options.',
#   'a',
#   'father',
#   'out',
#   'of',
#   'time.'],
#  ['theres', 'more', 'to', 'family', 'than', 'what', 'you', 'see.'],
#  ['a',
#   'lost',
#   'city',
#   'a',
#   'man',
#   'of',
#   'destiny',
#   'a',
#   'test',
#   'of',
#   'honor...'],
#  ['sometimes',
#   'you',
#   'have',
#   'to',
#   'break',
#   'the',
#   'rules',
#   'to',
#   'free',
#   'your',
#   'heart.'],
#  ['sent',
#   'to',
#   'a',
#   'country',
#   'shes',
#   'never',
#   'known...',
#   'she',
#   'must',
#   'risk',
#   'everything',
#   'to',
#   'break',
#   'free.'],
#  ['...he', 'lives', 'again', 'to', 'feed', 'again.'],
#  ['fed',
#   'up',
#   'with',
#   'the',
#   'system.',
#   'ticked',
#   'off',
#   'at',
#   'the',
#   'establishment.',
#   'and',
#   'mad',
#   'about...',
#   'each',
#   'other.'],
#  ['hes', 'an', 'operator.', 'hes', 'an', 'optimist.', 'hes', 'a', 'mystery.'],
#  ['can',
#   'anyone',
#   'survive',
#   'the',
#   'demented',
#   'marauding',
#   'zombies',
#   'in...'],
#  ['evil', 'comes', 'home'],
#  ['trapped...',
#   '4',
#   'desperate',
#   'men',
#   'and',
#   'a',
#   'strange',
#   'halfanimal',
#   'girl'],
#  ['the',
#   'rules',
#   'of',
#   'the',
#   'road',
#   'are',
#   'simple.',
#   'dont',
#   'turn',
#   'back.'],
#  ['sex', 'drugs', 'and', 'college', 'stuff'],
#  ['inspired', 'by', 'the', 'mumbai', 'terrorist', 'attacks', '261108'],
#  ['some', 'mysteries', 'should', 'never', 'be', 'solved'],
#  ['a',
#   'sexy',
#   'comedy',
#   'about',
#   'making',
#   'relationships',
#   'more',
#   'delicious.'],
#  ['a',
#   'horror',
#   'story...so',
#   'intense',
#   'so',
#   'barbaric',
#   'so',
#   'frightening...it',
#   'will',
#   'have',
#   'you',
#   'running',
#   'to',
#   'your',
#   'local',
#   'army',
#   'recruiter.'],
#  ['illusion',
#   'sets',
#   'the',
#   'stage.',
#   'deception',
#   'reveals',
#   'the',
#   'truth.'],
#  ['they',
#   'were',
#   'boozin',
#   'it',
#   'brusin',
#   'it',
#   'and',
#   'cruisin',
#   'it',
#   'but',
#   'mostly',
#   'they',
#   'were',
#   '.',
#   '.',
#   '.'],
#  ['for', 'a', 'workout', 'in', 'hell'],
#  ['the',
#   'army',
#   'was',
#   'no',
#   'laughing',
#   'matter',
#   'until',
#   'judy',
#   'benjamin',
#   'joined',
#   'it.'],
#  ['when',
#   'they',
#   'tried',
#   'to',
#   'buy',
#   'him',
#   'he',
#   'refused.',
#   'when',
#   'they',
#   'tried',
#   'to',
#   'bully',
#   'him',
#   'he',
#   'resisted.',
#   'when',
#   'they',
#   'tried',
#   'to',
#   'break',
#   'him',
#   'he',
#   'became',
#   'an',
#   'american',
#   'legend.',
#   'the',
#   'true',
#   'story',
#   'of',
#   'preston',
#   'tucker.'],
#  ['from', 'the', 'creators', 'of', 'hostel', 'and', 'cabin', 'fever'],
#  ['her',
#   'name',
#   'is',
#   'breezy',
#   'and',
#   'love',
#   'was',
#   'all',
#   'they',
#   'had',
#   'in',
#   'common'],
#  ['te', 'flm', 'watchman', 'is', 'a', 'triller', 'genre', 'film'],
#  ['man.', 'metal.', 'hero.'],
#  ['the', 'curse', 'is', 'real'],
#  ['the',
#   'travel',
#   'agency',
#   'promised',
#   'george',
#   'lollar',
#   'a',
#   'peaceful',
#   'island',
#   'getaway.',
#   'they',
#   'lied.'],
#  ['one', 'wish.', 'a', 'thousand', 'regrets.'],
#  ['another', 'bloody', 'office', 'outing.'],
#  ['seduction.', 'betrayal.', 'murder.', 'whos', 'conning', 'who'],
#  ['temptation.', 'seduction.', 'obsession.'],
#  ['a', 'heterosexual', 'film', 'by', 'gregg', 'araki.'],
#  ['no',
#   'man',
#   'can',
#   'posses',
#   'her.',
#   'no',
#   'man',
#   'can',
#   'defeat',
#   'her.',
#   'dvd'],
#  ['nobody', 'is', 'beyond', 'redemption.'],
#  ['no',
#   'matter',
#   'where',
#   'life',
#   'takes',
#   'you...',
#   'faith',
#   'takes',
#   'you',
#   'further.'],
#  ['when',
#   'east',
#   'meets',
#   'west',
#   'the',
#   'laughs',
#   'shift',
#   'into',
#   'high',
#   'gear'],
#  ['you', 'never', 'know', 'whos', 'looking', 'out', 'for', 'you.'],
#  ['under', 'their', 'own', 'command'],
#  ['wait', 'till', 'you', 'see', 'the', 'weird', 'part.', 'usa', 'theatrical'],
#  ['the', 'martian', 'has', 'landed.', 'there', 'goes', 'the', 'neighborhood.'],
#  ['its',
#   'the',
#   'funniest',
#   'operation',
#   'the',
#   'carry',
#   'on',
#   'gang',
#   'ever',
#   'tried'],
#  ['supermegatotally', 'thrilladelic'],
#  ['believe', 'in', 'the', 'impossible'],
#  ['what',
#   'happens',
#   'when',
#   'six',
#   'men',
#   'and',
#   'three',
#   'women',
#   'are',
#   'alone',
#   'in',
#   'an',
#   'open',
#   'boat'],
#  ['the', 'aliens', 'vs.', 'the', 'pearsons'],
#  ['organized', 'crime', 'has', 'never', 'been', 'this', 'disorganized'],
#  ['hunger',
#   'no',
#   'love',
#   '.',
#   '.',
#   '.',
#   'woman',
#   '.',
#   '.',
#   '.',
#   'or',
#   'wealth',
#   'could',
#   'satisfy'],
#  ['the',
#   'bravest',
#   'place',
#   'to',
#   'stand',
#   'is',
#   'by',
#   'each',
#   'others',
#   'side.'],
#  ['a',
#   'gripping',
#   'noirish',
#   'study',
#   'of',
#   'treachery',
#   'identity',
#   'and',
#   'survival.'],
#  ['four',
#   'went.',
#   'three',
#   'came',
#   'back.',
#   'only',
#   'one',
#   'of',
#   'them',
#   'knows',
#   'what',
#   'happened.'],
#  ['too', 'cool', 'for', 'words'],
#  ['words', 'can', 'kill...'],
#  ['let', 'yourself', 'go', '......', 'they', 'do'],
#  ['zombies', 'guns', 'and', 'sex', 'oh', 'my'],
#  ['thrills',
#   'chills',
#   'spills',
#   'live',
#   'the',
#   'power',
#   'of',
#   'the...',
#   'bmx',
#   'bandits'],
#  ['sometimes', 'we', 'have', 'to', 'fall', 'down', 'to', 'grow', 'up'],
#  ['they',
#   'said',
#   'game',
#   '7',
#   'would',
#   'be',
#   'a',
#   'war.',
#   'they',
#   'didnt',
#   'know',
#   'the',
#   'half',
#   'of',
#   'it.'],
#  ['the', 'haunting', 'has', 'come', 'back', 'home.'],
#  ['its', 'been', 'sleeping', 'for', '2000', 'years', 'until', 'now.'],
#  ['vacations', 'can', 'be', 'deadly'],
#  ['every', 'family', 'has', 'a', 'past.'],
#  ['battle', 'for', 'the', 'throne'],
#  ['question', 'what', 'you', 'think', 'is', 'real.'],
#  ['based',
#   'on',
#   'the',
#   'life',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'controversial',
#   'figures',
#   'of',
#   'our',
#   'time.'],
#  ['power', 'conquers', 'all'],
#  ['once', 'upon', 'a', 'time...'],
#  ['his', 'name', 'would', 'never', 'be', 'forgotten.'],
#  ['when',
#   'jackie',
#   'gleason',
#   'told',
#   'his',
#   'son',
#   'he',
#   'could',
#   'have',
#   'any',
#   'present',
#   'he',
#   'wanted',
#   'he',
#   'picked',
#   'the',
#   'most',
#   'outrageous',
#   'gift',
#   'of',
#   'all...',
#   'richard',
#   'pryor.'],
#  ['soldiers', 'of', 'fortune...', 'modern', 'musketeers.'],
#  ['her', 'wedding.', 'his', 'funeral.'],
#  ['its', 'just', 'like', 'paradise', 'only', 'better', 'looking.'],
#  ['the',
#   'only',
#   'thing',
#   'worse',
#   'than',
#   'losing',
#   'your',
#   'mind...',
#   'is',
#   'finding',
#   'it',
#   'again.'],
#  ['sometimes',
#   'the',
#   'smartest',
#   'people',
#   'have',
#   'the',
#   'most',
#   'to',
#   'learn'],
#  ['want',
#   'to',
#   'see',
#   'a',
#   'really',
#   'killer',
#   'websiteits',
#   'the',
#   'last',
#   'site',
#   'youll',
#   'ever',
#   'see.'],
#  ['a', 'comedy', 'of', 'the', 'heart', 'and', 'other', 'organs.'],
#  ['the',
#   'music',
#   'youll',
#   'love',
#   'forever.',
#   'the',
#   'man',
#   'youll',
#   'never',
#   'forget.',
#   'the',
#   'movie',
#   'you',
#   'must',
#   'not',
#   'miss.'],
#  ['the', 'whos', 'who', 'of', 'whodunnits.'],
#  ['words', 'lose', 'their', 'meaning', 'when', 'you', 'repeat', 'them.'],
#  ['are', 'all', 'men', 'bastards...or', 'just', 'misunderstood'],
#  ['between', 'heaven', 'and', 'hell', 'is', 'fear.'],
#  ['not', 'every', 'love', 'happens', 'at', 'first', 'sight.'],
#  ['she', 'found', 'love', 'in', 'the', 'most', 'unexpected', 'of', 'places.'],
#  ['little', 'dudes.', 'big', 'trouble.'],
#  ['seven',
#   'bullets',
#   'from',
#   'here',
#   'his',
#   'woman',
#   'would',
#   'be',
#   'waitingseven',
#   'men',
#   'from',
#   'nowher',
#   'shame',
#   'would',
#   'be',
#   'wiped',
#   'out'],
#  ['the',
#   'creaturesthey',
#   'came',
#   'from',
#   'beyond',
#   'the',
#   'gravethey',
#   'werent',
#   'bornthey',
#   'were',
#   'kicked',
#   'out',
#   'of',
#   'hell'],
#  ['fight', 'first.', 'apologize', 'later.'],
#  ['if',
#   'you',
#   'go',
#   'down',
#   'to',
#   'the',
#   'woods',
#   'today',
#   'youre',
#   'sure',
#   'of...'],
#  ['karma', 'is', 'a', 'bitch'],
#  ['innocence', 'isnt', 'lost...', 'its', 'taken.'],
#  ['welcome', 'to', 'the', 'scariest', 'place', 'on', 'earth'],
#  ['the', 'depraved', 'must', 'die...', 'beware', 'the', 'witch', 'hunter'],
#  ['when', 'the', 'sun', 'sets...', 'the', 'hunt', 'begins'],
#  ['the', 'ancient', 'gods', 'have', 'returned'],
#  ['8th', 'wonder', 'of', 'the', 'screen'],
#  ['for',
#   'everyone',
#   'on',
#   'the',
#   'outside',
#   'looking',
#   'in...',
#   'your',
#   'moment',
#   'has',
#   'arrived'],
#  ['the',
#   'secrets',
#   'that',
#   'hold',
#   'us',
#   'together',
#   'can',
#   'also',
#   'tear',
#   'us',
#   'apart.'],
#  ['if',
#   'you',
#   'thought',
#   'the',
#   'night',
#   'before',
#   'was',
#   'funny',
#   'wait',
#   'till',
#   'you',
#   'see',
#   'the',
#   'next',
#   'day.'],
#  ['welcome', 'to', 'the', 'future', 'of', 'the', 'past.'],
#  ['the',
#   'children',
#   'of',
#   'the',
#   'nazi',
#   'generation',
#   'vowed',
#   'fascism',
#   'would',
#   'never',
#   'rule',
#   'their',
#   'world',
#   'again.'],
#  ['in',
#   'the',
#   'arms',
#   'of',
#   'another',
#   'womans',
#   'man...she',
#   'finds',
#   'her',
#   'man',
#   'original',
#   'print',
#   'adalmost',
#   'all',
#   'caps'],
#  ['the', 'most', 'dangerous', 'man', 'in', 'the', 'world.'],
#  ['this', 'movies', 'been', 'clocked', 'at', '55', 'laughs', 'per', 'minute'],
#  ['two',
#   'rival',
#   'teams',
#   'of',
#   'assassins.',
#   'one',
#   'killer',
#   'day',
#   'at',
#   'the',
#   'office.'],
#  ['these',
#   'are',
#   'the',
#   'daughters',
#   'of',
#   'darkness...',
#   'they',
#   'are',
#   'waiting',
#   'for',
#   'youthey',
#   'thrive',
#   'on',
#   'blood'],
#  ['the',
#   'gunslinger',
#   'whose',
#   'life',
#   'he',
#   'had',
#   'saved',
#   'forced',
#   'him',
#   'to',
#   'stand',
#   'in',
#   'the',
#   'path',
#   'of',
#   'a...',
#   'bullet',
#   'for',
#   'a',
#   'badman'],
#  ['its', 'not', 'just', 'a', 'mans', 'world', 'anymore.'],
#  ['every', 'journey', 'must', 'begin', 'with', 'one', 'small', 'step.'],
#  ['you',
#   'never',
#   'know',
#   'whos',
#   'going',
#   'to',
#   'be',
#   'your',
#   'wakeup',
#   'call'],
#  ['death', 'isnt', 'always', 'the', 'end.'],
#  ['allnew', '3d', 'thills', 'original', 'poster'],
#  ['you', 'cant', 'run', 'from', 'a', 'nightmare'],
#  ['hell', 'hath', 'no', 'fury...'],
#  ['live', 'life', 'like', 'you', 'mean', 'it.'],
#  ['hes',
#   'an',
#   'indestructible',
#   'man',
#   'fused',
#   'with',
#   'powers',
#   'beyond',
#   'comprehension.',
#   'an',
#   'unstoppable',
#   'terror',
#   'who',
#   'in',
#   'one',
#   'final',
#   'showdown',
#   'will',
#   'push',
#   'chuck',
#   'norris',
#   'to',
#   'his',
#   'limits.',
#   'and',
#   'beyond.'],
#  ['this',
#   'school',
#   'year',
#   'experience',
#   'every',
#   'rich',
#   'kids',
#   'nightmare.'],
#  ['dolittle', 'is', 'back'],
#  ['the', 'falconthe', 'snowman.', 'a', 'true', 'story.'],
#  ['fear', 'revisited'],
#  ['not', 'all', 'nightmares', 'happen', 'on', 'elm', 'street.'],
#  ['a',
#   'ruthless',
#   'killer.',
#   'a',
#   'beautiful',
#   'hostage.',
#   'two',
#   'men',
#   'follow',
#   'them',
#   'into',
#   'the',
#   'mountains.',
#   'one',
#   'for',
#   'love.',
#   'one',
#   'for',
#   'revenge.'],
#  ['the',
#   'man',
#   'who',
#   'made',
#   'the',
#   'twenties',
#   'roar',
#   'now',
#   'after',
#   '45',
#   'years',
#   'his',
#   'true',
#   'story',
#   'can',
#   'be',
#   'told'],
#  ['theres', 'a', 'new', 'kid', 'in', 'town.'],
#  ['put', 'christ', 'back', 'in', 'christmas'],
#  ['this', 'sister', 'is', 'one', 'bad', 'mother'],
#  ['stupid',
#   'tricks.',
#   'outrageous',
#   'chaos.',
#   'total',
#   'destruction.',
#   'theyre',
#   'taking',
#   'it',
#   'on',
#   'the',
#   'road.'],
#  ['tom', 'selleck', 'takes', 'you', 'on', 'a', 'high', 'adventure'],
#  ['the',
#   'strange',
#   'adventure',
#   'of',
#   'lemmy',
#   'cautionsecret',
#   'agent',
#   'of',
#   'the',
#   'future'],
#  ['from', 'russia', 'with', 'hate'],
#  ['a', 'comedy', 'that', 'proves', 'love', 'is', 'blind'],
#  ['a',
#   'story',
#   'for',
#   'all',
#   'ages.',
#   'a',
#   'friendship',
#   'for',
#   'all',
#   'time.',
#   'share',
#   'the',
#   'adventure.'],
#  ['the', 'way', 'back', 'begins', 'with', 'a', 'single', 'chord.'],
#  ['the',
#   'writers',
#   'of',
#   'alien...',
#   '...bring',
#   'a',
#   'new',
#   'terror',
#   'to',
#   'earth.'],
#  ['sometimes', 'love', 'needs', 'a', 'rewrite'],
#  ['love', 'has', 'many', 'colors'],
#  ['readin...writin...', 'and', 'radiation'],
#  ['her', 'all', 'new', 'hollywood', 'adventure.', 'usa', 'theatrical'],
#  ['dont',
#   'waste',
#   'money',
#   'on',
#   'a',
#   'return',
#   'fare.',
#   'you',
#   'wont',
#   'be',
#   'coming',
#   'back'],
#  ['dating', 'bites.'],
#  ['raise', 'the', 'woof.'],
#  ['sinbad', 'the', 'greatest', 'of', 'all', 'adventurers'],
#  ['seclusion.', 'seduction.', 'survival.'],
#  ['the',
#   'poignant',
#   'incredible',
#   'story',
#   'of',
#   'a',
#   'man',
#   'whose',
#   'two',
#   'worlds',
#   'collide'],
#  ['beware',
#   'the',
#   'stare',
#   'that',
#   'bewitches',
#   'original',
#   'posterall',
#   'caps'],
#  ['the', 'journey', 'begins', 'this', 'easter'],
#  ['love',
#   'is',
#   'a',
#   'game',
#   'any',
#   'number',
#   'can',
#   'play...',
#   'especially',
#   'in',
#   'the',
#   'afternoon...'],
#  ['not',
#   'since',
#   'don',
#   'quixote',
#   'has',
#   'spain',
#   'had',
#   'so',
#   'much',
#   'fun'],
#  ['a', 'civilized', 'weapon', 'for', 'uncivilized', 'times'],
#  ['the', 'order', 'will', 'find', 'you.'],
#  ['13', '12', 'murders1423', 'laughsstudent', 'bodies'],
#  ['she',
#   'gave',
#   'them',
#   'a',
#   'gift',
#   'they',
#   'could',
#   'never',
#   'imagine.',
#   'they',
#   'gave',
#   'the',
#   'system',
#   'a',
#   'fight',
#   'it',
#   'would',
#   'never',
#   'forget.'],
#  ['upsadaisy', '..', 'downsadaisy', '...', 'turnedonsadaisy'],
#  ['there', 'are', 'no', 'feelings', 'in', 'outer', 'space.'],
#  ['its',
#   'frightening',
#   'to',
#   'think',
#   'they',
#   'did',
#   'it.its',
#   'terrifying',
#   'to',
#   'think',
#   'they',
#   'didnt.'],
#  ['be', 'there...', 'or', 'beheaded'],
#  ['when',
#   'a',
#   'deadly',
#   'conspiracy',
#   'became',
#   'a',
#   'shameful',
#   'coverup',
#   'one',
#   'witness',
#   'refused',
#   'to',
#   'be',
#   'silent.'],
#  ['the', 'assassination', 'was', 'only', 'the', 'beginning.'],
#  ['the',
#   'first',
#   'motion',
#   'picture',
#   'based',
#   'on',
#   'historical',
#   'facts',
#   'about',
#   'the',
#   'rise',
#   'and',
#   'revolt',
#   'of',
#   'slavery',
#   'in',
#   'america.'],
#  ['its', 'not', 'a', 'party', 'until', 'something', 'gets', 'broken.'],
#  ['united', 'by', 'blood', 'divided', 'by', 'fear.'],
#  ['come',
#   'to',
#   'laugh',
#   'come',
#   'to',
#   'cry',
#   'come',
#   'to',
#   'terms...',
#   'again.'],
#  ['the', 'past', 'awaits', 'her.'],
#  ['the', 'hardest', 'soul', 'to', 'save', 'was', 'his', 'own.'],
#  ['inspired', 'by', 'a', 'true', 'story.'],
#  ['n',
#   'ulykke',
#   'kommer',
#   'sjldent',
#   'alene',
#   'scandinavian',
#   'saying',
#   'equivalent',
#   'of',
#   'when',
#   'it',
#   'rains',
#   'it',
#   'pours'],
#  ['this',
#   'is',
#   'willard',
#   'and',
#   'his',
#   'friend',
#   'ben.ben',
#   'will',
#   'do',
#   'anything',
#   'for',
#   'willard.'],
#  ['nothing',
#   'is',
#   'more',
#   'deadly',
#   'than',
#   'a',
#   'woman',
#   'seeking',
#   'revenge.'],
#  ['see', 'doctors', 'transform', 'man', 'to', 'woman'],
#  ['bogart',
#   'rips',
#   'the',
#   'jap',
#   'underworld',
#   'apart',
#   'over',
#   'a',
#   'blonde',
#   'in',
#   'a',
#   'tokyo',
#   'hot',
#   'spot'],
#  ...]

# %%
# vocabulary for sources
s_vocab = list(set(sum(sources, [])))
s_vocab.sort()
s_vocab = ['<pad>'] + s_vocab
source2idx = {word : idx for idx, word in enumerate(s_vocab)}
idx2source = {idx : word for idx, word in enumerate(s_vocab)}

# %%
# vocabulary for targets
t_vocab = list(set(sum(targets, [])))
t_vocab.sort()
t_vocab = ['<pad>', '<bos>', '<eos>'] + t_vocab
target2idx = {word : idx for idx, word in enumerate(t_vocab)}
idx2target = {idx : word for idx, word in enumerate(t_vocab)}

# %%
def preprocess(sequences, max_len, dic, mode = 'source'):
    assert mode in ['source', 'target'], 'source와 target 중에 선택해주세요.'
    
    if mode == 'source':
        # preprocessing for source (encoder)
        s_input = list(map(lambda sentence : [dic.get(token) for token in sentence], sequences))
        
        #s_input = [[x for x in each_input if x] for each_input in s_input]
        #pprint(s_input)
        s_len = list(map(lambda sentence : len(sentence), s_input))
        s_input = pad_sequences(sequences = s_input, maxlen = max_len, padding = 'post', truncating = 'post')
        return s_len, s_input
    

    elif mode == 'target':
        # preprocessing for target (decoder)
        # input
        t_input = list(map(lambda sentence : ['<bos>'] + sentence + ['<eos>'], sequences))
        
        #t_input = [[x for x in each_input if x] for each_input in t_input]
        #pprint(t_input)
        t_input = list(map(lambda sentence : [dic.get(token) for token in sentence], t_input))
        t_len = list(map(lambda sentence : len(sentence), t_input))
        t_input = pad_sequences(sequences = t_input, maxlen = max_len, padding = 'post', truncating = 'post')
     
        # output
        t_output = list(map(lambda sentence : sentence + ['<eos>'], sequences))
        t_output = list(map(lambda sentence : [dic.get(token) for token in sentence], t_output))
        t_output = pad_sequences(sequences = t_output, maxlen = max_len, padding = 'post', truncating = 'post')
        
        return t_len, t_input, t_output

# %%
# preprocessing for source
s_max_len = 10
s_len, s_input = preprocess(sequences = sources,
                            max_len = s_max_len, dic = source2idx, mode = 'source')
#print(s_len, s_input)

# %%
# preprocessing for target
t_max_len = 12
t_len, t_input, t_output = preprocess(sequences = targets,
                                      max_len = t_max_len, dic = target2idx, mode = 'target')
print(t_len, t_input, t_output)
# Out:
# [5, 7, 18, 5, 7, 9, 17, 5, 9, 9, 9, 6, 5, 5, 25, 8, 8, 8, 4, 8, 5, 8, 26, 17, 7, 6, 13, 11, 47, 6, 12, 13, 6, 10, 15, 8, 6, 17, 9, 9, 75, 35, 12, 8, 4, 10, 12, 8, 13, 8, 4, 12, 22, 4, 7, 6, 4, 10, 5, 23, 8, 8, 5, 7, 10, 10, 12, 7, 5, 7, 6, 23, 7, 6, 5, 12, 6, 10, 14, 19, 4, 12, 7, 6, 8, 8, 6, 9, 37, 15, 6, 5, 13, 8, 11, 7, 13, 10, 7, 5, 9, 6, 6, 16, 10, 14, 9, 10, 16, 11, 8, 6, 10, 6, 8, 8, 21, 11, 10, 23, 6, 6, 5, 13, 10, 6, 10, 12, 5, 7, 8, 5, 5, 12, 8, 9, 10, 8, 8, 6, 4, 9, 4, 6, 11, 5, 14, 11, 5, 11, 12, 13, 6, 29, 10, 8, 13, 10, 10, 7, 7, 5, 11, 10, 6, 7, 7, 9, 7, 8, 8, 9, 11, 6, 7, 11, 6, 8, 6, 14, 5, 9, 16, 11, 18, 6, 45, 9, 5, 8, 7, 9, 23, 9, 9, 13, 16, 8, 9, 17, 4, 7, 10, 14, 5, 6, 7, 12, 8, 9, 5, 17, 5, 26, 10, 11, 5, 8, 8, 6, 11, 7, 7, 13, 6, 13, 15, 6, 7, 26, 9, 12, 10, 12, 16, 9, 8, 11, 11, 6, 15, 7, 8, 12, 8, 5, 10, 8, 11, 10, 9, 9, 6, 9, 16, 10, 8, 6, 16, 12, 10, 6, 12, 8, 9, 6, 8, 20, 15, 14, 9, 7, 19, 12, 9, 6, 6, 14, 8, 13, 10, 11, 9, 18, 15, 6, 10, 13, 18, 13, 8, 6, 10, 9, 8, 9, 6, 11, 20, 9, 10, 3, 6, 9, 8, 10, 14, 5, 28, 10, 18, 7, 25, 10, 13, 9, 10, 9, 13, 11, 16, 7, 19, 8, 7, 10, 10, 17, 7, 10, 6, 8, 32, 7, 20, 11, 8, 14, 17, 5, 5, 8, 5, 5, 5, 6, 7, 16, 10, 5, 15, 9, 15, 6, 6, 20, 5, 10, 6, 9, 5, 4, 6, 9, 10, 4, 13, 7, 11, 26, 7, 13, 9, 10, 6, 8, 6, 12, 8, 8, 8, 9, 7, 7, 7, 7, 11, 11, 10, 16, 16, 9, 6, 9, 9, 9, 7, 7, 11, 7, 21, 23, 9, 16, 8, 8, 10, 8, 7, 13, 3, 11, 13, 4, 8, 12, 18, 10, 12, 8, 10, 11, 7, 11, 6, 9, 7, 19, 10, 7, 6, 10, 18, 7, 13, 6, 7, 16, 14, 13, 20, 4, 5, 11, 6, 7, 12, 9, 7, 8, 9, 7, 12, 12, 10, 8, 5, 15, 11, 4, 10, 13, 13, 14, 6, 16, 8, 7, 6, 5, 6, 10, 9, 5, 6, 19, 9, 13, 7, 10, 5, 13, 26, 12, 10, 4, 6, 7, 7, 13, 6, 8, 5, 21, 8, 7, 6, 8, 16, 6, 8, 16, 9, 21, 25, 20, 6, 9, 5, 14, 21, 20, 19, 16, 14, 10, 9, 14, 7, 10, 6, 13, 4, 32, 7, 5, 10, 7, 13, 46, 8, 6, 8, 8, 9, 9, 6, 7, 12, 11, 10, 16, 21, 6, 18, 11, 13, 13, 10, 13, 9, 13, 14, 11, 7, 12, 8, 4, 15, 12, 7, 10, 9, 13, 9, 10, 9, 7, 11, 19, 18, 6, 12, 12, 6, 10, 10, 10, 5, 9, 7, 13, 12, 7, 9, 12, 7, 7, 7, 9, 6, 6, 11, 6, 9, 9, 14, 6, 13, 7, 9, 7, 10, 12, 22, 9, 16, 9, 6, 13, 15, 10, 7, 7, 8, 7, 12, 5, 7, 8, 9, 9, 8, 9, 7, 13, 13, 23, 10, 5, 5, 16, 10, 13, 12, 22, 6, 8, 5, 9, 4, 4, 13, 10, 9, 12, 6, 9, 10, 13, 8, 9, 6, 10, 6, 9, 11, 13, 18, 8, 12, 6, 7, 24, 8, 7, 7, 12, 6, 13, 6, 14, 11, 4, 13, 6, 7, 10, 7, 7, 10, 16, 5, 15, 10, 5, 7, 11, 7, 8, 19, 11, 5, 8, 5, 5, 6, 21, 16, 11, 10, 6, 13, 15, 6, 11, 13, 10, 11, 16, 13, 14, 9, 20, 12, 21, 7, 10, 13, 11, 5, 7, 5, 13, 6, 18, 10, 13, 13, 5, 7, 13, 9, 12, 13, 8, 10, 5, 5, 15, 28, 8, 10, 7, 10, 9, 9, 9, 6, 10, 9, 15, 7, 6, 13, 17, 7, 18, 4, 9, 28, 9, 19, 10, 10, 7, 12, 12, 9, 9, 8, 5, 15, 19, 6, 8, 9, 25, 7, 16, 8, 12, 116, 11, 5, 8, 22, 12, 7, 8, 30, 12, 5, 5, 6, 9, 5, 8, 21, 9, 9, 7, 9, 11, 18, 12, 37, 6, 5, 8, 8, 12, 8, 19, 10, 22, 19, 6, 22, 9, 23, 8, 8, 7, 11, 10, 17, 12, 6, 14, 19, 14, 14, 5, 9, 14, 10, 16, 6, 9, 10, 6, 13, 7, 13, 11, 13, 6, 6, 9, 99, 12, 10, 13, 13, 16, 8, 17, 11, 10, 5, 11, 12, 7, 9, 8, 10, 19, 10, 18, 7, 13, 35, 10, 14, 10, 5, 6, 14, 7, 6, 8, 5, 8, 13, 6, 12, 12, 10, 6, 11, 10, 12, 4, 6, 16, 7, 9, 16, 12, 11, 14, 6, 5, 8, 8, 12, 11, 17, 8, 10, 6, 7, 6, 8, 16, 5, 6, 8, 25, 7, 6, 9, 14, 11, 20, 15, 10, 18, 16, 7, 10, 8, 8, 9, 11, 6, 19, 16, 6, 13, 6, 7, 9, 10, 9, 7, 7, 13, 13, 17, 9, 16, 17, 9, 11, 13, 16, 22, 9, 10, 12, 7, 7, 8, 6, 8, 28, 10, 5, 8, 4, 9, 21, 19, 8, 7, 8, 14, 10, 12, 6, 9, 11, 15, 10, 19, 12, 7, 6, 5, 26, 9, 14, 4, 5, 8, 5, 13, 12, 10, 7, 14, 12, 8, 7, 7, 21, 7, 9, 14, 6, 16, 8, 19, 10, 8, 12, 6, 10, 7, 16, 14, 11, 7, 8, 16, 13, 7, 7, 8, 13, 13, 8, 8, 19, 36, 13, 10, 6, 8, 6, 9, 8, 11, 10, 9, 12, 6, 9, 7, 5, 5, 9, 12, 8, 28, 14, 12, 10, 14, 5, 13, 9, 5, 5, 20, 13, 10, 9, 4, 8, 15, 10, 15, 63, 11, 8, 17, 10, 9, 12, 6, 5, 18, 5, 9, 26, 11, 11, 7, 14, 13, 9, 7, 7, 7, 7, 5, 6, 10, 9, 14, 5, 7, 12, 7, 19, 13, 12, 13, 6, 7, 6, 12, 6, 9, 11, 8, 29, 34, 10, 9, 14, 6, 19, 10, 8, 8, 6, 20, 8, 20, 8, 15, 4, 7, 7, 7, 11, 8, 15, 11, 13, 15, 8, 12, 5, 11, 7, 23, 5,  ...
#  [   1 3742  374 ...    0    0    0]
#  [   1  382 7679 ... 2059 7830 6959]
#  ...
#  [   1 3280 3609 ... 1166 3305    2]
#  [   1 6989 7604 ... 3609 3728    2]
#  [   1 6959 7542 ... 6959 6246 7909]] [[6959 4845 1290 ...    0    0    0]
#  [3742  374 6959 ...    0    0    0]
#  [ 382 7679 3242 ... 7830 6959 7071]
#  ...
#  [3280 3609 7272 ... 3305    2    0]
#  [6989 7604 2119 ... 3728    2    0]
#  [6959 7542 6643 ... 6246 7909  721]]

# %% [markdown]
# # hyper-param

# %%
# hyper-parameters
epochs = 100
batch_size = 2
learning_rate = .005
total_step = epochs / batch_size
buffer_size = 100
n_batch = buffer_size//batch_size
embedding_dim = 32
units = 32

# input
data = tf.data.Dataset.from_tensor_slices((s_len, s_input, t_len, t_input, t_output))
data = data.shuffle(buffer_size = buffer_size)
data = data.batch(batch_size = batch_size)
# s_mb_len, s_mb_input, t_mb_len, t_mb_input, t_mb_output = iterator.get_next()

# %%
def gru(units):
  # If you have a GPU, we recommend using CuDNNGRU(provides a 3x speedup than GRU)
  # the code automatically does that.
    if tf.test.is_gpu_available():
        return tf.keras.layers.CuDNNGRU(units, 
                                        return_sequences=True, 
                                        return_state=True, 
                                        recurrent_initializer='glorot_uniform')
    else:
        return tf.keras.layers.GRU(units, 
                                   return_sequences=True, 
                                   return_state=True, 
                                   recurrent_activation='sigmoid', 
                                   recurrent_initializer='glorot_uniform')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.enc_units)
        
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        return output, state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.dec_units)
        self.fc = tf.keras.layers.Dense(vocab_size)
                
    def call(self, x, hidden, enc_output):
        
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size * 1, vocab)
        x = self.fc(output)
        
        return x, state
        
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.dec_units))

# %%
encoder = Encoder(len(source2idx), embedding_dim, units, batch_size)
decoder = Decoder(len(target2idx), embedding_dim, units, batch_size)

def loss_function(real, pred):
    mask = 1 - np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
    
#     print("real: {}".format(real))
#     print("pred: {}".format(pred))
#     print("mask: {}".format(mask))
#     print("loss: {}".format(tf.reduce_mean(loss_)))
    
    return tf.reduce_mean(loss_)

# creating optimizer
optimizer = tf.train.AdamOptimizer()

# creating check point (Object-based saving)
checkpoint_dir = './data_out/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                encoder=encoder,
                                decoder=decoder)

# create writer for tensorboard
summary_writer = tf.contrib.summary.create_file_writer(logdir=checkpoint_dir)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
#최근 학습된 모델을 불러오고 이어서 EPOCHS로 돌아감
#checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
data
# Out:
# <DatasetV1Adapter shapes: ((?,), (?, 10), (?,), (?, 12), (?, 12)), types: (tf.int32, tf.int32, tf.int32, tf.int32, tf.int32)>

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    
    hidden = encoder.initialize_hidden_state()
    #print(hidden.shape)
    total_loss = 0
    for i, (s_len, s_input, t_len, t_input, t_output) in enumerate(data):
        loss = 0
        #print(s_input, s_input.shape)
        with tf.GradientTape() as tape:
            enc_output, enc_hidden = encoder(s_input, hidden)

            dec_hidden = enc_hidden
            
            dec_input = tf.expand_dims([target2idx['<bos>']] * batch_size, 1)
            
            #Teacher Forcing: feeding the target as the next input
            for t in range(1, t_input.shape[1]):
                
                predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
                
                loss += loss_function(t_input[:, t], predictions)
            
                dec_input = tf.expand_dims(t_input[:, t], 1) #using teacher forcing
                
        batch_loss = (loss / int(t_input.shape[1]))
        
        total_loss += batch_loss
        
        variables = encoder.variables + decoder.variables
        
        gradient = tape.gradient(loss, variables)
        
        optimizer.apply_gradients(zip(gradient, variables))
        
    if epoch % 10 == 0:
        #save model every 10 epoch
        print('Epoch {} Loss {:.4f} Batch Loss {:.4f}'.format(epoch,
                                            total_loss / n_batch,
                                            batch_loss.numpy()))
        checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# Epoch 0 Loss 195.8770 Batch Loss 4.7306
# Epoch 10 Loss 124.6016 Batch Loss 3.1906
# Epoch 20 Loss 93.5189 Batch Loss 2.4954
# Epoch 30 Loss 72.7913 Batch Loss 1.7229
# Epoch 40 Loss 59.3133 Batch Loss 1.3510
# Epoch 50 Loss 50.5944 Batch Loss 1.1558
# Epoch 60 Loss 44.0625 Batch Loss 1.0846
# Epoch 70 Loss 39.6991 Batch Loss 0.8870
# Epoch 80 Loss 35.7240 Batch Loss 0.8137
# Epoch 90 Loss 32.7558 Batch Loss 0.7465

# %%
#restore checkpoint

#checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
states = tf.train.get_checkpoint_state(checkpoint_dir)
checkpoint_paths = states.all_model_checkpoint_paths
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
#sentence = 'I feel hungry'
sentence = df.movie_summary[39]

# %%
sentence
# Out:
# 'an adaptation of homers great epic the film follows the assault on troy by the united greek forces and chronicles the fates of the men involved. it is the year 1250 b.c. during the late bronze age. two emerging nations begin to clash after paris the trojan prince convinces helen queen of sparta to leave her husband menelaus and sail with him back to troy. after menelaus finds out that his wife was taken by the trojans he asks his brother agamemnon to help him get her back. agamemnon sees this as an opportunity for power. so they set off with 1000 ships holding 50000 greeks to troy. with the help of achilles the greeks are able to fight the never before defeated trojans. but they come to a stop by hector prince of troy. the whole movie shows their battle struggles and the foreshadowing of fate in this remake by wolfgang petersen of homers the iliad.'

# %%
df
# Out:
#                                             movie_genre  \
# 0                  [Adventure, Drama, Horror, Thriller]
# 2                                      [Horror, Sci-Fi]
# 4                           [Adventure, Drama, Fantasy]
# 5                              [Crime, Drama, Thriller]
# 6                          [Adventure, Family, Fantasy]
# 7                             [Comedy, Family, Fantasy]
# 18                          [Horror, Mystery, Thriller]
# 21                              [Action, Crime, Horror]
# 23                                     [Drama, Western]
# 24                                       [Drama, Sport]
# 25                        [Action, Adventure, Thriller]
# 26                         [Action, Adventure, Fantasy]
# 27                          [Action, Adventure, Sci-Fi]
# 29                                              [Drama]
# 31                    [Crime, Drama, Mystery, Thriller]
# 32                            [Action, Crime, Thriller]
# 33                   [Action, Crime, Fantasy, Thriller]
# 34                  [Action, Adventure, Drama, Romance]
# 39                                     [Drama, History]
# 44                [Action, Adventure, Sci-Fi, Thriller]
# 45                 [Action, Adventure, Drama, Thriller]
# 48                    [Biography, Comedy, Drama, Sport]
# 49                          [Action, Adventure, Sci-Fi]
# 50                   [Action, Horror, Sci-Fi, Thriller]
# 51              [Action, Drama, Romance, Thriller, War]
# 52                     [Action, Crime, Drama, Thriller]
# 54    [Action, Crime, Drama, Mystery, Sci-Fi, Thriller]
# 57                        [Adventure, Horror, Thriller]
# 58                                 [Drama, Horror, War]
# 59                          [Action, Adventure, Sci-Fi]
# ...                                                 ...
# 9903                   [Comedy, Drama, Family, Romance]
# 9904                                   [Action, Horror]
# 9906                                           [Comedy]
# 9909                                    [Comedy, Drama]
# 9911                       [Animation, Comedy, Fantasy]
# 9926                                            [Drama]
# 9930                   [Documentary, Adventure, Family]
# 9931                                    [Comedy, Drama]
# 9942                                            [Drama]
# 9948                                            [Drama]
# 9949  [Musical, Adventure, Comedy, Drama, Romance, W...
# 9950                          [Crime, Drama, Film-Noir]
# 9953                                          [Western]
# 9956                                           [Comedy]
# 9960                   [Action, Crime, Drama, Thriller]
# 9961                                    [Comedy, Drama]
# 9964                             [Drama, Thriller, War]
# 9965                                            [Drama]
# 9966                                           [Comedy]
# 9969                                            [Drama]
# 9971                                   [Crime, History]
# 9976                                            [Drama]
# 9978                              [Drama, Western, War]
# 9982                                    [Comedy, Drama]
# 9983                            [History, War, Western]
# 9984                     [Biography, Drama, Sport, War]
# 9986                                            [Drama]
# 9988                                            [Drama]
# 9991                                           [Comedy]
# 9993       [Action, Adventure, Drama, Horror, Thriller]
#
#                                              movie_name  \
# 0                               47 Meters Down: Uncaged
# 2                                                 Alien
# 4     The Lord of the Rings: The Fellowship of the Ring
# 5                                              The Mule
# 6                 Harry Potter and the Sorcerer's Stone
# 7                                           Hocus Pocus
# 18                                      Friday the 13th
# 21                                  From Dusk Till Dawn
# 23                                     Django Unchained
# 24                                            Overcomer
# 25                                              Mile 22
# 26                                                 Thor
# 27                                            Star Trek
# 29                                      American Beauty
# 31                             In the Heat of the Night
# 32                                      The Equalizer 2
# 33                                               Wanted
# 34                                            King Kong
# 39                                                 Troy
# 44                The Hunger Games: Mockingjay - Part 1
# 45                                      The Book of Eli
# 48                              Fighting with My Family
# 49                                        Green Lantern
# 50                                            They Live
# 51                                               Allied
# 52                                  Law Abiding Citizen
# 54                                             Criminal
# 57                                          The Descent
# 58                       Sal챵, or the 120 Days of Sodom
# 59                      Transformers: Age of Extinction
# ...                                                 ...
# 9903                               So This Is Christmas
# 9904                                    The Haunted Sea
# 9906                                Sail a Crooked Ship
# 9909                                            Empties
# 9911                                   Midnight Delight
# 9926                                        Atlikarinca
# 9930                                     Nintendo Quest
# 9931                                       Aloha Summer
# 9942                            Jumpin' at the Boneyard
# 9948                                           Atlantic
# 9949                                         Rose Marie
# 9950                                  Beware, My Lovely
# 9953                                    City of Bad Men
# 9956                                Cheaper to Keep Her
# 9960                                     The Naked Cage
# 9961                                    The White Sheik
# 9964                                  Nazi Love Camp 27
# 9965                                         The Female
# 9966                                Doctor in the House
# 9969                                         Miss Kicki
# 9971                  The Rise and Fall of Legs Diamond
# 9976                            Three Into Two Won't Go
# 9978                                     The Scavengers
# 9982                        The Last Days of Emma Blank
# 9983                                   The Last Command
# 9984                                      Max Schmeling
# 9986                                           Take Out
# 9988                                      Heaven & Hell
# 9991                                    Up in the World
# 9993                                            Cyclone
#
#                                            movie_poster  \
# 0     www.imdb.com/title/tt7329656/mediaviewer/rm242...
# 2     www.imdb.com/title/tt0078748/mediaviewer/rm299...
# 4     www.imdb.com/title/tt0120737/mediaviewer/rm359...
# 5     www.imdb.com/title/tt7959026/mediaviewer/rm320...
# 6     www.imdb.com/title/tt0241527/mediaviewer/rm683...
# 7     www.imdb.com/title/tt0107120/mediaviewer/rm354...
# 18    www.imdb.com/title/tt0758746/mediaviewer/rm380...
# 21    www.imdb.com/title/tt0116367/mediaviewer/rm147...
# 23    www.imdb.com/title/tt1853728/mediaviewer/rm958...
# 24    www.imdb.com/title/tt8186318/mediaviewer/rm428...
# 25    www.imdb.com/title/tt4560436/mediaviewer/rm285...
# 26    www.imdb.com/title/tt0800369/mediaviewer/rm327...
# 27    www.imdb.com/title/tt0796366/mediaviewer/rm101...
# 29    www.imdb.com/title/tt0169547/mediaviewer/rm243...
# 31    www.imdb.com/title/tt0061811/mediaviewer/rm258...
# 32    www.imdb.com/title/tt3766354/mediaviewer/rm140...
# 33    www.imdb.com/title/tt0493464/mediaviewer/rm108...
# 34    www.imdb.com/title/tt0360717/mediaviewer/rm252...
# 39    www.imdb.com/title/tt0332452/mediaviewer/rm108...
# 44    www.imdb.com/title/tt1951265/mediaviewer/rm425...
# 45    www.imdb.com/title/tt1037705/mediaviewer/rm231...
# 48    www.imdb.com/title/tt6513120/mediaviewer/rm280...
# 49    www.imdb.com/title/tt1133985/mediaviewer/rm314...
# 50    www.imdb.com/title/tt0096256/mediaviewer/rm141...
# 51    www.imdb.com/title/tt3640424/mediaviewer/rm195...
# 52    www.imdb.com/title/tt1197624/mediaviewer/rm374...
# 54    www.imdb.com/title/tt3014866/mediaviewer/rm144...
# 57    www.imdb.com/title/tt0435625/mediaviewer/rm398...
# 58    www.imdb.com/title/tt0073650/mediaviewer/rm423...
# 59    www.imdb.com/title/tt2109248/mediaviewer/rm100...
# ...                                                 ...
# 9903  www.imdb.com/title/tt2081367/mediaviewer/rm324...
# 9904  www.imdb.com/title/tt0119261/mediaviewer/rm319...
# 9906  www.imdb.com/title/tt0055394/mediaviewer/rm310...
# 9909  www.imdb.com/title/tt0809951/mediaviewer/rm414...
# 9911  www.imdb.com/title/tt3136146/mediaviewer/rm128...
# 9926  www.imdb.com/title/tt1848789/mediaviewer/rm247...
# 9930  www.imdb.com/title/tt3063470/mediaviewer/rm284...
# 9931  www.imdb.com/title/tt0094637/mediaviewer/rm276...
# 9942  www.imdb.com/title/tt0102174/mediaviewer/rm389...
# 9948  www.imdb.com/title/tt0019658/mediaviewer/rm341...
# 9949  www.imdb.com/title/tt0047429/mediaviewer/rm399...
# 9950  www.imdb.com/title/tt0044417/mediaviewer/rm311...
# 9953  www.imdb.com/title/tt0045632/mediaviewer/rm115...
# 9956  www.imdb.com/title/tt0080519/mediaviewer/rm125...
# 9960  www.imdb.com/title/tt0091603/mediaviewer/rm152...
# 9961  www.imdb.com/title/tt0044000/mediaviewer/rm407...
# 9964  www.imdb.com/title/tt0140588/mediaviewer/rm392...
# 9965  www.imdb.com/title/tt0051608/mediaviewer/rm140...
# 9966  www.imdb.com/title/tt0046921/mediaviewer/rm412...
# 9969  www.imdb.com/title/tt1322346/mediaviewer/rm150...
# 9971  www.imdb.com/title/tt0054243/mediaviewer/rm421...
# 9976  www.imdb.com/title/tt0065097/mediaviewer/rm378...
# 9978  www.imdb.com/title/tt0067714/mediaviewer/rm132...
# 9982  www.imdb.com/title/tt1239446/mediaviewer/rm413...
# 9983  www.imdb.com/title/tt0048287/mediaviewer/rm391...
# 9984  www.imdb.com/title/tt1361828/mediaviewer/rm302...
# 9986  www.imdb.com/title/tt0391483/mediaviewer/rm375...
# 9988  www.imdb.com/title/tt0192528/mediaviewer/rm980...
# 9991  www.imdb.com/title/tt0049906/mediaviewer/rm392...
# 9993  www.imdb.com/title/tt0075901/mediaviewer/rm152...
#
#                                           movie_summary  \
# 0     once inside their rush of excitement turns int...
# 2     after a space merchant vessel perceives an unk...
# 4     a meek hobbit from the shire and eight compani...
# 5     a 90yearold horticulturist and korean war vete...
# 6     an orphaned boy enrolls in a school of wizardr...
# 7     a curious youngster moves to salem where he st...
# 18    a group of young adults discover a boarded up ...
# 21    two criminals and their hostages unknowingly s...
# 23    with the help of a german bounty hunter a free...
# 24    a highschool basketball coach volunteers to co...
# 25    a small team of elite american intelligence of...
# 26    the powerful but arrogant god thor is cast out...
# 27    the brash james t. kirk tries to live up to hi...
# 29    a sexually frustrated suburban father has a mi...
# 31    an africanamerican police detective is asked t...
# 32    robert mccall serves an unflinching justice fo...
# 33    a frustrated office worker learns that he is t...
# 34    a greedy film producer assembles a team of mov...
# 39    an adaptation of homers great epic the film fo...
# 44    katniss everdeen is in district 13 after she s...
# 45    a postapocalyptic tale in which a lone man fig...
# 48    a former wrestler and his family make a living...
# 49    reckless test pilot hal jordan is granted an a...
# 50    a drifter discovers a pair of sunglasses that ...
# 51    in 1942 a canadian intelligence officer in nor...
# 52    a frustrated man decides to take justice into ...
# 54    in a lastditch effort to stop a diabolical plo...
# 57    a caving expedition goes horribly wrong as the...
# 58    in world war ii italy four fascist libertines ...
# 59    when humanity allies with a bounty hunter in p...
# ...                                                 ...
# 9903  ashley lives in the fast lane until a handyman...
# 9904  a mysterious ship is found adrift in midocean ...
# 9906  a bungling burglar determined to go down in th...
# 9909  a comic love story about a man who refuses to ...
# 9911  set of characters in a smoking lounge reflect ...
# 9926  erdem and sevil live in a small town with thei...
# 9930  in this allencompassing documentary on nintend...
# 9931  its the 60s and a bunch of crazy teenagers mee...
# 9942  manny tries to get his crack addict brother da...
# 9948  on its maiden voyage in april 1912 the suppose...
# 9949  tomboy rose marie lemaitre the orphaned ward o...
# 9950  a psychopath on the run takes a job as a handy...
# 9953  after six years spent in mexico a penniless br...
# 9956  a newly divorced swinger on the prowl goes to ...
# 9960  a young woman is falsely convicted of a bank r...
# 9961  during a day in their honeymoon a couple is se...
# 9964  as the menacing clouds of wwii spread all over...
# 9965  handsome and rich spanish gentleman abandons h...
# 9966  simon sparrow sir dirk bogarde is a newly arri...
# 9969  kicki has after several years abroad returned ...
# 9971  jack diamond and his sickly brother arrive in ...
# 9976  steve howard a british sales executive living ...
# 9978  renegade confederate soldiers take over a fron...
# 9982  a woman living in a large country home drives ...
# 9983  moderate jim bowie leads rebellious texicansan...
# 9984  max schmelings fights against joe louis are li...
# 9986  an illegal chinese immigrant falls behind on p...
# 9988  in 1990s los angeles danger lurks around the c...
# 9991  a friendly window cleaner works at an english ...
# 9993  an airplane goes down in the ocean during a st...
#
#                                          movie_synopsis  \
# 0     the film starts at a girls school in yucatan m...
# 2     the opening credits appear in front of a large...
# 4     the prologue spoken by galadriel shows the dar...
# 5     this movie is based on a true story of a world...
# 6     lord voldemort an evil and powerful dark wizar...
# 7     hocus pocus begins in a small town in  were a ...
# 18                      n                 n
# 21    texas sheriff edgar mcgraw pulls up to an isol...
# 23    in  django   a slave is chained to a bunch of ...
# 24    the opening scene takes us into the gym of bro...
# 25    the film starts with agents alice kerr lauren ...
# 26    three scientists jane foster   erik selvig   a...
# 27    in  the uss kelvin a federation starship inves...
# 29    lester burnham kevin spacey is a yearold fathe...
# 31    philip colbert a wealthy man from chicago who ...
# 32    the film opens on the turkish railway  miles f...
# 33    a young man named wesley gibson james mcavoy w...
# 34    in  during the great depression vaudeville act...
# 39    the story takes place in the fertile eastern l...
# 44    katniss everdeen   victor of the th and th hun...
# 45    the film opens in ashfilled woods. a corpse li...
# 48    young saraya bevis and her brother zak are fig...
# 49    millions of years before the earth was formed ...
# 50    george nada roddy piper is a homeless laborer ...
# 51    french morocco  max vatan brad pitt parachutes...
# 52    clyde shelton gerard butler a philadelphia eng...
# 54    the film opens with jericho stewart kevin cost...
# 57    a whitewater rafting trip is underway with thr...
# 58                      n                 n
# 59    after defeating sentinel prime and megatrons a...
# ...                                                 ...
# 9903                    n                 n
# 9904                    n                 n
# 9906                    n                 n
# 9909                    n                 n
# 9911                    n                 n
# 9926                    n                 n
# 9930                    n                 n
# 9931                    n                 n
# 9942                    n                 n
# 9948                    n                 n
# 9949                    n                 n
# 9950                    n                 n
# 9953                    n                 n
# 9956                    n                 n
# 9960                    n                 n
# 9961  young newlyweds ivan cavalli leopoldo trieste ...
# 9964                    n                 n
# 9965                    n                 n
# 9966                    n                 n
# 9969                    n                 n
# 9971                    n                 n
# 9976                    n                 n
# 9978                    n                 n
# 9982  a simple country house on the edge of the dune...
# 9983                    n                 n
# 9984  in the opening scene set in may  during the ge...
# 9986                    n                 n
# 9988                    n                 n
# 9991                    n                 n
# 9993                    n                 n
#
#                                           movie_tagline
# 0                                      the next chapter
# 2                          its alien the 8th passenger.
# 4     all we have to decide is what to do with the t...
# 5                                   nobody runs forever
# 6                       the magic begins november 16th.
# 7                       its just a bunch of hocus pocus
# 18    you know his name. you know the story. on frid...
# 21                             vampires. no interviews.
# 23                    the d is silent. payback wont be.
# 24                      what do you allow to define you
# 25                  90 minutes. 22 miles. zero back up.
# 26                                two worlds. one hero.
# 27                                   the future begins.
# 29                                      ... look closer
# 31    theyre going to pin something on that smart co...
# 32                             dont go to war with him.
# 33                 their world. her rules. his destiny.
# 34                      the eighth wonder of the world.
# 39                                             for love
# 44                  fire burns brighter in the darkness
# 45                                    religion is power
# 48                  based on the incredible true story.
# 49    in brightest day in blackest night no evil sha...
# 50    i have come here to chew bubblegum and kick as...
# 51                              nothing is as it seems.
# 52                                  justice at any cost
# 54      the cias last hope is in the mind of a criminal
# 57            afraid of the dark you will be july 2005.
# 58    banned in australia for 17 yearsnow for the fi...
# 59                               the rules have changed
# ...                                                 ...
# 9903  sometimes the greatest gifts are the ones you ...
# 9904  an ancient aztec treasure holds the key to esc...
# 9906                                its a kookie cruise
# 9909               a comedy about the fullness of life.
# 9911                                  say hi to high...
# 9926  people can forget what you do them but not how...
# 9930                       the ultimate 8bit road trip.
# 9931  together they faced the biggest challenge of t...
# 9942  brothers dont always love each other but somet...
# 9948      a thunderbolt of drama impossible to describe
# 9949  mgm presents the first great musical in cinema...
# 9950                    trapped by a man beyond control
# 9953  see the most notorious killers of all timeall ...
# 9956  when it comes to girls dekkers just a natural ...
# 9960                  raw violence and hot rage explode
# 9961                 incredibly sweet and charming film
# 9964  a tremendous sexual shocker that goes all the way
# 9965  she couldnt love a man completely til she brou...
# 9966                     republics happygolaughable hit
# 9969                                dreaming the dream.
# 9971                the wildest mobster of the wild 20s
# 9976  shes young and ready...shes wild and willing.....
# 9978  the scavengers were rotten to the corethorough...
# 9982  emma blank waits for her death. so do her serv...
# 9983  the bugle sounds... no mercy no quarter for th...
# 9984       alone against the fhrer... scandinavian dvd.
# 9986         once you enter america you have succeeded.
# 9988  heavens in trouble and theres one man who can ...
# 9991      they walk down the aisle ... youll roll in it
# 9993  the violent storm was only the beginning ... t...
#
# [3996 rows x 6 columns]

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    
    inputs = [inp_lang[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
        
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
        
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
   
    for t in range(max_length_targ):
        

        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += idx2target[predicted_id] + ' '
        
        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)    
            
    return result, sentence
    
result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)

print(sentence)
print(result)
# Out:
# an adaptation of homers great epic the film follows the assault on troy by the united greek forces and chronicles the fates of the men involved. it is the year 1250 b.c. during the late bronze age. two emerging nations begin to clash after paris the trojan prince convinces helen queen of sparta to leave her husband menelaus and sail with him back to troy. after menelaus finds out that his wife was taken by the trojans he asks his brother agamemnon to help him get her back. agamemnon sees this as an opportunity for power. so they set off with 1000 ships holding 50000 greeks to troy. with the help of achilles the greeks are able to fight the never before defeated trojans. but they come to a stop by hector prince of troy. the whole movie shows their battle struggles and the foreshadowing of fate in this remake by wolfgang petersen of homers the iliad.
# fight to save their hands and beauty <eos>

# %%
print(df.movie_tagline[6])  #Troy 8문장 : k = 3
print(df.movie_tagline[23]) #django 39문장 : k = 7
# Out:
# the magic begins november 16th.
# the d is silent. payback wont be.

# %%
len(df.movie_summary[39].split('. '))
# Out:
# 10

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    
    inputs = [inp_lang[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
        
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
    idx = 0
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    
    xList = []
    for t in range(max_length_targ):
      predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
      #print("*"*100)
      #print(predictions)
      #print("*"*100)
      print(tf.argmax(predictions[0]))
      x = tf.nn.top_k(predictions[0], k=3, sorted=True, name=None)
      for i in range(3):
        predicted_id = x[1][i].numpy()


        result += idx2target[predicted_id] + ' '

        if idx2target.get(predicted_id) == '<eos>':
#             return result, sentence
          xList.append([result, sentence])
          result=""

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)  

    return xList

# result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
tList=prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
# print(sentence)
from pprint import pprint
pprint(tList)
# Out:
# tf.Tensor(2633, shape=(), dtype=int64)
# tf.Tensor(440, shape=(), dtype=int64)
# tf.Tensor(7370, shape=(), dtype=int64)
# tf.Tensor(1134, shape=(), dtype=int64)
# tf.Tensor(5735, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(212, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(6959, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(5010, shape=(), dtype=int64)
# tf.Tensor(4382, shape=(), dtype=int64)
# [['fight savage lust and in is undercover red music by over. red remarques '
#   'laugh. up. <eos> ',
#   'an adaptation of homers great epic the film follows the assault on troy by '
#   'the united greek forces and chronicles the fates of the men involved. it is '
#   'the year 1250 b.c. during the late bronze age. two emerging nations begin '
#   'to clash after paris the trojan prince convinces helen queen of sparta to '
#   'leave her husband menelaus and sail with him back to troy. after menelaus '
#   'finds out that his wife was taken by the trojans he asks his brother '
#   'agamemnon to help him get her back. agamemnon sees this as an opportunity '
#   'for power. so they set off with 1000 ships holding 50000 greeks to troy. '
#   'with the help of achilles the greeks are able to fight the never before '
#   'defeated trojans. but they come to a stop by hector prince of troy. the '
#   'whole movie shows their battle struggles and the foreshadowing of fate in '
#   'this remake by wolfgang petersen of homers the iliad.'],
#  ['just told a <eos> ',
#   'an adaptation of homers great epic the film follows the assault on troy by '
#   'the united greek forces and chronicles the fates of the men involved. it is '
#   'the year 1250 b.c. during the late bronze age. two emerging nations begin '
#   'to clash after paris the trojan prince convinces helen queen of sparta to '
#   'leave her husband menelaus and sail with him back to troy. after menelaus '
#   'finds out that his wife was taken by the trojans he asks his brother '
#   'agamemnon to help him get her back. agamemnon sees this as an opportunity '
#   'for power. so they set off with 1000 ships holding 50000 greeks to troy. '
#   'with the help of achilles the greeks are able to fight the never before '
#   'defeated trojans. but they come to a stop by hector prince of troy. the '
#   'whole movie shows their battle struggles and the foreshadowing of fate in '
#   'this remake by wolfgang petersen of homers the iliad.'],
#  ['back <eos> ',
#   'an adaptation of homers great epic the film follows the assault on troy by '
#   'the united greek forces and chronicles the fates of the men involved. it is '
#   'the year 1250 b.c. during the late bronze age. two emerging nations begin '
#   'to clash after paris the trojan prince convinces helen queen of sparta to '
#   'leave her husband menelaus and sail with him back to troy. after menelaus '
#   'finds out that his wife was taken by the trojans he asks his brother '
#   'agamemnon to help him get her back. agamemnon sees this as an opportunity '
#   'for power. so they set off with 1000 ships holding 50000 greeks to troy. '
#   'with the help of achilles the greeks are able to fight the never before '
#   'defeated trojans. but they come to a stop by hector prince of troy. the '
#   'whole movie shows their battle struggles and the foreshadowing of fate in '
#   'this remake by wolfgang petersen of homers the iliad.'],
#  ['a in the a earth <eos> ',
#   'an adaptation of homers great epic the film follows the assault on troy by '
#   'the united greek forces and chronicles the fates of the men involved. it is '
#   'the year 1250 b.c. during the late bronze age. two emerging nations begin '
#   'to clash after paris the trojan prince convinces helen queen of sparta to '
#   'leave her husband menelaus and sail with him back to troy. after menelaus '
#   'finds out that his wife was taken by the trojans he asks his brother '
#   'agamemnon to help him get her back. agamemnon sees this as an opportunity '
#   'for power. so they set off with 1000 ships holding 50000 greeks to troy. '
#   'with the help of achilles the greeks are able to fight the never before '
#   'defeated trojans. but they come to a stop by hector prince of troy. the '
#   'whole movie shows their battle struggles and the foreshadowing of fate in '
#   'this remake by wolfgang petersen of homers the iliad.']]

# %%
def evaluate(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    attention_plot = np.zeros((max_length_targ, max_length_inp))
    
#     sentence = preprocess_sentence(sentence)

    inputs = [inp_lang[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
    
    result = ''

    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input, dec_hidden, enc_out)
        
        # storing the attention weigths to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += idx2target[predicted_id] + ' '

        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence, attention_plot
        
        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention_plot

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %%
sentence = 'I feel hungry'

# %%
result, sentence, a = evaluate(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
print(result)
print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-258-2922982f06ad> in <module>()
# ----> 1 result, sentence, a = evaluate(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
#       2 print(result)
#       3 print(sentence)
#
# <ipython-input-257-1f3facf12fd0> in evaluate(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ)
#      17
#      18     for t in range(max_length_targ):
# ---> 19         predictions, dec_hidden, attention_weights = decoder(dec_input, dec_hidden, enc_out)
#      20
#      21         # storing the attention weigths to plot later on
#
# ValueError: not enough values to unpack (expected 3, got 2)
