# %% [markdown]
# # Lab 12-5 sequence to sequence (Keras + eager version)
#
# ### simple neural machine translation training
#
# * sequence to sequence
#
# ### Reference
# * [Sequence to Sequence Learning with Neural Networks](https://arxiv.org/abs/1409.3215)

# %%
pip install tensorflow==1.15

# %%
from __future__ import absolute_import, division, print_function

# Import TensorFlow >= 1.10 and enable eager execution
import tensorflow as tf
print(tf.__version__)
tf.enable_eager_execution()

from matplotlib import font_manager, rc

rc('font', family='AppleGothic') #for mac

import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

from pprint import pprint
import numpy as np
import os
import pandas as pd
import re
#요약
from gensim.summarization.summarizer import summarize

# %%
#path = '/content/drive/My Drive/Colab Notebooks/moviedata2.json'
df = pd.read_json('movies_a.json')
df
# Out:
#                                               movie_genre  \
# 0                           [Action, Adventure, Thriller]
# 1                                [Crime, Drama, Thriller]
# 2                           [Action, Adventure, Thriller]
# 3                       [Action, Comedy, Crime, Thriller]
# 4                               [Action, Crime, Thriller]
# 5               [Comedy, Crime, Drama, Mystery, Thriller]
# 6                       [Action, Drama, Horror, Thriller]
# 7                            [Adventure, Family, Fantasy]
# 8                                          [Crime, Drama]
# 9                             [Adventure, Drama, Fantasy]
# 10                   [Action, Adventure, Fantasy, Sci-Fi]
# 11                           [Adventure, Family, Fantasy]
# 12                                       [Drama, Romance]
# 13                    [Drama, Fantasy, Romance, Thriller]
# 14                                         [Crime, Drama]
# 15                                  [Drama, Romance, War]
# 16                   [Action, Adventure, Fantasy, Sci-Fi]
# 17                            [Adventure, Drama, Romance]
# 18                           [Adventure, Family, Fantasy]
# 19                            [Action, Adventure, Sci-Fi]
# 20           [Adventure, Comedy, Family, Fantasy, Horror]
# 21                   [Action, Adventure, Family, Fantasy]
# 22      [Animation, Action, Adventure, Comedy, Family,...
# 23                    [Action, Adventure, Drama, Fantasy]
# 24                           [Animation, Family, Fantasy]
# 25                           [Adventure, Family, Fantasy]
# 26                           [Action, Adventure, Fantasy]
# 27                          [Action, Adventure, Thriller]
# 28                  [Action, Adventure, Sci-Fi, Thriller]
# 29         [Action, Adventure, Horror, Mystery, Thriller]
# ...                                                   ...
# 125509                                           [Comedy]
# 125510                                            [Drama]
# 125511                                    [Drama, Sci-Fi]
# 125512                                      [Documentary]
# 125513                             [Comedy, Crime, Drama]
# 125514                                          [Romance]
# 125515                                      [Documentary]
# 125516                                            [Crime]
# 125517                                                 []
# 125518                                           [Family]
# 125519                                   [Drama, Romance]
# 125520                                            [Drama]
# 125521                                            [Drama]
# 125522                                            [Drama]
# 125523               [Documentary, Crime, Drama, History]
# 125524                                                 []
# 125525                                       [Drama, War]
# 125526                                            [Music]
# 125527                                                 []
# 125528                                            [Drama]
# 125529                                            [Drama]
# 125530                                      [Documentary]
# 125531                                                 []
# 125532                      [Documentary, History, Music]
# 125533                          [Drama, Horror, Thriller]
# 125534                                                 []
# 125535                                           [Comedy]
# 125536                                                 []
# 125537                                      [Documentary]
# 125538                             [Action, Crime, Drama]
#
#                                                movie_name  \
# 0                                         No Time to Die혻
# 1                                                  Joker혻
# 2                                      Rambo: Last Blood혻
# 3                                                 Stuber혻
# 4                      John Wick: Chapter 3 - Parabellum혻
# 5                                             Knives Out혻
# 6                                                  Crawl혻
# 7                           Maleficent: Mistress of Evil혻
# 8                                 The Godfather: Part II혻
# 9       The Lord of the Rings: The Fellowship of the R...
# 10             Star Wars: Episode I - The Phantom Menace혻
# 11           Fantastic Beasts: The Crimes of Grindelwald혻
# 12                                        Phantom Thread혻
# 13                                                 Ghost혻
# 14                                         The Outsiders혻
# 15                                         The Aftermath혻
# 16                                    Kong: Skull Island혻
# 17                                             Cast Away혻
# 18               Fantastic Beasts and Where to Find Them혻
# 19                                             Time Trap혻
# 20                                            Goosebumps혻
# 21                                   Clash of the Titans혻
# 22                                      BoBoiBoy Movie 2혻
# 23                            The Huntsman: Winter's War혻
# 24                                            The Grinch혻
# 25                                                 Dumbo혻
# 26                                   Clash of the Titans혻
# 27                                               Spectre혻
# 28                                          The Predator혻
# 29                                           Escape Room혻
# ...                                                   ...
# 125509                                     Not Your Year혻
# 125510                     Shocking porn: are ga daisuki혻
# 125511                                     Einstein Girl혻
# 125512                             A arte de interpretar혻
# 125513          Jerry Powell & the Delusions of Grandeur혻
# 125514                                  Love Is a Hunter혻
# 125515                                            Chayka혻
# 125516                          La muerte llama otra vez혻
# 125517                                   Daydream Nation혻
# 125518                               Tante Tut fra Paris혻
# 125519                            The Illustrious Prince혻
# 125520                                The Last White Man혻
# 125521                                      Mukhyamantri혻
# 125522                                          Teenager혻
# 125523                               The Anxious Day Out혻
# 125524                                  Nattuchakkeruttu혻
# 125525                                     Venok sonetov혻
# 125526                                     Zitra se bude혻
# 125527                                   Thalai Prasavam혻
# 125528                                              K챕s철혻
# 125529                         Shimikin no kekkon senshu혻
# 125530                    Hard Beauty Helaine Blumenfeld혻
# 125531                              P.S. - Post Scriptum혻
# 125532                                When a Woman Sings혻
# 125533                  The Reincarnation of Jesse Belle혻
# 125534                                         The Spasm혻
# 125535                                 Music in Salzburg혻
# 125536                                   Les pots cass챕s혻
# 125537                          Silence Above the Clouds혻
# 125538                                        Fair Share혻
#
#                                              movie_poster  \
# 0       www.imdb.com/title/tt2382320/mediaviewer/rm369...
# 1       www.imdb.com/title/tt7286456/mediaviewer/rm335...
# 2       www.imdb.com/title/tt1206885/mediaviewer/rm144...
# 3       www.imdb.com/title/tt7734218/mediaviewer/rm293...
# 4       www.imdb.com/title/tt6146586/mediaviewer/rm237...
# 5       www.imdb.com/title/tt8946378/mediaviewer/rm256...
# 6       www.imdb.com/title/tt8364368/mediaviewer/rm325...
# 7       www.imdb.com/title/tt4777008/mediaviewer/rm354...
# 8       www.imdb.com/title/tt0071562/mediaviewer/rm415...
# 9       www.imdb.com/title/tt0120737/mediaviewer/rm359...
# 10      www.imdb.com/title/tt0120915/mediaviewer/rm223...
# 11      www.imdb.com/title/tt4123430/mediaviewer/rm283...
# 12      www.imdb.com/title/tt5776858/mediaviewer/rm767...
# 13      www.imdb.com/title/tt0099653/mediaviewer/rm247...
# 14      www.imdb.com/title/tt0086066/mediaviewer/rm183...
# 15      www.imdb.com/title/tt5977276/mediaviewer/rm254...
# 16      www.imdb.com/title/tt3731562/mediaviewer/rm941...
# 17      www.imdb.com/title/tt0162222/mediaviewer/rm381...
# 18      www.imdb.com/title/tt3183660/mediaviewer/rm371...
# 19      www.imdb.com/title/tt4815122/mediaviewer/rm424...
# 20      www.imdb.com/title/tt1051904/mediaviewer/rm407...
# 21      www.imdb.com/title/tt0082186/mediaviewer/rm264...
# 22      www.imdb.com/title/tt10419266/mediaviewer/rm36...
# 23      www.imdb.com/title/tt2381991/mediaviewer/rm350...
# 24      www.imdb.com/title/tt2709692/mediaviewer/rm263...
# 25      www.imdb.com/title/tt3861390/mediaviewer/rm181...
# 26      www.imdb.com/title/tt0800320/mediaviewer/rm336...
# 27      www.imdb.com/title/tt2379713/mediaviewer/rm388...
# 28      www.imdb.com/title/tt3829266/mediaviewer/rm311...
# 29      www.imdb.com/title/tt5886046/mediaviewer/rm155...
# ...                                                   ...
# 125509  www.imdb.com/title/tt5106480/mediaviewer/rm285...
# 125510                                                NaN
# 125511                                                NaN
# 125512  www.imdb.com/title/tt9749438/mediaviewer/rm410...
# 125513  www.imdb.com/title/tt2093187/mediaviewer/rm115...
# 125514                                                NaN
# 125515  www.imdb.com/title/tt8137040/mediaviewer/rm130...
# 125516                                                NaN
# 125517                                                NaN
# 125518  www.imdb.com/title/tt0124157/mediaviewer/rm186...
# 125519  www.imdb.com/title/tt0010283/mediaviewer/rm417...
# 125520  www.imdb.com/title/tt10939812/mediaviewer/rm30...
# 125521  www.imdb.com/title/tt1459940/mediaviewer/rm780...
# 125522  www.imdb.com/title/tt0491092/mediaviewer/rm378...
# 125523                                                NaN
# 125524                                                NaN
# 125525                                                NaN
# 125526  www.imdb.com/title/tt2265669/mediaviewer/rm288...
# 125527  www.imdb.com/title/tt3421704/mediaviewer/rm235...
# 125528                                                NaN
# 125529                                                NaN
# 125530  www.imdb.com/title/tt8191244/mediaviewer/rm237...
# 125531                                                NaN
# 125532                                                NaN
# 125533  www.imdb.com/title/tt3097138/mediaviewer/rm246...
# 125534                                                NaN
# 125535  www.imdb.com/title/tt0037106/mediaviewer/rm150...
# 125536  www.imdb.com/title/tt0267839/mediaviewer/rm349...
# 125537  www.imdb.com/title/tt1667874/mediaviewer/rm328...
# 125538                                                NaN
#
#                                             movie_summary  \
# 0                                                      []
# 1       [In Gotham City, mentally-troubled comedian Ar...
# 2       [Rambo must confront his past and unearth his ...
# 3       [A detective recruits his Uber driver into an ...
# 4       [John Wick is on the run after killing a membe...
# 5       [A detective investigates the death of a patri...
# 6       [A young woman, while attempting to save her f...
# 7       [Maleficent and her goddaughter Aurora begin t...
# 8       [The early life and career of Vito Corleone in...
# 9       [A meek Hobbit from the Shire and eight compan...
# 10      [Two Jedi escape a hostile blockade to find al...
# 11      [The second installment of the "Fantastic Beas...
# 12      [Set in 1950s London, Reynolds Woodcock is a r...
# 13      [After a young man is murdered, his spirit sta...
# 14      [The rivalry between two gangs, the poor Greas...
# 15      [Post World War II, a British colonel and his ...
# 16      [After the Vietnam war, a team of scientists e...
# 17      [A FedEx executive undergoes a physical and em...
# 18      [The adventures of writer Newt Scamander in Ne...
# 19      [A professor enters a cave and goes missing. S...
# 20      [A teenager teams up with the daughter of youn...
# 21      [Perseus must battle Medusa and the Kraken to ...
# 22      [BoBoiBoy and his friends have been attacked b...
# 23      [Eric and fellow warrior Sara, raised as membe...
# 24      [A grumpy Grinch plots to ruin Christmas for t...
# 25      [A young elephant, whose oversized ears enable...
# 26      [Perseus demigod, son of Zeus, battles the min...
# 27      [A cryptic message from 007's past sends him p...
# 28      [When a young boy accidentally triggers the un...
# 29      [Six strangers find themselves in a maze of de...
# ...                                                   ...
# 125509  [A guy who got rich quick and then lost it all...
# 125510                                                NaN
# 125511                                                NaN
# 125512                                                NaN
# 125513  [Jerry Powell is a low-level thief with memory...
# 125514                                                NaN
# 125515  [Investigation of financial frauds of persons ...
# 125516                                                NaN
# 125517                                                NaN
# 125518                                                NaN
# 125519                                                NaN
# 125520  [An elderly white man lives in the ghetto and ...
# 125521                                                NaN
# 125522                                                NaN
# 125523  [For his belief and conscience, YOON KI-JIN (Y...
# 125524                                                NaN
# 125525                                                NaN
# 125526  [The theme of my opera is the communist show t...
# 125527                                                NaN
# 125528  [A well known surgeon-professor who saved many...
# 125529                                                NaN
# 125530  [Helaine Blumenfeld is one of the most respect...
# 125531  [A three-part omnibus drama that shows destini...
# 125532  [This music-filled documentary examines the im...
# 125533  [A retired Marshall, who has been recently dia...
# 125534  [Working class of a small town near Ljubljana ...
# 125535                                                NaN
# 125536                                                NaN
# 125537  [Up there, above the clouds, one can feel a my...
# 125538                                                NaN
#
#                                            movie_synopsis  \
# 0                                                      []
# 1       [Gotham City, 1981, Arthur Fleck (Joaquin Phoe...
# 2       [The film opens in Arizona where the aged John...
# 3       [The film starts with Detectives Vic Manning (...
# 4       [John runs through New York as time runs out o...
# 5                    [\n                , \n            ]
# 6       [The film starts at a swim relay at the Univer...
# 7                    [\n                , \n            ]
# 8       [The Godfather Part II presents two parallel s...
# 9       [The prologue, spoken by Galadriel, shows the ...
# 10      [The opening crawl reveals that the Trade Fede...
# 11      [New York, 1927, Notorious dark wizard Gellert...
# 12      [In 1950s London, renowned fashion designer Re...
# 13      [Sam Wheat (Patrick Swayze), a banker, and Mol...
# 14      [The film opens with Ponyboy Curtis (C. Thomas...
# 15                   [\n                , \n            ]
# 16      [In the year 1944, somewhere over the South Pa...
# 17      [Chuck Nolan (Tom Hanks) is a systems engineer...
# 18      [In the year 1926 in the ,  universe, the dark...
# 19      [Students Taylor and Jackie, along with their ...
# 20      [Zach Cooper (, ) is reluctantly moving from N...
# 21      [King Acrisius of Argos (Donald Houston) locks...
# 22                   [\n                , \n            ]
# 23      [Narrator asks "What does the Mirror show you"...
# 24      [In the town of Whoville, the Whos are eagerly...
# 25      [In 1919, equestrian performer and World War I...
# 26      [ is set in the Greek city of Argos, where a w...
# 27                   [\n                , \n            ]
# 28      [This latest of the long-running series 'Preda...
# 29      [A man (Logan Miller) is seen trying to escape...
# ...                                                   ...
# 125509               [\n                , \n            ]
# 125510                                                NaN
# 125511                                                NaN
# 125512                                                NaN
# 125513               [\n                , \n            ]
# 125514                                                NaN
# 125515               [\n                , \n            ]
# 125516                                                NaN
# 125517                                                NaN
# 125518                                                NaN
# 125519                                                NaN
# 125520               [\n                , \n            ]
# 125521                                                NaN
# 125522                                                NaN
# 125523               [\n                , \n            ]
# 125524                                                NaN
# 125525                                                NaN
# 125526               [\n                , \n            ]
# 125527                                                NaN
# 125528               [\n                , \n            ]
# 125529                                                NaN
# 125530  [Hard Beauty, the first film about the life an...
# 125531               [\n                , \n            ]
# 125532               [\n                , \n            ]
# 125533               [\n                , \n            ]
# 125534               [\n                , \n            ]
# 125535                                                NaN
# 125536                                                NaN
# 125537               [\n                , \n            ]
# 125538                                                NaN
#
#                                             movie_tagline
# 0          ['\n', '\n', '\xa0', '\n', '\xa0', '\n', '\n']
# 1                        ['\n', '\nPut on a happy face.']
# 2       ['\n', '\nThey Drew First Blood. He Will Draw ...
# 3            ['\n', '\nBuckle up for a ***** ride', '\n']
# 4       ['\n', '\nOn May 17th, Every Action Has Conseq...
# 5       ['\n', '\nEveryone has a motive. No one has a ...
# 6                  ['\n', '\nThey Were Here First', '\n']
# 7       ['\n', '\nOn October 18, go beyond the fairy t...
# 8       ['\n', "\nAll the power on earth can't change ...
# 9       ['\n', '\nIts power corrupts all who desire it...
# 10                 ['\n', '\nOne truth, one hate.', '\n']
# 11      ['\n', '\nThe fate of one will change the futu...
# 12                       ['\n', '\n', '\xa0', '\n', '\n']
# 13      ['\n', "\nBefore Sam was murdered he told Moll...
# 14      ['\n', "\nS.E. Hinton's classic novel about yo...
# 15      ['\n', '\nIn The Aftermath Of War, The Last Th...
# 16                    ['\n', '\nAll hail the King', '\n']
# 17      ['\n', '\nAt the edge of the world, his journe...
# 18      ['\n', '\nWhat would you do if your beasts esc...
# 19                ['\n', '\nEscape to the future.', '\n']
# 20         ['\n', '\nYou will believe in monsters', '\n']
# 21            ['\n', '\nExperience The Fantastic!', '\n']
# 22                                     ['\n', '\n', '\n']
# 23      ['\n', '\nDiscover the story before Snow White...
# 24               ['\n', '\nChristmas is canceled.', '\n']
# 25      ['\n', '\nIn 2019, a beloved tale will take yo...
# 26               ['\n', '\nThe Clash Begins in 3D', '\n']
# 27                         ['\n', '\nThe dead are alive']
# 28         ['\n', "\nYou'll never see him coming.", '\n']
# 29      ['\n', '\nSolve the Puzzle. Escape the Room. F...
# ...                                                   ...
# 125509                                 ['\n', '\n', '\n']
# 125510                                                 []
# 125511                                                 []
# 125512                                                 []
# 125513     ['\n', '\n', '\xa0', '\n', '\xa0', '\n', '\n']
# 125514                                 ['\n', '\n', '\n']
# 125515                                 ['\n', '\n', '\n']
# 125516                                 ['\n', '\n', '\n']
# 125517                                                 []
# 125518                                 ['\n', '\n', '\n']
# 125519                                 ['\n', '\n', '\n']
# 125520                                 ['\n', '\n', '\n']
# 125521                                 ['\n', '\n', '\n']
# 125522                                                 []
# 125523                                 ['\n', '\n', '\n']
# 125524                                                 []
# 125525                                                 []
# 125526                                 ['\n', '\n', '\n']
# 125527                                                 []
# 125528                                 ['\n', '\n', '\n']
# 125529                                                 []
# 125530                                 ['\n', '\n', '\n']
# 125531                                                 []
# 125532     ['\n', '\n', '\xa0', '\n', '\xa0', '\n', '\n']
# 125533     ['\n', '\n', '\xa0', '\n', '\xa0', '\n', '\n']
# 125534                                                 []
# 125535                                 ['\n', '\n', '\n']
# 125536                                                 []
# 125537                                 ['\n', '\n', '\n']
# 125538                                                 []
#
# [125539 rows x 6 columns]

# %% [markdown]
# # 전처리

# %%
#df = movie_dataframe

df.movie_name = df.movie_name.apply(lambda x: x.replace('혻',''))

df.movie_summary = df.movie_summary.apply(lambda x: str(x).lower())
df.movie_summary = df.movie_summary.apply(lambda x: re.sub("[^A-Za-z. ]", '', x))
df.movie_summary = df.movie_summary.apply(lambda x: x.replace('\\n',''))

#df.movie_synopsis = df.movie_synopsis.apply(lambda x : str(x).lower())
#df.movie_synopsis = df.movie_synopsis.apply(lambda x : re.sub('[^A-Za-z. ]', '', x))

df.movie_tagline = df.movie_tagline.apply(lambda x: str(x).lower())
df.movie_tagline = df.movie_tagline.apply(lambda x: x.replace('\\n','').replace('\\xa0',''))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub('[^A-Za-z. ]', '', x))
df.movie_tagline = df.movie_tagline.apply(lambda x : re.sub(' {2,}', '', x))

#태그라인 없는 데이터 row 삭제
index = df[df['movie_tagline']==''].index
df.drop(index, inplace = True)

#summary 없는 데이터 row 삭제
summary_index = df[df['movie_summary']==''].index
df.drop(summary_index, inplace = True)

# index = df[df['movie_summary'].str.contains('  ')].index
#df.drop(index , inplace = True)

# %%
df.movie_summary = df.movie_summary.apply(lambda x: x.split('.'))

# %%
df = df.reset_index()

# %%
df

# %%
df1 = []
for idx,val in enumerate(df.movie_summary):
    for val2 in val:
        df1.append([df['movie_name'][idx], val2,df['movie_tagline'][idx]])

# %%
df1 = pd.DataFrame(df1)

# %%
df1.columns = ['movie_name','movie_summary','movie_tagline']

# %%
df1

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
df1['shrinked'] = ""
#example = "Family is not an important thing. It's everything."
stop_words = set(stopwords.words('english')) 
for idx, i in enumerate(df1.movie_summary):
    word_tokens = word_tokenize(i)

    result = []
    for w in word_tokens: 
        if w not in stop_words: 
            result.append(w) 
    df1['shrinked'][idx] = list(result)
    if idx % 100 == 0:
        print(idx)
print(df1)
print(word_tokens) 
print(result)

# %%
df2 = df1

# %%
df2.to_json('movie_data_final.json')

# %%
df2 = pd.read_json('movie_data_final.json')

# %%
tl = list(df2["movie_tagline"])
tl = ["".join([ j for j in i if j != "\n"]).strip() for i in tl]

summ = df2['movie_summary']

df2.movie_tagline = tl
df2.movie_summary = summ

sources = [idx for idx in df2['shrinked']]
targets = [i.split() for i in df2['movie_tagline']]

# %% [markdown]
# # 단어 나누기

# %%
# vocabulary for sources
s_vocab = list(set(sum(sources, [])))
s_vocab.sort()
s_vocab = ['<pad>'] + s_vocab
source2idx = {word : idx for idx, word in enumerate(s_vocab)}
idx2source = {idx : word for idx, word in enumerate(s_vocab)}

# %%
# vocabulary for targets
t_vocab = list(set(sum(targets, [])))
t_vocab.sort()
t_vocab = ['<pad>', '<bos>', '<eos>'] + t_vocab
target2idx = {word : idx for idx, word in enumerate(t_vocab)}
idx2target = {idx : word for idx, word in enumerate(t_vocab)}

# %%
def preprocess(sequences, max_len, dic, mode = 'source'):
    assert mode in ['source', 'target'], 'source와 target 중에 선택해주세요.'
    
    if mode == 'source':
        # preprocessing for source (encoder)
        s_input = list(map(lambda sentence : [dic.get(token) for token in sentence], sequences))
        
        #s_input = [[x for x in each_input if x] for each_input in s_input]
        #pprint(s_input)
        s_len = list(map(lambda sentence : len(sentence), s_input))
        s_input = pad_sequences(sequences = s_input, maxlen = max_len, padding = 'post', truncating = 'post')
        return s_len, s_input
    

    elif mode == 'target':
        # preprocessing for target (decoder)
        # input
        t_input = list(map(lambda sentence : ['<bos>'] + sentence + ['<eos>'], sequences))
        
        #t_input = [[x for x in each_input if x] for each_input in t_input]
        #pprint(t_input)
        t_input = list(map(lambda sentence : [dic.get(token) for token in sentence], t_input))
        t_len = list(map(lambda sentence : len(sentence), t_input))
        t_input = pad_sequences(sequences = t_input, maxlen = max_len, padding = 'post', truncating = 'post')
     
        # output
        t_output = list(map(lambda sentence : sentence + ['<eos>'], sequences))
        t_output = list(map(lambda sentence : [dic.get(token) for token in sentence], t_output))
        t_output = pad_sequences(sequences = t_output, maxlen = max_len, padding = 'post', truncating = 'post')
        
        return t_len, t_input, t_output

# %%
sum_ = 0
for i in df.movie_summary:
    length = len(i.split())
    sum_ += length
average_no = sum_ / len(df) #summary당 평균 122.84 단어
# preprocessing for source
#단어 수는 120개로 제한
s_max_len = 10
s_len, s_input = preprocess(sequences = sources,
                            max_len = s_max_len, dic = source2idx, mode = 'source')
print(s_max_len)

# %%
sum_ = 0
for i in df.movie_tagline:
    length = len(i.split())
    sum_ += length
average_no = sum_ / len(df) #각 tagline별 단어 수는 9.6개

# preprocessing for target
#단어 수 10개로 제한
t_max_len = int(average_no)
t_len, t_input, t_output = preprocess(sequences = targets,
                                      max_len = t_max_len, dic = target2idx, mode = 'target')
print(t_max_len)
#print(t_len, t_input, t_output)

# %% [markdown]
# # hyper-param

# %%
# hyper-parameters
epochs = 100
batch_size = 4
learning_rate = .005
total_step = epochs / batch_size
buffer_size = 100
n_batch = buffer_size//batch_size
embedding_dim = 32
units =64

# input
data = tf.data.Dataset.from_tensor_slices((s_len, s_input, t_len, t_input, t_output))
data = data.shuffle(buffer_size = buffer_size)
data = data.batch(batch_size = batch_size)
# s_mb_len, s_mb_input, t_mb_len, t_mb_input, t_mb_output = iterator.get_next()

# %%
def gru(units):
  # If you have a GPU, we recommend using CuDNNGRU(provides a 3x speedup than GRU)
  # the code automatically does that.
    if tf.test.is_gpu_available():
        return tf.keras.layers.CuDNNGRU(units, 
                                        return_sequences=True, 
                                        return_state=True, 
                                        recurrent_initializer='glorot_uniform')
    else:
        return tf.keras.layers.GRU(units, 
                                   return_sequences=True, 
                                   return_state=True, 
                                   recurrent_activation='sigmoid', 
                                   recurrent_initializer='glorot_uniform')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.enc_units)
        
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        return output, state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = gru(self.dec_units)
        self.fc = tf.keras.layers.Dense(vocab_size)
                
    def call(self, x, hidden, enc_output):
        
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size * 1, vocab)
        x = self.fc(output)
        
        return x, state
        
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.dec_units))

# %%
encoder = Encoder(len(source2idx), embedding_dim, units, batch_size)
decoder = Decoder(len(target2idx), embedding_dim, units, batch_size)

def loss_function(real, pred):
    mask = 1 - np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
    
#     print("real: {}".format(real))
#     print("pred: {}".format(pred))
#     print("mask: {}".format(mask))
#     print("loss: {}".format(tf.reduce_mean(loss_)))
    
    return tf.reduce_mean(loss_)

# creating optimizer
optimizer = tf.train.AdamOptimizer()

# creating check point (Object-based saving)
checkpoint_dir = './data_out/training_checkpoints_after중경'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                encoder=encoder,
                                decoder=decoder)
print(checkpoint_prefix)
# create writer for tensorboard
summary_writer = tf.contrib.summary.create_file_writer(logdir=checkpoint_dir)
print(summary_writer)

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    
    hidden = encoder.initialize_hidden_state()
    #print(hidden.shape)
    total_loss = 0
    for i, (s_len, s_input, t_len, t_input, t_output) in enumerate(data):
        loss = 0
        #print(s_input, s_input.shape)
        with tf.GradientTape() as tape:
            enc_output, enc_hidden = encoder(s_input, hidden)

            dec_hidden = enc_hidden
            
            dec_input = tf.expand_dims([target2idx['<bos>']] * batch_size, 1)
            
            #Teacher Forcing: feeding the target as the next input
            for t in range(1, t_input.shape[1]):
                
                predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
                
                loss += loss_function(t_input[:, t], predictions)
            
                dec_input = tf.expand_dims(t_input[:, t], 1) #using teacher forcing
                
        batch_loss = (loss / int(t_input.shape[1]))
        
        total_loss += batch_loss
        
        variables = encoder.variables + decoder.variables
        
        gradient = tape.gradient(loss, variables)
        
        optimizer.apply_gradients(zip(gradient, variables))


    if epoch % 10 == 0:
        #save model every 10 epoch
        print('Epoch {} Loss {:.4f} Batch Loss {:.4f}'.format(epoch,
                                            total_loss / n_batch,
                                            batch_loss.numpy()))
        #optimizer.minimize(variables)
        checkpoint.save(file_prefix = checkpoint_prefix)

# %%
# #최근 학습된 모델을 불러오고 이어서 EPOCHS로 돌아감
# saver = tf.train.Saver()
# with tf.Session() as sess:
    
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
#sentence = 'I feel hungry'
sentence1 = """Wounded Afghan veteran Dr. John Watson (Martin Freeman) meets brilliant 
consulting detective Sherlock Holmes (Benedict Cumberbatch) and moves into a flat 
on 221B Baker Street with him. Their landlady, Mrs. Hudson (Una Stubbs), acts as a de 
facto housekeeper for them. Sherlock's first case, "A Study in Pink", sees him apprehend 
cabbi-turned-serial killer Jeff Hope (Phil Davis). Their confrontation escalates to the 
point that John, who's followed Sherlock unnoticed to the scene, shoots the cabbie out of 
fear for Sherlock's life. However, Sherlock manages to extract from the dying cabbie that 
he was being sponsored in his crimes by a figure called Moriarty, who is apparently a "fan" 
of Sherlock's. The case seals Sherlock and John's friendship. In their next case, "The Blind Banker", 
they uncover a Chinese smuggling ring, which is again implied to have been linked to Moriarty.
"The Great Game" sees Sherlock being baited into solving a series of "puzzles" by Moriarty, who is 
as yet unseen. Each puzzle involves solving an undetected crime, with the additional incentive 
being that failure to solve the crime within a set time will lead to the death of an innocent 
bystander. Simultaneously, Sherlock works on recovering the missing Bruce-Partington Plans for 
his older brother Mycroft (Mark Gatiss), who is a powerful figure in the British government. 
The series ends with Sherlock encountering Moriarty (Andrew Scott) by a swimming pool, 
where Moriarty warns Sherlock that he will destroy him.""".lower()
sentence2 = """The series ends with Sherlock encountering Moriarty (Andrew Scott) by a swimming pool, 
where Moriarty warns Sherlock that he will destroy him.""".lower()
sentence3 = df.movie_summary[200]
print(df.movie_summary[7])
print(df.movie_name[7])
print(df.movie_tagline[7])
#sentence = 'desperado'
#checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
df[df['movie_tagline'].str.contains('dirty mind')]

# %%
sentence3 = 'donghoon loves a pie.'
sentence3

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(inp_lang[i])  
    print(inputs)
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)   
    print(inputs)
    result = ''  
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)     
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    print(dec_input)
    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += idx2target[predicted_id] + ' '
        print(idx2target[predicted_id])
        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence
        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)               
    return result, sentence    
result, output_sentence = prediction(sentence3, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)

print(output_sentence)
print(result)

# %%
df[df['movie_tagline'].str.contains('thats all they')]

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(inp_lang[i])  
    print(inputs)
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)   
    print(inputs)
    result = ''  
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)     
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    print(dec_input)
    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += idx2target[predicted_id] + ' '
        print(idx2target[predicted_id])
        if idx2target.get(predicted_id) == '<eos>':
            return result, sentence
        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)               
    return result, sentence    
result, output_sentence = prediction(sentence1, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)

print(output_sentence)
print(result)

# %%
#len(df.movie_summary[39].split('. '))

# %%
def prediction(sentence, encoder, decoder, inp_lang, targ_lang, max_length_inp, max_length_targ):
    inputs = []
    x = sentence.split(' ')
    #keyerror 처리
    for i in x:
        if not i in inp_lang.keys():
            pass
        else:
            inputs.append(inp_lang[i])
            
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)
    print(inputs)
    result = ''
    
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)
    idx = 0
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang['<bos>']], 0)
    #print(dec_input)
    xList = []
    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        #print("*"*100)
        #print(predictions)
        #print("*"*100)
        #print(tf.argmax(predictions[0]))
        print(predictions)
        x = tf.nn.top_k(predictions[0], k=4, sorted=True, name=None)
        for i in range(4):
            predicted_id = x[1][i].numpy()
            #print(predicted_id)

            result += idx2target[predicted_id] + ' '
            #print("result:", result)
            #print(idx2target[predicted_id])
            #if idx2target.get(predicted_id) == '<eos>':
            #             return result, sentence

          #result=""

        # the predicted ID is fed back into the model
            dec_input = tf.expand_dims([predicted_id], 0)  
        xList.append([result])
        result = ''
        
    return xList

# result, output_sentence = prediction(sentence, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
tList=prediction(sentence1, encoder, decoder, source2idx, target2idx, s_max_len, t_max_len)
# print(sentence)
from pprint import pprint
pprint(tList)
